# %% [markdown]
# # StudentPerformance_RandomSearchCV
# This is a duplicate notebook from StudentPerformance_with_NN. In this notebook I will use Grid Search Cross Validation to search for optimum hyperparameter instead of doing it empirically in the previous notebook.
#
# Hyperparameters Grid Search 101:
#
# https://elutins.medium.com/grid-searching-in-machine-learning-quick-explanation-and-python-implementation-550552200596
#
# References:
#
# https://machinelearningmastery.com/grid-search-hyperparameters-deep-learning-models-python-keras/

# %% [markdown]
# ### Other Notebooks(in this learnign "series"):
# 1. [Genetic Algorithm with Python](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/GA_with_Python.ipynb) --> Understanding Genetic Algorithm with Python(without libraries)
# 2. [Predicting Student Performance(Empirically)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_with_NN.ipynb) --> Empirically tune hyper-parameters
#
# ***This Notebook*** 3. [Predicting Student Performance(SKLearn's GridSearchCV)](ww) --> Tune hyper-parameters with Sci-Kit Learn's GridSearchCV
#
# 4. [Predicting Student Performance(Genetic Algorithm with PyGAD)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_PyGAD.ipynb) --> Tune hyper-parameters with GA using PyGAD
# 5. [Predicting Student Performance(Genetic Algorithm with Trained Model + PyGAD)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_Tensorflow_PyGAD.ipynb) --> Tune GA hyper-parameters using PyGAD of a trained Model
# 6. [Some Findings, Comparison, Summary](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/GA_summary.ipynb) --> Summary of this learning "series"
# 7. [Using GA to find the Best Hyperparameters](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_with_HParamter_GA_Tuning.ipynb) --> Using GA to find the Best Hyperparameters, encoding desire hyperparameter into gene in string of chromosome.

# %% [markdown]
# ### Index
#
# 1. Dataset
# 2. Packages Needed
# 3. Data Preprocessing
# 4. Grid Search Cross Validation
# 5. Inference
# 6. Some findings

# %% [markdown]
# ## 1. Dataset
#
# Source: https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# ### Description
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires.
#
# Two datasets are provided regarding the performance in two distinct subjects: Mathematics (mat) and Portuguese language (por).
#
# ### Note: In this notebook, I used the Dataset with Portuguese Language
#
# In [Cortez and Silva, 2008], the two datasets were modeled under binary/five-level classification and regression tasks.
#
# Important note: the target attribute G3 has a strong correlation with attributes G2 and G1.
#
# This occurs because G3 is the final year grade (issued at the 3rd period), while G1 and G2 correspond to the 1st and 2nd-period grades. It is more difficult to predict G3 without G2 and G1, but such prediction is much more useful (see paper source for more details).

# %% [markdown]
# ### Attribute Information:
#
# ### Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
# * 1 school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)*
# * 2 sex - student's sex (binary: 'F' - female or 'M' - male)
# * 3 age - student's age (numeric: from 15 to 22)
# * 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * 7 Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# * 8 Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# * 9 Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * 10 Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# * 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# * 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * 16 schoolsup - extra educational support (binary: yes or no)
# * 17 famsup - family educational support (binary: yes or no)
# * 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * 19 activities - extra-curricular activities (binary: yes or no)
# * 20 nursery - attended nursery school (binary: yes or no)
# * 21 higher - wants to take higher education (binary: yes or no)
# * 22 internet - Internet access at home (binary: yes or no)
# * 23 romantic - with a romantic relationship (binary: yes or no)
# * 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
# * 30 absences - number of school absences (numeric: from 0 to 93)
#
# #### these grades are related with the course subject, Math or Portuguese:
# * 31 G1 - first period grade (numeric: from 0 to 20)
# * 31 G2 - second period grade (numeric: from 0 to 20)
# * 32 G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## 2. Packages Needed

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.constraints import MaxNorm
from tensorflow import convert_to_tensor

from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import RandomizedSearchCV, KFold

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# ### 3. Data Preprocessing
#
# Here, I will find for empty data, encode categorical data, plot some graph to understand the data.

# %%
df = pd.read_csv("student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         4   0  11  11
# 1       1     1       3         2   9  11  11
# 2       2     3       3         6  12  13  12
# 3       1     1       5         0  14  14  14
# 4       1     2       5         0  11  13  13
# ..    ...   ...     ...       ...  ..  ..  ..
# 644     1     2       5         4  10  11  10
# 645     1     1       1         4  15  15  16
# 646     1     1       5         6  11  12   9
# 647     3     4       2         6  10  10  10
# 648     3     4       5         4  10  11  11
#
# [649 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
# df.dtypes

# %%
# df.isnull().sum() 
# Check for missing data

# %%
features_list = list(df.columns)[:-1]
print("Features: {x}".format(x = features_list))
print("\nNumber of Features: {x}".format(x = len(features_list)))
# Out:
# Features: ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']
#
# Number of Features: 32

# %%
# df.info()
# # Check datatype of features

# %%
features = df.drop(["G3"], axis = 1)
features
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2
# 0       1     1       3         4   0  11
# 1       1     1       3         2   9  11
# 2       2     3       3         6  12  13
# 3       1     1       5         0  14  14
# 4       1     2       5         0  11  13
# ..    ...   ...     ...       ...  ..  ..
# 644     1     2       5         4  10  11
# 645     1     1       1         4  15  15
# 646     1     1       5         6  11  12
# 647     3     4       2         6  10  10
# 648     3     4       5         4  10  11
#
# [649 rows x 32 columns]

# %%
target = df.drop(features_list, axis = 1)
target
# Out:
#      G3
# 0    11
# 1    11
# 2    12
# 3    14
# 4    13
# ..   ..
# 644  10
# 645  16
# 646   9
# 647  10
# 648  11
#
# [649 rows x 1 columns]

# %%
mapping_school = {'GP' : 0, 'MS' : 1}
mapping_sex = {'F' : 0, 'M' : 1}
mapping_address = {'U' : 0, 'R' : 1}
mapping_famsize = {'GT3' : 0, 'LE3' : 1}
mapping_pstatus = {'A' : 0, 'T' : 1}
mapping_mjob = {'at_home' : 0, 'health' : 1, 'other' : 2, 'services' : 3, 'teacher' : 4}
mapping_fjob = {'at_home' : 0, 'health' : 1, 'other' : 2, 'services' : 3, 'teacher' : 4}
mapping_reason = {'course' : 0, 'other' : 1, 'home' : 2, 'reputation' : 3}
mapping_guardian = {'mother' : 0, 'father' : 1, 'other': 2}
mapping_schoolsup = {'no' : 0, 'yes' : 1}
mapping_famsup = {'no' : 0, 'yes' : 1}
mapping_romantic = {'no' : 0, 'yes' : 1}
mapping_paid = {'no' : 0, 'yes' : 1}
mapping_activities = {'no' : 0, 'yes' : 1}
mapping_nursery = {'no' : 0, 'yes' : 1}
mapping_higher = {'no' : 0, 'yes' : 1}
mapping_internet = {'no' : 0, 'yes' : 1}

# %%
df['school'] = features['school'].map(mapping_school)
df['sex'] = features['sex'].map(mapping_sex)
df['address'] = features['address'].map(mapping_address)
df['famsize'] = features['famsize'].map(mapping_famsize)
df['Pstatus'] = features['Pstatus'].map(mapping_pstatus)
df['Mjob'] = features['Mjob'].map(mapping_mjob)
df['Fjob'] = features['Fjob'].map(mapping_fjob)
df['reason'] = features['reason'].map(mapping_reason)
df['guardian'] = features['guardian'].map(mapping_guardian).astype('Int64')
df['famsup'] = features['famsup'].map(mapping_famsup)
df['schoolsup'] = features['schoolsup'].map(mapping_schoolsup)
df['romantic'] = features['romantic'].map(mapping_romantic)
df['paid'] = features['paid'].map(mapping_paid)
df['activities'] = features['activities'].map(mapping_activities)
df['nursery'] = features['nursery'].map(mapping_nursery)
df['higher'] = features['higher'].map(mapping_higher)
df['internet'] = features['internet'].map(mapping_internet)

# %%
features
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2
# 0       1     1       3         4   0  11
# 1       1     1       3         2   9  11
# 2       2     3       3         6  12  13
# 3       1     1       5         0  14  14
# 4       1     2       5         0  11  13
# ..    ...   ...     ...       ...  ..  ..
# 644     1     2       5         4  10  11
# 645     1     1       1         4  15  15
# 646     1     1       5         6  11  12
# 647     3     4       2         6  10  10
# 648     3     4       5         4  10  11
#
# [649 rows x 32 columns]

# %%
# features.dtypes

# %%
sns.countplot(x='school', data=features);

# %%
features.hist(bins=20, figsize=(20,15));

# %% [markdown]
# #### Outliers
#
# As I go through the data, I found there are students who achieve 0 in their G3 depsite having more than half during their G1 & G2 examinations.
# The outliers might affect model's performance, hence I decided to drop those outliers.

# %%
sns.boxplot(x=target["G3"]);

# %% [markdown]
# #### Drop Outliers data if certain requirement satisfied.
#
# G3 with score of 2.5 and less considered as Outliers. To understand this data, I will list down these outliers.

# %%
df_outliers = df[df["G3"]<2.5]
df_outliers
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 163       0    1   18        0        1        1     1     1     2     2
# 172       0    1   16        0        0        1     3     3     2     3
# 440       1    1   16        0        0        1     1     1     0     3
# 519       1    1   16        1        0        1     2     1     2     3
# 563       1    1   17        0        0        1     2     2     2     2
# 567       1    1   18        1        0        1     3     2     3     2
# 583       1    0   18        1        0        1     2     2     2     2
# 586       1    0   17        0        0        1     4     2     4     3
# 597       1    0   18        1        0        1     2     2     0     2
# 603       1    0   18        1        1        0     4     2     4     2
# 605       1    0   19        0        0        1     1     1     0     3
# 610       1    0   19        1        0        0     1     1     0     0
# 626       1    0   18        1        0        1     4     4     2     4
# 637       1    1   18        1        0        1     2     1     2     2
# 639       1    1   19        1        0        1     1     1     2     3
# 640       1    1   18        1        0        1     4     2     2     2
#
#      reason  guardian  traveltime  studytime  failures  schoolsup  famsup  \
# 163       0         0           1          1         2          0       0
# 172       0         1           1          2         1          0       1
# 440       2         0           2          2         0          0       1
# 519       3         0           2          2         0          0       0
# 563       0         0           1          1         1          0       0
# 567       0         0           1          1         1          0       0
# 583       1         0           2          1         1          0       0
# 586       2         0           1          2         0          1       1
# 597       0         0           3          2         1          0       0
# 603       3         0           1          2         0          0       0
# 605       1         1           2          1         1          0       0
# 610       0         2           2          2         3          0       1
# 626       1         1           3          2         0          0       1
# 637       1         0           2          1         0          0       0
# 639       1         0           2          1         1          0       0
# 640       2         1           2          1         1          0       0
#
#      paid  activities  nursery  higher  internet  romantic  famrel  freetime  \
# 163     0           0        1       0         1         1       2         3
# 172     0           0        1       1         1         1       4         5
# 440     0           1        1       1         0         1       5         4
# 519     0           1        1       1         1         0       5         2
# 563     0           1        1       1         0         1       1         2
# 567     0           0        1       0         1         0       2         3
# 583     0           0        1       0         1         1       5         5
# 586     0           1        1       1         1         0       5         5
# 597     0           1        1       1         0         1       4         3
# 603     0           1        1       1         1         1       5         3
# 605     0           0        1       0         0         0       5         5
# 610     0           1        1       0         0         1       3         5
# 626     0           0        0       1         1         1       3         2
# 637     0           1        0       1         1         1       4         4
# 639     0           0        1       1         0         0       4         3
# 640     1           0        1       1         0         0       5         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# 163      5     2     5       4         0  11   9   0
# 172      5     4     4       5         0  10  10   1
# 440      5     4     5       3         0   7   0   0
# 519      1     1     1       2         0   8   7   0
# 563      1     2     3       5         0   7   0   0
# 567      1     2     2       5         0   4   0   0
# 583      5     1     1       3         0   8   6   0
# 586      5     1     3       5         0   8   8   0
# 597      3     1     1       4         0   9   0   0
# 603      1     1     1       5         0   5   0   0
# 605      5     2     3       2         0   5   0   0
# 610      4     1     4       1         0   8   0   0
# 626      2     4     2       5         0   7   5   0
# 637      3     1     3       5         0   7   7   0
# 639      2     1     3       5         0   5   8   0
# 640      3     4     3       3         0   7   7   0

# %%
len(df_outliers.index)
# Out:
# 16

# %%
df["G1"].mean()
# Out:
# 11.399075500770415

# %%
df["G2"].median()
# Out:
# 11.0

# %% [markdown]
# #### Dropping rows if:
#
# G3 considered as outliers when G1 or G2 above average.

# %%
outlier_idx = df[df["G3"] < 2.5].index
len(outlier_idx) 
df = df.drop(outlier_idx)
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0         0    0   18        0        0        0     4     4     0     4
# 1         0    0   17        0        0        1     1     1     0     2
# 2         0    0   15        0        1        1     1     1     0     2
# 3         0    0   15        0        0        1     4     2     1     3
# 4         0    0   16        0        0        1     3     3     2     2
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...
# 644       1    0   19        1        0        1     2     3     3     2
# 645       1    0   18        0        1        1     3     1     4     3
# 646       1    0   18        0        0        1     1     1     2     2
# 647       1    1   17        0        1        1     3     1     3     3
# 648       1    1   18        1        1        1     3     2     3     2
#
#      reason  guardian  traveltime  studytime  failures  schoolsup  famsup  \
# 0         0         0           2          2         0          1       0
# 1         0         1           1          2         0          0       1
# 2         1         0           1          2         0          1       0
# 3         2         0           1          3         0          0       1
# 4         2         1           1          2         0          0       1
# ..      ...       ...         ...        ...       ...        ...     ...
# 644       0         0           1          3         1          0       0
# 645       0         0           1          2         0          0       1
# 646       0         0           2          2         0          0       0
# 647       0         0           2          1         0          0       0
# 648       0         0           3          1         0          0       0
#
#      paid  activities  nursery  higher  internet  romantic  famrel  freetime  \
# 0       0           0        1       1         0         0       4         3
# 1       0           0        0       1         1         0       5         3
# 2       0           0        1       1         1         0       4         3
# 3       0           1        1       1         1         1       3         2
# 4       0           0        1       1         0         0       4         3
# ..    ...         ...      ...     ...       ...       ...     ...       ...
# 644     0           1        0       1         1         0       5         4
# 645     0           0        1       1         1         0       4         3
# 646     0           1        1       1         0         0       1         1
# 647     0           0        0       1         1         0       2         4
# 648     0           0        0       1         1         0       4         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# 0        4     1     1       3         4   0  11  11
# 1        3     1     1       3         2   9  11  11
# 2        2     2     3       3         6  12  13  12
# 3        2     1     1       5         0  14  14  14
# 4        2     1     2       5         0  11  13  13
# ..     ...   ...   ...     ...       ...  ..  ..  ..
# 644      2     1     2       5         4  10  11  10
# 645      4     1     1       1         4  15  15  16
# 646      1     1     1       5         6  11  12   9
# 647      5     3     4       2         6  10  10  10
# 648      1     3     4       5         4  10  11  11
#
# [633 rows x 33 columns]

# %% [markdown]
# ### Reassign features and target dataframe after dropping outliers

# %%
target = df.drop(features_list, axis = 1)
features = df.drop(["G3"], axis = 1)

# %% [markdown]
# ## 4. Grid Search Cross Validation
#
# Here the real thing begins. We will use Sci-Kit Learn's GridSearchCV to find the optimal hypter parameters for the model for this problem.
#
# #### To be tuned:
#
# 1. Batch Size & Number of Epochs with Training Optimization Algorithm
# 3. Learning Rate & Momentum(if applies) of the optimal Training Optimization Algorithm
# 4. Network Weight Initialization
# 5. Neuron Activation Function
# 6. Dropout Regularization
# 7. Number of Neurons in the Hidden Layer

# %% [markdown]
# #### Search/Tuning Flow:
# 1. Define Model
# 2. Wrap Keras model with KerasRegressor of Sci-Kit Learn
# 3. Define Grid Parameters
# 4. Train model with Grid Parameters defined
# 5. Summarize Results
#
# Note: Set verbose = 0, as it's gonna be long list.

# %% [markdown]
# #### Data normalization

# %% [markdown]
# #### Split Training and Testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.3,random_state=11)

# %%
X_train.shape
# Out:
# (443, 32)

# %%
scaler = preprocessing.MinMaxScaler(feature_range = (0,1))
X_train_scaled = scaler.fit_transform(X_train)
y_train_scaled = scaler.fit_transform(y_train)
X_test_scaled = scaler.fit_transform(X_test)
y_test_scaled = scaler.fit_transform(y_test)

# %%
X_train_unscaled = scaler.inverse_transform(X_train_scaled).astype('float64') 
y_train_unscaled = scaler.inverse_transform(y_train_scaled).astype('float64') 
X_test_unscaled = scaler.inverse_transform(X_test_scaled).astype('float64') 
y_test_unscaled = scaler.inverse_transform(y_test_scaled).astype('float64')

# %%
X_test_np = X_test.values.astype(int)
y_test_np = y_test.values.astype(int)
X_test_np = convert_to_tensor(X_test_np)
y_test_np = convert_to_tensor(y_test_np)

# %%
X_test.shape, X_train.shape
# Out:
# ((190, 32), (443, 32))

# %% [markdown]
# ### Here we go!

# %% [markdown]
# ### Batch Size & Number of Epochs with Training Optimization Algorithm
#
# 1. ###### Batch Size & Number of Epochs with Training Optimization Algorithm (This section)
# 3. Learning Rate & Momentum(if applies) of the optimal Training Optimization Algorithm
# 4. Network Weight Initialization
# 5. Neuron Activation Function
# 6. Dropout Regularization
# 7. Number of Neurons in the Hidden Layer
#
# Based on the best parameter obtained, we can further fine tune it. For instance, the Adam optimizer used with default Learning Rate of 0.001. Here, GridSearchCV is used again to search for best Learning Rate.

# %%
def create_model(optimizer='adam'):
    
    model = Sequential([
        Dense(32, input_dim=32, activation='relu'),
        Dense(64, activation='relu'),
        Dense(32, activation='relu'),
        Dense(1, activation='relu')
    ])
    
    model.compile(
    loss='mse', 
    optimizer=optimizer, 
    metrics=['mse', 'mae'])
        
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_252 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_253 (Dense)            (None, 64)                2112
# _________________________________________________________________
# dense_254 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_255 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 5,281
# Trainable params: 5,281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = KerasRegressor(build_fn=create_model, verbose=0)

# %%
# define the grid search parameters
batch_size = [10, 50]
epochs = [10, 50, 100, 200, 500, 700, 100]
optimizer = ['SGD', 'RMSprop', 'Adagrad', 'Adam']


param_grid = dict(batch_size=batch_size, epochs=epochs, optimizer=optimizer)
grid = RandomizedSearchCV(estimator=model, param_distributions=param_grid, n_jobs=None, cv=3, verbose =2)
grid_result = grid.fit(X_train_scaled, y_train_scaled)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] optimizer=Adam, epochs=500, batch_size=50 .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........ optimizer=Adam, epochs=500, batch_size=50, total=   2.9s
# [CV] optimizer=Adam, epochs=500, batch_size=50 .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.9s remaining:    0.0s
# [CV] ........ optimizer=Adam, epochs=500, batch_size=50, total=   3.0s
# [CV] optimizer=Adam, epochs=500, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=500, batch_size=50, total=   2.8s
# [CV] optimizer=SGD, epochs=10, batch_size=10 .........................
# [CV] .......... optimizer=SGD, epochs=10, batch_size=10, total=   0.5s
# [CV] optimizer=SGD, epochs=10, batch_size=10 .........................
# [CV] .......... optimizer=SGD, epochs=10, batch_size=10, total=   0.5s
# [CV] optimizer=SGD, epochs=10, batch_size=10 .........................
# [CV] .......... optimizer=SGD, epochs=10, batch_size=10, total=   0.5s
# [CV] optimizer=Adam, epochs=200, batch_size=10 .......................
# [CV] ........ optimizer=Adam, epochs=200, batch_size=10, total=   4.7s
# [CV] optimizer=Adam, epochs=200, batch_size=10 .......................
# [CV] ........ optimizer=Adam, epochs=200, batch_size=10, total=   4.5s
# [CV] optimizer=Adam, epochs=200, batch_size=10 .......................
# [CV] ........ optimizer=Adam, epochs=200, batch_size=10, total=   4.5s
# [CV] optimizer=Adagrad, epochs=500, batch_size=10 ....................
# [CV] ..... optimizer=Adagrad, epochs=500, batch_size=10, total=  10.6s
# [CV] optimizer=Adagrad, epochs=500, batch_size=10 ....................
# [CV] ..... optimizer=Adagrad, epochs=500, batch_size=10, total=  10.2s
# [CV] optimizer=Adagrad, epochs=500, batch_size=10 ....................
# [CV] ..... optimizer=Adagrad, epochs=500, batch_size=10, total=  10.0s
# [CV] optimizer=Adagrad, epochs=100, batch_size=50 ....................
# [CV] ..... optimizer=Adagrad, epochs=100, batch_size=50, total=   0.8s
# [CV] optimizer=Adagrad, epochs=100, batch_size=50 ....................
# [CV] ..... optimizer=Adagrad, epochs=100, batch_size=50, total=   0.8s
# [CV] optimizer=Adagrad, epochs=100, batch_size=50 ....................
# [CV] ..... optimizer=Adagrad, epochs=100, batch_size=50, total=   0.8s
# [CV] optimizer=Adam, epochs=200, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=200, batch_size=50, total=   1.3s
# [CV] optimizer=Adam, epochs=200, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=200, batch_size=50, total=   1.3s
# [CV] optimizer=Adam, epochs=200, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=200, batch_size=50, total=   1.3s
# [CV] optimizer=RMSprop, epochs=50, batch_size=50 .....................
# [CV] ...... optimizer=RMSprop, epochs=50, batch_size=50, total=   0.7s
# [CV] optimizer=RMSprop, epochs=50, batch_size=50 .....................
# [CV] ...... optimizer=RMSprop, epochs=50, batch_size=50, total=   0.7s
# [CV] optimizer=RMSprop, epochs=50, batch_size=50 .....................
# [CV] ...... optimizer=RMSprop, epochs=50, batch_size=50, total=   0.9s
# [CV] optimizer=Adam, epochs=100, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=100, batch_size=50, total=   0.8s
# [CV] optimizer=Adam, epochs=100, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=100, batch_size=50, total=   0.8s
# [CV] optimizer=Adam, epochs=100, batch_size=50 .......................
# [CV] ........ optimizer=Adam, epochs=100, batch_size=50, total=   0.8s
# [CV] optimizer=RMSprop, epochs=100, batch_size=50 ....................
# [CV] ..... optimizer=RMSprop, epochs=100, batch_size=50, total=   1.0s
# [CV] optimizer=RMSprop, epochs=100, batch_size=50 ....................
# [CV] ..... optimizer=RMSprop, epochs=100, batch_size=50, total=   1.0s
# [CV] optimizer=RMSprop, epochs=100, batch_size=50 ....................
# [CV] ..... optimizer=RMSprop, epochs=100, batch_size=50, total=   1.0s
# [CV] optimizer=Adam, epochs=50, batch_size=10 ........................
# [CV] ......... optimizer=Adam, epochs=50, batch_size=10, total=   1.3s
# [CV] optimizer=Adam, epochs=50, batch_size=10 ........................
# [CV] ......... optimizer=Adam, epochs=50, batch_size=10, total=   1.3s
# [CV] optimizer=Adam, epochs=50, batch_size=10 ........................
# [CV] ......... optimizer=Adam, epochs=50, batch_size=10, total=   1.3s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.2min finished

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.008925 using {'optimizer': 'Adam', 'epochs': 200, 'batch_size': 10}
# -0.012422 (0.002478) with: {'optimizer': 'Adam', 'epochs': 500, 'batch_size': 50}
# -0.029369 (0.003853) with: {'optimizer': 'SGD', 'epochs': 10, 'batch_size': 10}
# -0.008925 (0.001017) with: {'optimizer': 'Adam', 'epochs': 200, 'batch_size': 10}
# -0.110665 (0.137571) with: {'optimizer': 'Adagrad', 'epochs': 500, 'batch_size': 10}
# -0.019876 (0.001760) with: {'optimizer': 'Adagrad', 'epochs': 100, 'batch_size': 50}
# -0.009917 (0.001290) with: {'optimizer': 'Adam', 'epochs': 200, 'batch_size': 50}
# -0.019045 (0.008305) with: {'optimizer': 'RMSprop', 'epochs': 50, 'batch_size': 50}
# -0.010491 (0.000855) with: {'optimizer': 'Adam', 'epochs': 100, 'batch_size': 50}
# -0.014705 (0.002462) with: {'optimizer': 'RMSprop', 'epochs': 100, 'batch_size': 50}
# -0.010373 (0.001880) with: {'optimizer': 'Adam', 'epochs': 50, 'batch_size': 10}

# %% [markdown]
# Some reading on the negative values on scoring :
#
# https://stackoverflow.com/questions/21443865/scikit-learn-cross-validation-negative-values-with-mean-squared-error

# %% [markdown]
# ### Learning Rate
#
# 1. Batch Size & Number of Epochs with Training Optimization Algorithm
# (Best Params : Batch Size: 10, Epochs = 700, Optimzation Algorithm: Adam)
# 3. ###### Learning Rate & Momentum(if applies) of the optimal Training Optimization Algorithm (This section)
# 4. Network Weight Initialization
# 5. Neuron Activation Function
# 6. Dropout Regularization
# 7. Number of Neurons in the Hidden Layer
#
# Based on the best parameter obtained, we can further fine tune it. For instance, the Adam optimizer used with default Learning Rate of 0.001. Here, GridSearchCV is used again to search for best Learning Rate.

# %%
def create_model(learn_rate=0.001,
                          init_mode = 'uniform',
                          activation='relu', 
                          output_activation = 'sigmoid',
                          neurons_h_layer_1 = 1, 
                          neurons_h_layer_2 = 1):
    
    model = Sequential([
        Dense(32, 
              input_dim=32, 
              activation='relu', 
              kernel_initializer='lecun_uniform'),
        Dense(neurons_h_layer_1, activation=activation),
        Dense(neurons_h_layer_2, activation=activation),
        Dense(1, activation=output_activation)
    ])
    optimizer = Adam(lr = 0.01)
    
    model.compile(
    loss='mse', 
    optimizer=optimizer, 
    metrics=['mse', 'mae'])
        
    return model

model_2 = KerasRegressor(build_fn=create_model, epochs=200, batch_size=10, verbose=0)

# %% [markdown]
# # w3wwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwwww

# %%
# define the grid search parameters
learn_rate = [0.001, 0.01, 0.005, 0.1]
init_mode = ['uniform', 'lecun_uniform', 'normal', 'zero', 'glorot_normal', 'glorot_uniform', 'he_normal', 'he_uniform']
activation = ['softmax', 'softplus', 'softsign', 'tanh', 'sigmoid', 'hard_sigmoid', 'linear']
output_activation = ['softmax', 'softplus', 'softsign', 'relu', 'tanh', 'hard_sigmoid', 'linear']
neurons_h_layer_1 = [8, 16, 32, 64, 128]
neurons_h_layer_2 = [16, 32, 64, 128]


param_grid = dict(learn_rate=learn_rate, 
                  init_mode=init_mode, 
                  activation=activation, 
                  output_activation=output_activation,
                 neurons_h_layer_1=neurons_h_layer_1, 
                  neurons_h_layer_2=neurons_h_layer_2)
grid = RandomizedSearchCV(estimator=model_2, param_distributions=param_grid, n_jobs=None, cv=3, verbose = 2)
grid_result = grid.fit(X_train_scaled, y_train_scaled)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV] output_activation=softmax, neurons_h_layer_2=32, neurons_h_layer_1=8, learn_rate=0.001, init_mode=glorot_normal, activation=softplus
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  output_activation=softmax, neurons_h_layer_2=32, neurons_h_layer_1=8, learn_rate=0.001, init_mode=glorot_normal, activation=softplus, total=   4.8s
# [CV] output_activation=softmax, neurons_h_layer_2=32, neurons_h_layer_1=8, learn_rate=0.001, init_mode=glorot_normal, activation=softplus
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.8s remaining:    0.0s
# [CV]  output_activation=softmax, neurons_h_layer_2=32, neurons_h_layer_1=8, learn_rate=0.001, init_mode=glorot_normal, activation=softplus, total=   4.5s
# [CV] output_activation=softmax, neurons_h_layer_2=32, neurons_h_layer_1=8, learn_rate=0.001, init_mode=glorot_normal, activation=softplus
# [CV]  output_activation=softmax, neurons_h_layer_2=32, neurons_h_layer_1=8, learn_rate=0.001, init_mode=glorot_normal, activation=softplus, total=   4.4s
# [CV] output_activation=linear, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=lecun_uniform, activation=linear
# [CV]  output_activation=linear, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=lecun_uniform, activation=linear, total=   4.3s
# [CV] output_activation=linear, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=lecun_uniform, activation=linear
# [CV]  output_activation=linear, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=lecun_uniform, activation=linear, total=   4.2s
# [CV] output_activation=linear, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=lecun_uniform, activation=linear
# [CV]  output_activation=linear, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=lecun_uniform, activation=linear, total=   4.2s
# [CV] output_activation=relu, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.005, init_mode=uniform, activation=linear
# [CV]  output_activation=relu, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.005, init_mode=uniform, activation=linear, total=   4.3s
# [CV] output_activation=relu, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.005, init_mode=uniform, activation=linear
# [CV]  output_activation=relu, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.005, init_mode=uniform, activation=linear, total=   4.2s
# [CV] output_activation=relu, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.005, init_mode=uniform, activation=linear
# [CV]  output_activation=relu, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.005, init_mode=uniform, activation=linear, total=   4.2s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=64, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=hard_sigmoid
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=64, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=hard_sigmoid, total=   4.9s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=64, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=hard_sigmoid
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=64, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=hard_sigmoid, total=   5.0s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=64, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=hard_sigmoid
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=64, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=hard_sigmoid, total=   5.0s
# [CV] output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=he_uniform, activation=hard_sigmoid
# [CV]  output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=he_uniform, activation=hard_sigmoid, total=   5.0s
# [CV] output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=he_uniform, activation=hard_sigmoid
# [CV]  output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=he_uniform, activation=hard_sigmoid, total=   4.8s
# [CV] output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=he_uniform, activation=hard_sigmoid
# [CV]  output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=64, learn_rate=0.01, init_mode=he_uniform, activation=hard_sigmoid, total=   4.8s
# [CV] output_activation=softmax, neurons_h_layer_2=64, neurons_h_layer_1=32, learn_rate=0.001, init_mode=zero, activation=hard_sigmoid
# [CV]  output_activation=softmax, neurons_h_layer_2=64, neurons_h_layer_1=32, learn_rate=0.001, init_mode=zero, activation=hard_sigmoid, total=   5.0s
# [CV] output_activation=softmax, neurons_h_layer_2=64, neurons_h_layer_1=32, learn_rate=0.001, init_mode=zero, activation=hard_sigmoid
# [CV]  output_activation=softmax, neurons_h_layer_2=64, neurons_h_layer_1=32, learn_rate=0.001, init_mode=zero, activation=hard_sigmoid, total=   4.9s
# [CV] output_activation=softmax, neurons_h_layer_2=64, neurons_h_layer_1=32, learn_rate=0.001, init_mode=zero, activation=hard_sigmoid
# [CV]  output_activation=softmax, neurons_h_layer_2=64, neurons_h_layer_1=32, learn_rate=0.001, init_mode=zero, activation=hard_sigmoid, total=   4.8s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.01, init_mode=normal, activation=hard_sigmoid
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.01, init_mode=normal, activation=hard_sigmoid, total=   4.9s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.01, init_mode=normal, activation=hard_sigmoid
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.01, init_mode=normal, activation=hard_sigmoid, total=   4.9s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.01, init_mode=normal, activation=hard_sigmoid
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.01, init_mode=normal, activation=hard_sigmoid, total=   4.9s
# [CV] output_activation=linear, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.001, init_mode=he_uniform, activation=hard_sigmoid
# [CV]  output_activation=linear, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.001, init_mode=he_uniform, activation=hard_sigmoid, total=   4.7s
# [CV] output_activation=linear, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.001, init_mode=he_uniform, activation=hard_sigmoid
# [CV]  output_activation=linear, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.001, init_mode=he_uniform, activation=hard_sigmoid, total=   4.7s
# [CV] output_activation=linear, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.001, init_mode=he_uniform, activation=hard_sigmoid
# [CV]  output_activation=linear, neurons_h_layer_2=128, neurons_h_layer_1=32, learn_rate=0.001, init_mode=he_uniform, activation=hard_sigmoid, total=   4.6s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=16, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=softmax
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=16, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=softmax, total=   5.0s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=16, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=softmax
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=16, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=softmax, total=   4.7s
# [CV] output_activation=hard_sigmoid, neurons_h_layer_2=16, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=softmax
# [CV]  output_activation=hard_sigmoid, neurons_h_layer_2=16, neurons_h_layer_1=16, learn_rate=0.1, init_mode=uniform, activation=softmax, total=   4.8s
# [CV] output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.1, init_mode=lecun_uniform, activation=tanh
# [CV]  output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.1, init_mode=lecun_uniform, activation=tanh, total=   4.2s
# [CV] output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.1, init_mode=lecun_uniform, activation=tanh
# [CV]  output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.1, init_mode=lecun_uniform, activation=tanh, total=   4.5s
# [CV] output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.1, init_mode=lecun_uniform, activation=tanh
# [CV]  output_activation=softsign, neurons_h_layer_2=32, neurons_h_layer_1=32, learn_rate=0.1, init_mode=lecun_uniform, activation=tanh, total=   4.6s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  2.3min finished

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
# for mean, stdev, param in zip(means, stds, params):
#     print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.006358 using {'output_activation': 'hard_sigmoid', 'neurons_h_layer_2': 32, 'neurons_h_layer_1': 32, 'learn_rate': 0.01, 'init_mode': 'normal', 'activation': 'hard_sigmoid'}

# %% [markdown]
# ### Optimal Parameters
#
# 1. Batch Size & Number of Epochs with Training Optimization Algorithm
# (Best Params : Batch Size: 10, Epochs = 500, Optimzation Algorithm: Adam)
# 3. Learning Rate & Momentum(if applies) of the optimal Training Optimization Algorithm (Learning Rate = 0.01)
# 4. Network Weight Initialization(glorot_normal)
# 5. Neuron Activation Function (activation=tanH, output_activation = SoftPlus)
# 6. Dropout Regularization (dropout_rate: 0.0, weight_constraint: 5)
# 7. Number of Neurons in the Hidden Layer(First Hidden layer = 8, Second Hidden layer = 32)

# %% [markdown]
# #### Grid Searched CV's model
#
# With the best parameter GridSearchCV could find based on given set of parameters grid. Now we instantiate a model and train it.

# %%
def create_model_gridsearched():
    
    model = Sequential([
        Dense(32, 
              input_dim=32, 
              activation='hard_sigmoid', 
              kernel_initializer='normal',
              kernel_constraint=MaxNorm(5),
             ),
        Dense(32, activation='hard_sigmoid'),
        Dropout(0.2),
        Dense(32, activation='hard_sigmoid'),
        Dense(1, activation='hard_sigmoid')
    ])
    optimizer = Adam(lr = 0.01)
    
    model.compile(
    loss='mse', 
    optimizer=optimizer, 
    metrics=['mse', 'mae'])
        
    return model

model_gridsearched = create_model_gridsearched()

# %%
history_model_gridsearched = model_gridsearched.fit(X_test_scaled, y_test_scaled, epochs=200, batch_size=10,  verbose=1, validation_split=0.2)
# Out:
# Epoch 1/200
# 16/16 [==============================] - 0s 6ms/step - loss: 0.0486 - mse: 0.0486 - mae: 0.1790 - val_loss: 0.0505 - val_mse: 0.0505 - val_mae: 0.1819
# Epoch 2/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0402 - mse: 0.0402 - mae: 0.1674 - val_loss: 0.0449 - val_mse: 0.0449 - val_mae: 0.1713
# Epoch 3/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0387 - mse: 0.0387 - mae: 0.1622 - val_loss: 0.0457 - val_mse: 0.0457 - val_mae: 0.1707
# Epoch 4/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0371 - mse: 0.0371 - mae: 0.1581 - val_loss: 0.0422 - val_mse: 0.0422 - val_mae: 0.1662
# Epoch 5/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0347 - mse: 0.0347 - mae: 0.1543 - val_loss: 0.0363 - val_mse: 0.0363 - val_mae: 0.1530
# Epoch 6/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0278 - mse: 0.0278 - mae: 0.1332 - val_loss: 0.0265 - val_mse: 0.0265 - val_mae: 0.1267
# Epoch 7/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0251 - mse: 0.0251 - mae: 0.1273 - val_loss: 0.0220 - val_mse: 0.0220 - val_mae: 0.1173
# Epoch 8/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0194 - mse: 0.0194 - mae: 0.1120 - val_loss: 0.0201 - val_mse: 0.0201 - val_mae: 0.1127
# Epoch 9/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0165 - mse: 0.0165 - mae: 0.1007 - val_loss: 0.0251 - val_mse: 0.0251 - val_mae: 0.1318
# Epoch 10/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0137 - mse: 0.0137 - mae: 0.0943 - val_loss: 0.0185 - val_mse: 0.0185 - val_mae: 0.1118
# Epoch 11/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0123 - mse: 0.0123 - mae: 0.0866 - val_loss: 0.0127 - val_mse: 0.0127 - val_mae: 0.0939
# Epoch 12/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0099 - mse: 0.0099 - mae: 0.0781 - val_loss: 0.0130 - val_mse: 0.0130 - val_mae: 0.0947
# Epoch 13/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0100 - mse: 0.0100 - mae: 0.0774 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0906
# Epoch 14/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0772 - val_loss: 0.0110 - val_mse: 0.0110 - val_mae: 0.0864
# Epoch 15/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0788 - val_loss: 0.0145 - val_mse: 0.0145 - val_mae: 0.0968
# Epoch 16/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0738 - val_loss: 0.0122 - val_mse: 0.0122 - val_mae: 0.0896
# Epoch 17/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0737 - val_loss: 0.0120 - val_mse: 0.0120 - val_mae: 0.0879
# Epoch 18/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0702 - val_loss: 0.0106 - val_mse: 0.0106 - val_mae: 0.0807
# Epoch 19/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0642 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0925
# Epoch 20/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0632 - val_loss: 0.0091 - val_mse: 0.0091 - val_mae: 0.0770
# Epoch 21/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0644 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0815
# Epoch 22/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0632 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0743
# Epoch 23/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0597 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0724
# Epoch 24/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0622 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0735
# Epoch 25/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0658 - val_loss: 0.0089 - val_mse: 0.0089 - val_mae: 0.0763
# Epoch 26/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0608 - val_loss: 0.0093 - val_mse: 0.0093 - val_mae: 0.0788
# Epoch 27/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0632 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0704
# Epoch 28/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0573 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0675
# Epoch 29/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0575 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0661
# Epoch 30/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0549 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0758
# Epoch 31/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0549 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0683
# Epoch 32/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0560 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0679
# Epoch 33/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0551 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0613
# Epoch 34/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0556 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0641
# Epoch 35/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0591 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0708
# Epoch 36/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0504 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0642
# Epoch 37/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0516 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0618
# Epoch 38/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0517 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0777
# Epoch 39/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0550 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0630
# Epoch 40/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0506 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0639
# Epoch 41/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0522 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0686
# Epoch 42/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0544 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0647
# Epoch 43/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0545 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0599
# Epoch 44/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0485 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0630
# Epoch 45/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0496 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0595
# Epoch 46/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0476 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0625
# Epoch 47/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0482 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0585
# Epoch 48/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0508 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0605
# Epoch 49/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0459 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0693
# Epoch 50/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0437 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0608
# Epoch 51/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0402 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0604
# Epoch 52/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0432 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0580
# Epoch 53/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0417 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0627
# Epoch 54/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0457 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0595
# Epoch 55/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0430 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0602
# Epoch 56/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0410 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0620
# Epoch 57/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0449 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0674
# Epoch 58/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0472 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0569
# Epoch 59/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0407 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0616
# Epoch 60/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0436 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0624
# Epoch 61/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0375 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0628
# Epoch 62/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0472 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0656
# Epoch 63/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0402 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0669
# Epoch 64/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0467 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0650
# Epoch 65/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0415 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0595
# Epoch 66/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0404 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0592
# Epoch 67/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0367 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0650
# Epoch 68/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0362 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0672
# Epoch 69/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0438 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0636
# Epoch 70/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0400 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0608
# Epoch 71/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0352 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0576
# Epoch 72/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0340 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0580
# Epoch 73/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0366 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0575
# Epoch 74/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0432 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0658
# Epoch 75/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0384 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0653
# Epoch 76/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0431 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0588
# Epoch 77/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0431 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0633
# Epoch 78/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0376 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0605
# Epoch 79/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0349 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0616
# Epoch 80/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0395 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0585
# Epoch 81/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0391 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0608
# Epoch 82/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0386 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0642
# Epoch 83/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0449 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0591
# Epoch 84/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0364 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0631
# Epoch 85/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0327 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0585
# Epoch 86/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0325 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0637
# Epoch 87/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0319 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0577
# Epoch 88/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0319 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0611
# Epoch 89/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0305 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0603
# Epoch 90/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0324 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0566
# Epoch 91/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0317 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0622
# Epoch 92/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0341 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0616
# Epoch 93/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0310 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0562
# Epoch 94/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0293 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0575
# Epoch 95/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0323 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0597
# Epoch 96/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0311 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0610
# Epoch 97/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0304 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0599
# Epoch 98/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0307 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0581
# Epoch 99/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0334 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0597
# Epoch 100/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0308 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0705
# Epoch 101/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0305 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0628
# Epoch 102/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0320 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0684
# Epoch 103/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0339 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0592
# Epoch 104/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0334 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0706
# Epoch 105/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0351 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0595
# Epoch 106/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0304 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0608
# Epoch 107/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0317 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0606
# Epoch 108/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0302 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0580
# Epoch 109/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0024 - mse: 0.0024 - mae: 0.0386 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0660
# Epoch 110/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0323 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0629
# Epoch 111/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0332 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0681
# Epoch 112/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0327 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0588
# Epoch 113/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0321 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0624
# Epoch 114/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0302 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0587
# Epoch 115/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0355 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0588
# Epoch 116/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0354 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0555
# Epoch 117/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0326 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0600
# Epoch 118/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0283 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0590
# Epoch 119/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0306 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0637
# Epoch 120/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0344 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0621
# Epoch 121/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0283 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0626
# Epoch 122/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0282 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0649
# Epoch 123/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0320 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0616
# Epoch 124/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0258 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0579
# Epoch 125/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0287 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0664
# Epoch 126/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0286 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0579
# Epoch 127/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0307 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0602
# Epoch 128/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0286 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0614
# Epoch 129/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0019 - mse: 0.0019 - mae: 0.0355 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0628
# Epoch 130/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0295 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0588
# Epoch 131/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0279 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0613
# Epoch 132/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0259 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0595
# Epoch 133/200
# 16/16 [==============================] - 0s 2ms/step - loss: 7.7372e-04 - mse: 7.7372e-04 - mae: 0.0222 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0579
# Epoch 134/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0239 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0572
# Epoch 135/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0263 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0631
# Epoch 136/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0263 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0602
# Epoch 137/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0303 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0589
# Epoch 138/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0285 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0628
# Epoch 139/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0260 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0643
# Epoch 140/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0284 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0687
# Epoch 141/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0367 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0630
# Epoch 142/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0332 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0678
# Epoch 143/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0304 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0597
# Epoch 144/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0281 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0613
# Epoch 145/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0256 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0589
# Epoch 146/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0250 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0584
# Epoch 147/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0249 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0625
# Epoch 148/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.7856e-04 - mse: 9.7856e-04 - mae: 0.0242 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0620
# Epoch 149/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0294 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0673
# Epoch 150/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0334 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0596
# Epoch 151/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0408 - val_loss: 0.0097 - val_mse: 0.0097 - val_mae: 0.0819
# Epoch 152/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0357 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0599
# Epoch 153/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0284 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0620
# Epoch 154/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.3162e-04 - mse: 9.3162e-04 - mae: 0.0235 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0591
# Epoch 155/200
# 16/16 [==============================] - 0s 3ms/step - loss: 9.9605e-04 - mse: 9.9605e-04 - mae: 0.0249 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0680
# Epoch 156/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.0521e-04 - mse: 9.0521e-04 - mae: 0.0240 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0594
# Epoch 157/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0260 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0675
# Epoch 158/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0272 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0600
# Epoch 159/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0246 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 160/200
# 16/16 [==============================] - 0s 3ms/step - loss: 8.5246e-04 - mse: 8.5246e-04 - mae: 0.0233 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0630
# Epoch 161/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.8625e-04 - mse: 9.8625e-04 - mae: 0.0250 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0607
# Epoch 162/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.5751e-04 - mse: 9.5751e-04 - mae: 0.0250 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0698
# Epoch 163/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0299 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0588
# Epoch 164/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0269 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0645
# Epoch 165/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0294 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0634
# Epoch 166/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0269 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0645
# Epoch 167/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.1805e-04 - mse: 9.1805e-04 - mae: 0.0229 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0701
# Epoch 168/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0270 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0623
# Epoch 169/200
# 16/16 [==============================] - 0s 2ms/step - loss: 7.7193e-04 - mse: 7.7193e-04 - mae: 0.0217 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0636
# Epoch 170/200
# 16/16 [==============================] - 0s 2ms/step - loss: 7.5069e-04 - mse: 7.5069e-04 - mae: 0.0217 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0667
# Epoch 171/200
# 16/16 [==============================] - 0s 2ms/step - loss: 8.8704e-04 - mse: 8.8704e-04 - mae: 0.0234 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0685
# Epoch 172/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0257 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0622
# Epoch 173/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0258 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0763
# Epoch 174/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0334 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0588
# Epoch 175/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.0131e-04 - mse: 9.0131e-04 - mae: 0.0235 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0619
# Epoch 176/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.9221e-04 - mse: 9.9221e-04 - mae: 0.0252 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0635
# Epoch 177/200
# 16/16 [==============================] - 0s 3ms/step - loss: 9.2291e-04 - mse: 9.2291e-04 - mae: 0.0241 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0593
# Epoch 178/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0255 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0615
# Epoch 179/200
# 16/16 [==============================] - 0s 2ms/step - loss: 8.8583e-04 - mse: 8.8583e-04 - mae: 0.0238 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0628
# Epoch 180/200
# 16/16 [==============================] - 0s 3ms/step - loss: 9.6571e-04 - mse: 9.6571e-04 - mae: 0.0233 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0621
# Epoch 181/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.1743e-04 - mse: 9.1743e-04 - mae: 0.0232 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0636
# Epoch 182/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0251 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0670
# Epoch 183/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0277 - val_loss: 0.0056 - val_mse: 0.0056 - val_mae: 0.0610
# Epoch 184/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0265 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0635
# Epoch 185/200
# 16/16 [==============================] - 0s 2ms/step - loss: 6.9274e-04 - mse: 6.9274e-04 - mae: 0.0210 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0638
# Epoch 186/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.4875e-04 - mse: 9.4875e-04 - mae: 0.0231 - val_loss: 0.0053 - val_mse: 0.0053 - val_mae: 0.0612
# Epoch 187/200
# 16/16 [==============================] - 0s 3ms/step - loss: 7.2034e-04 - mse: 7.2034e-04 - mae: 0.0214 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0631
# Epoch 188/200
# 16/16 [==============================] - 0s 2ms/step - loss: 8.5340e-04 - mse: 8.5340e-04 - mae: 0.0232 - val_loss: 0.0057 - val_mse: 0.0057 - val_mae: 0.0635
# Epoch 189/200
# 16/16 [==============================] - 0s 3ms/step - loss: 8.3744e-04 - mse: 8.3744e-04 - mae: 0.0222 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0633
# Epoch 190/200
# 16/16 [==============================] - 0s 2ms/step - loss: 7.4747e-04 - mse: 7.4747e-04 - mae: 0.0200 - val_loss: 0.0055 - val_mse: 0.0055 - val_mae: 0.0614
# Epoch 191/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0258 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0618
# Epoch 192/200
# 16/16 [==============================] - 0s 2ms/step - loss: 6.2320e-04 - mse: 6.2320e-04 - mae: 0.0194 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0637
# Epoch 193/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.1652e-04 - mse: 9.1652e-04 - mae: 0.0225 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0604
# Epoch 194/200
# 16/16 [==============================] - 0s 3ms/step - loss: 8.6784e-04 - mse: 8.6784e-04 - mae: 0.0214 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0561
# Epoch 195/200
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0250 - val_loss: 0.0063 - val_mse: 0.0063 - val_mae: 0.0671
# Epoch 196/200
# 16/16 [==============================] - 0s 3ms/step - loss: 9.3573e-04 - mse: 9.3573e-04 - mae: 0.0255 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0615
# Epoch 197/200
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0253 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0669
# Epoch 198/200
# 16/16 [==============================] - 0s 2ms/step - loss: 8.6326e-04 - mse: 8.6326e-04 - mae: 0.0235 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0616
# Epoch 199/200
# 16/16 [==============================] - 0s 2ms/step - loss: 9.8376e-04 - mse: 9.8376e-04 - mae: 0.0246 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0638
# Epoch 200/200
# 16/16 [==============================] - 0s 2ms/step - loss: 6.1637e-04 - mse: 6.1637e-04 - mae: 0.0198 - val_loss: 0.0062 - val_mse: 0.0062 - val_mae: 0.0658

# %%
# print(history.history.keys())
plt.plot(history_model_gridsearched.history['loss'])
plt.plot(history_model_gridsearched.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
loss, mean_sq_e, mean_abs_e = model_gridsearched.evaluate(X_test_scaled, y_test_scaled)
print("Mean Squared Error : {:.5f}".format(mean_sq_e))
print("Mean Absolute Error : {:.5f}".format(mean_abs_e))
# Out:
# 6/6 [==============================] - 0s 1ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0274
# Mean Squared Error : 0.00163
# Mean Absolute Error : 0.02736

# %% [markdown]
# ## Inference

# %%
df2 = features.iloc[2] # Test with the 14th Student 
Xnew = np.array([df2])
Xnew.reshape(-1, 1)

Xnew= scaler.transform(Xnew)
ynew= model_gridsearched.predict(Xnew)

# #invert normalize
ynew = scaler.inverse_transform(ynew) 
Xnew = scaler.inverse_transform(Xnew)

#print("X=%s, Predicted=%s" % (Xnew[0], ynew[0]))
print("Predicted G3's score is {:.2f}".format(float(ynew)))
# Out:
# Predicted G3's score is 14.42

# %%
predictions = model_gridsearched.predict(X_test_scaled)
predictions = scaler.inverse_transform(predictions)
predictions = np.round(predictions, 2)

# %%
diff_list = []

for i in range(0,len(y_test)):
    
    g_truth = float(y_test_np[i])
    p = float(predictions[i])
    diff = np.abs(p-g_truth)
    diff_list.append(diff)
    print(i)  
    print("Real Values :", g_truth)
    print("Predicted G3's score is {:.2f}".format(p))
    print("Difference : {:.3f}".format(diff))
# Out:
# 0
# Real Values : 14.0
# Predicted G3's score is 14.38
# Difference : 0.380
# 1
# Real Values : 12.0
# Predicted G3's score is 12.30
# Difference : 0.300
# 2
# Real Values : 10.0
# Predicted G3's score is 10.17
# Difference : 0.170
# 3
# Real Values : 19.0
# Predicted G3's score is 18.31
# Difference : 0.690
# 4
# Real Values : 13.0
# Predicted G3's score is 12.86
# Difference : 0.140
# 5
# Real Values : 15.0
# Predicted G3's score is 15.00
# Difference : 0.000
# 6
# Real Values : 10.0
# Predicted G3's score is 10.36
# Difference : 0.360
# 7
# Real Values : 11.0
# Predicted G3's score is 11.28
# Difference : 0.280
# 8
# Real Values : 11.0
# Predicted G3's score is 11.20
# Difference : 0.200
# 9
# Real Values : 11.0
# Predicted G3's score is 11.06
# Difference : 0.060
# 10
# Real Values : 15.0
# Predicted G3's score is 14.82
# Difference : 0.180
# 11
# Real Values : 16.0
# Predicted G3's score is 15.88
# Difference : 0.120
# 12
# Real Values : 10.0
# Predicted G3's score is 10.23
# Difference : 0.230
# 13
# Real Values : 11.0
# Predicted G3's score is 10.81
# Difference : 0.190
# 14
# Real Values : 16.0
# Predicted G3's score is 15.69
# Difference : 0.310
# 15
# Real Values : 6.0
# Predicted G3's score is 6.17
# Difference : 0.170
# 16
# Real Values : 10.0
# Predicted G3's score is 10.29
# Difference : 0.290
# 17
# Real Values : 13.0
# Predicted G3's score is 12.95
# Difference : 0.050
# 18
# Real Values : 14.0
# Predicted G3's score is 13.99
# Difference : 0.010
# 19
# Real Values : 12.0
# Predicted G3's score is 12.28
# Difference : 0.280
# 20
# Real Values : 9.0
# Predicted G3's score is 9.42
# Difference : 0.420
# 21
# Real Values : 11.0
# Predicted G3's score is 11.09
# Difference : 0.090
# 22
# Real Values : 10.0
# Predicted G3's score is 10.14
# Difference : 0.140
# 23
# Real Values : 17.0
# Predicted G3's score is 16.46
# Difference : 0.540
# 24
# Real Values : 9.0
# Predicted G3's score is 9.60
# Difference : 0.600
# 25
# Real Values : 14.0
# Predicted G3's score is 14.16
# Difference : 0.160
# 26
# Real Values : 11.0
# Predicted G3's score is 11.04
# Difference : 0.040
# 27
# Real Values : 13.0
# Predicted G3's score is 13.10
# Difference : 0.100
# 28
# Real Values : 13.0
# Predicted G3's score is 12.81
# Difference : 0.190
# 29
# Real Values : 10.0
# Predicted G3's score is 10.32
# Difference : 0.320
# 30
# Real Values : 8.0
# Predicted G3's score is 8.34
# Difference : 0.340
# 31
# Real Values : 16.0
# Predicted G3's score is 15.68
# Difference : 0.320
# 32
# Real Values : 8.0
# Predicted G3's score is 8.62
# Difference : 0.620
# 33
# Real Values : 15.0
# Predicted G3's score is 14.41
# Difference : 0.590
# 34
# Real Values : 10.0
# Predicted G3's score is 10.10
# Difference : 0.100
# 35
# Real Values : 14.0
# Predicted G3's score is 13.90
# Difference : 0.100
# 36
# Real Values : 14.0
# Predicted G3's score is 14.28
# Difference : 0.280
# 37
# Real Values : 11.0
# Predicted G3's score is 11.14
# Difference : 0.140
# 38
# Real Values : 10.0
# Predicted G3's score is 10.14
# Difference : 0.140
# 39
# Real Values : 13.0
# Predicted G3's score is 13.01
# Difference : 0.010
# 40
# Real Values : 13.0
# Predicted G3's score is 13.19
# Difference : 0.190
# 41
# Real Values : 17.0
# Predicted G3's score is 16.57
# Difference : 0.430
# 42
# Real Values : 12.0
# Predicted G3's score is 12.18
# Difference : 0.180
# 43
# Real Values : 14.0
# Predicted G3's score is 14.17
# Difference : 0.170
# 44
# Real Values : 10.0
# Predicted G3's score is 10.28
# Difference : 0.280
# 45
# Real Values : 12.0
# Predicted G3's score is 12.17
# Difference : 0.170
# 46
# Real Values : 14.0
# Predicted G3's score is 13.98
# Difference : 0.020
# 47
# Real Values : 13.0
# Predicted G3's score is 12.94
# Difference : 0.060
# 48
# Real Values : 10.0
# Predicted G3's score is 10.05
# Difference : 0.050
# 49
# Real Values : 13.0
# Predicted G3's score is 13.17
# Difference : 0.170
# 50
# Real Values : 17.0
# Predicted G3's score is 16.58
# Difference : 0.420
# 51
# Real Values : 10.0
# Predicted G3's score is 10.12
# Difference : 0.120
# 52
# Real Values : 11.0
# Predicted G3's score is 11.20
# Difference : 0.200
# 53
# Real Values : 11.0
# Predicted G3's score is 11.04
# Difference : 0.040
# 54
# Real Values : 8.0
# Predicted G3's score is 8.60
# Difference : 0.600
# 55
# Real Values : 10.0
# Predicted G3's score is 10.17
# Difference : 0.170
# 56
# Real Values : 17.0
# Predicted G3's score is 16.72
# Difference : 0.280
# 57
# Real Values : 12.0
# Predicted G3's score is 11.91
# Difference : 0.090
# 58
# Real Values : 12.0
# Predicted G3's score is 12.08
# Difference : 0.080
# 59
# Real Values : 11.0
# Predicted G3's score is 11.18
# Difference : 0.180
# 60
# Real Values : 15.0
# Predicted G3's score is 15.06
# Difference : 0.060
# 61
# Real Values : 10.0
# Predicted G3's score is 9.97
# Difference : 0.030
# 62
# Real Values : 10.0
# Predicted G3's score is 10.24
# Difference : 0.240
# 63
# Real Values : 11.0
# Predicted G3's score is 11.23
# Difference : 0.230
# 64
# Real Values : 12.0
# Predicted G3's score is 12.24
# Difference : 0.240
# 65
# Real Values : 14.0
# Predicted G3's score is 14.30
# Difference : 0.300
# 66
# Real Values : 12.0
# Predicted G3's score is 12.05
# Difference : 0.050
# 67
# Real Values : 10.0
# Predicted G3's score is 10.15
# Difference : 0.150
# 68
# Real Values : 13.0
# Predicted G3's score is 13.13
# Difference : 0.130
# 69
# Real Values : 10.0
# Predicted G3's score is 10.32
# Difference : 0.320
# 70
# Real Values : 12.0
# Predicted G3's score is 12.27
# Difference : 0.270
# 71
# Real Values : 14.0
# Predicted G3's score is 14.04
# Difference : 0.040
# 72
# Real Values : 11.0
# Predicted G3's score is 10.93
# Difference : 0.070
# 73
# Real Values : 11.0
# Predicted G3's score is 11.09
# Difference : 0.090
# 74
# Real Values : 16.0
# Predicted G3's score is 15.69
# Difference : 0.310
# 75
# Real Values : 18.0
# Predicted G3's score is 17.75
# Difference : 0.250
# 76
# Real Values : 11.0
# Predicted G3's score is 10.95
# Difference : 0.050
# 77
# Real Values : 16.0
# Predicted G3's score is 15.87
# Difference : 0.130
# 78
# Real Values : 16.0
# Predicted G3's score is 15.65
# Difference : 0.350
# 79
# Real Values : 13.0
# Predicted G3's score is 13.26
# Difference : 0.260
# 80
# Real Values : 13.0
# Predicted G3's score is 13.43
# Difference : 0.430
# 81
# Real Values : 18.0
# Predicted G3's score is 17.38
# Difference : 0.620
# 82
# Real Values : 12.0
# Predicted G3's score is 12.07
# Difference : 0.070
# 83
# Real Values : 16.0
# Predicted G3's score is 16.01
# Difference : 0.010
# 84
# Real Values : 14.0
# Predicted G3's score is 14.03
# Difference : 0.030
# 85
# Real Values : 9.0
# Predicted G3's score is 9.36
# Difference : 0.360
# 86
# Real Values : 18.0
# Predicted G3's score is 17.68
# Difference : 0.320
# 87
# Real Values : 13.0
# Predicted G3's score is 12.92
# Difference : 0.080
# 88
# Real Values : 10.0
# Predicted G3's score is 10.39
# Difference : 0.390
# 89
# Real Values : 13.0
# Predicted G3's score is 12.95
# Difference : 0.050
# 90
# Real Values : 10.0
# Predicted G3's score is 10.22
# Difference : 0.220
# 91
# Real Values : 8.0
# Predicted G3's score is 8.37
# Difference : 0.370
# 92
# Real Values : 16.0
# Predicted G3's score is 15.85
# Difference : 0.150
# 93
# Real Values : 12.0
# Predicted G3's score is 12.17
# Difference : 0.170
# 94
# Real Values : 12.0
# Predicted G3's score is 12.35
# Difference : 0.350
# 95
# Real Values : 11.0
# Predicted G3's score is 11.21
# Difference : 0.210
# 96
# Real Values : 16.0
# Predicted G3's score is 15.57
# Difference : 0.430
# 97
# Real Values : 9.0
# Predicted G3's score is 9.63
# Difference : 0.630
# 98
# Real Values : 17.0
# Predicted G3's score is 16.48
# Difference : 0.520
# 99
# Real Values : 14.0
# Predicted G3's score is 13.82
# Difference : 0.180
# 100
# Real Values : 8.0
# Predicted G3's score is 8.91
# Difference : 0.910
# 101
# Real Values : 11.0
# Predicted G3's score is 11.14
# Difference : 0.140
# 102
# Real Values : 11.0
# Predicted G3's score is 11.32
# Difference : 0.320
# 103
# Real Values : 15.0
# Predicted G3's score is 14.97
# Difference : 0.030
# 104
# Real Values : 13.0
# Predicted G3's score is 13.13
# Difference : 0.130
# 105
# Real Values : 9.0
# Predicted G3's score is 9.28
# Difference : 0.280
# 106
# Real Values : 13.0
# Predicted G3's score is 13.10
# Difference : 0.100
# 107
# Real Values : 9.0
# Predicted G3's score is 9.74
# Difference : 0.740
# 108
# Real Values : 13.0
# Predicted G3's score is 12.89
# Difference : 0.110
# 109
# Real Values : 11.0
# Predicted G3's score is 11.08
# Difference : 0.080
# 110
# Real Values : 15.0
# Predicted G3's score is 14.67
# Difference : 0.330
# 111
# Real Values : 10.0
# Predicted G3's score is 10.48
# Difference : 0.480
# 112
# Real Values : 12.0
# Predicted G3's score is 11.88
# Difference : 0.120
# 113
# Real Values : 13.0
# Predicted G3's score is 12.94
# Difference : 0.060
# 114
# Real Values : 16.0
# Predicted G3's score is 15.82
# Difference : 0.180
# 115
# Real Values : 9.0
# Predicted G3's score is 9.49
# Difference : 0.490
# 116
# Real Values : 9.0
# Predicted G3's score is 9.46
# Difference : 0.460
# 117
# Real Values : 12.0
# Predicted G3's score is 12.10
# Difference : 0.100
# 118
# Real Values : 15.0
# Predicted G3's score is 14.98
# Difference : 0.020
# 119
# Real Values : 10.0
# Predicted G3's score is 10.40
# Difference : 0.400
# 120
# Real Values : 10.0
# Predicted G3's score is 10.48
# Difference : 0.480
# 121
# Real Values : 13.0
# Predicted G3's score is 12.82
# Difference : 0.180
# 122
# Real Values : 17.0
# Predicted G3's score is 16.49
# Difference : 0.510
# 123
# Real Values : 15.0
# Predicted G3's score is 14.62
# Difference : 0.380
# 124
# Real Values : 9.0
# Predicted G3's score is 9.47
# Difference : 0.470
# 125
# Real Values : 11.0
# Predicted G3's score is 11.16
# Difference : 0.160
# 126
# Real Values : 13.0
# Predicted G3's score is 12.99
# Difference : 0.010
# 127
# Real Values : 10.0
# Predicted G3's score is 9.95
# Difference : 0.050
# 128
# Real Values : 13.0
# Predicted G3's score is 13.20
# Difference : 0.200
# 129
# Real Values : 11.0
# Predicted G3's score is 11.10
# Difference : 0.100
# 130
# Real Values : 14.0
# Predicted G3's score is 13.81
# Difference : 0.190
# 131
# Real Values : 13.0
# Predicted G3's score is 12.96
# Difference : 0.040
# 132
# Real Values : 11.0
# Predicted G3's score is 11.08
# Difference : 0.080
# 133
# Real Values : 15.0
# Predicted G3's score is 14.88
# Difference : 0.120
# 134
# Real Values : 11.0
# Predicted G3's score is 10.87
# Difference : 0.130
# 135
# Real Values : 16.0
# Predicted G3's score is 15.72
# Difference : 0.280
# 136
# Real Values : 12.0
# Predicted G3's score is 12.50
# Difference : 0.500
# 137
# Real Values : 11.0
# Predicted G3's score is 11.26
# Difference : 0.260
# 138
# Real Values : 14.0
# Predicted G3's score is 14.14
# Difference : 0.140
# 139
# Real Values : 10.0
# Predicted G3's score is 10.23
# Difference : 0.230
# 140
# Real Values : 15.0
# Predicted G3's score is 15.05
# Difference : 0.050
# 141
# Real Values : 10.0
# Predicted G3's score is 10.28
# Difference : 0.280
# 142
# Real Values : 13.0
# Predicted G3's score is 13.11
# Difference : 0.110
# 143
# Real Values : 11.0
# Predicted G3's score is 11.20
# Difference : 0.200
# 144
# Real Values : 17.0
# Predicted G3's score is 16.47
# Difference : 0.530
# 145
# Real Values : 11.0
# Predicted G3's score is 10.90
# Difference : 0.100
# 146
# Real Values : 14.0
# Predicted G3's score is 14.10
# Difference : 0.100
# 147
# Real Values : 11.0
# Predicted G3's score is 11.19
# Difference : 0.190
# 148
# Real Values : 12.0
# Predicted G3's score is 12.17
# Difference : 0.170
# 149
# Real Values : 15.0
# Predicted G3's score is 14.76
# Difference : 0.240
# 150
# Real Values : 13.0
# Predicted G3's score is 13.19
# Difference : 0.190
# 151
# Real Values : 14.0
# Predicted G3's score is 14.18
# Difference : 0.180
# 152
# Real Values : 14.0
# Predicted G3's score is 13.07
# Difference : 0.930
# 153
# Real Values : 7.0
# Predicted G3's score is 7.84
# Difference : 0.840
# 154
# Real Values : 18.0
# Predicted G3's score is 16.53
# Difference : 1.470
# 155
# Real Values : 6.0
# Predicted G3's score is 7.35
# Difference : 1.350
# 156
# Real Values : 14.0
# Predicted G3's score is 13.01
# Difference : 0.990
# 157
# Real Values : 16.0
# Predicted G3's score is 16.25
# Difference : 0.250
# 158
# Real Values : 13.0
# Predicted G3's score is 12.22
# Difference : 0.780
# 159
# Real Values : 14.0
# Predicted G3's score is 14.93
# Difference : 0.930
# 160
# Real Values : 13.0
# Predicted G3's score is 12.58
# Difference : 0.420
# 161
# Real Values : 18.0
# Predicted G3's score is 15.86
# Difference : 2.140
# 162
# Real Values : 16.0
# Predicted G3's score is 15.44
# Difference : 0.560
# 163
# Real Values : 15.0
# Predicted G3's score is 15.40
# Difference : 0.400
# 164
# Real Values : 11.0
# Predicted G3's score is 9.62
# Difference : 1.380
# 165
# Real Values : 9.0
# Predicted G3's score is 9.21
# Difference : 0.210
# 166
# Real Values : 11.0
# Predicted G3's score is 11.03
# Difference : 0.030
# 167
# Real Values : 15.0
# Predicted G3's score is 15.23
# Difference : 0.230
# 168
# Real Values : 13.0
# Predicted G3's score is 13.75
# Difference : 0.750
# 169
# Real Values : 16.0
# Predicted G3's score is 15.03
# Difference : 0.970
# 170
# Real Values : 8.0
# Predicted G3's score is 9.24
# Difference : 1.240
# 171
# Real Values : 12.0
# Predicted G3's score is 11.51
# Difference : 0.490
# 172
# Real Values : 13.0
# Predicted G3's score is 12.79
# Difference : 0.210
# 173
# Real Values : 11.0
# Predicted G3's score is 12.09
# Difference : 1.090
# 174
# Real Values : 12.0
# Predicted G3's score is 13.28
# Difference : 1.280
# 175
# Real Values : 9.0
# Predicted G3's score is 10.52
# Difference : 1.520
# 176
# Real Values : 15.0
# Predicted G3's score is 15.02
# Difference : 0.020
# 177
# Real Values : 12.0
# Predicted G3's score is 12.98
# Difference : 0.980
# 178
# Real Values : 15.0
# Predicted G3's score is 15.58
# Difference : 0.580
# 179
# Real Values : 14.0
# Predicted G3's score is 13.87
# Difference : 0.130
# 180
# Real Values : 12.0
# Predicted G3's score is 12.73
# Difference : 0.730
# 181
# Real Values : 10.0
# Predicted G3's score is 11.03
# Difference : 1.030
# 182
# Real Values : 10.0
# Predicted G3's score is 11.00
# Difference : 1.000
# 183
# Real Values : 13.0
# Predicted G3's score is 15.23
# Difference : 2.230
# 184
# Real Values : 12.0
# Predicted G3's score is 10.92
# Difference : 1.080
# 185
# Real Values : 11.0
# Predicted G3's score is 11.85
# Difference : 0.850
# 186
# Real Values : 11.0
# Predicted G3's score is 10.13
# Difference : 0.870
# 187
# Real Values : 9.0
# Predicted G3's score is 11.04
# Difference : 2.040
# 188
# Real Values : 11.0
# Predicted G3's score is 10.76
# Difference : 0.240
# 189
# Real Values : 14.0
# Predicted G3's score is 14.22
# Difference : 0.220

# %% [markdown]
# ### Mean Absolute Error after applying genetic algorithm

# %%
mean_abs_e_on_test_set = sum(diff_list) / len(y_test)
# mean_abs_e_on_test_set = mean_absolute_error(y_test_np, predictions)
print("Mean Absolute Error : {:.5f}".format(mean_abs_e_on_test_set))
# Out:
# Mean Absolute Error : 0.35526
