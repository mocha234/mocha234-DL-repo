# %% [markdown]
# # StudentPerformance_PyGAD
# This is a duplicate notebook from StudentPerformance_with_Keras_and_PyGAD. In this notebook I will use a Genetic Algorithm Library, namely PyGAD to find optimal weights instead of doing it with Grid Search Corss Validation and empirically in the previous notebooks.
#
# A deep learning model consists of trained/learned weights where the weights can be train by foward and back propagation. However, we need to tune the hyperparameters such as the learning rate.
#
# With Genetic Algorithm, we can train the weights of the Neural Networks easily.
# By analogy, the model with weight considered as Chromosome/Solution/Individual in a Population(consist of n number of solutions). The goal is to obtain the fittest Chromosome in the population. To achieve thta, the fittest Chromosomes(highest Fitness value) are the Parents will have its offspring knowns as Children throughout Generations with some mutation to it. Since the fittest chromosomes will be chosen to be mated, hence the offspring will be better and better throughout the generations.
#
# These Offsprings, by end of the day, are the "Best Solution" or the "Best Weights" found and used for making predictions.

# %% [markdown]
# ### Other Notebooks(in this learnign "series"):
# 1. [Genetic Algorithm with Python](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/GA_with_Python.ipynb) --> Understanding Genetic Algorithm with Python(without libraries)
# 2. [Predicting Student Performance(Empirically)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_with_NN.ipynb) --> Empirically tune hyper-parameters
# 3. [Predicting Student Performance(SKLearn's GridSearchCV)](ww) --> Tune hyper-parameters with Sci-Kit Learn's GridSearchCV
# ***This Notebook*** 4. [Predicting Student Performance(Genetic Algorithm with PyGAD)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_PyGAD.ipynb) --> Tune hyper-parameters with GA using PyGAD
#
# 5. [Predicting Student Performance(Genetic Algorithm with Trained Model + PyGAD)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_Tensorflow_PyGAD.ipynb) --> Tune GA hyper-parameters using PyGAD of a trained Model
# 6. [Some Findings, Comparison, Summary](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/GA_summary.ipynb) --> Summary of this learning "series"

# %% [markdown]
# ### Index
#
# 1. Dataset
# 2. Packages Needed
# 3. Data Preprocessing
# 4. Building Deep Learning Model with Tensorflow/Keras
# 5. Applying Genetic Algorithm
# 6. Inference

# %% [markdown]
# ## 1. Dataset
#
# Source: https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# ### Description
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires.
#
# Two datasets are provided regarding the performance in two distinct subjects: Mathematics (mat) and Portuguese language (por).
#
# ### Note: In this notebook, I used the Dataset with Portuguese Language
#
# In [Cortez and Silva, 2008], the two datasets were modeled under binary/five-level classification and regression tasks.
#
# Important note: the target attribute G3 has a strong correlation with attributes G2 and G1.
#
# This occurs because G3 is the final year grade (issued at the 3rd period), while G1 and G2 correspond to the 1st and 2nd-period grades. It is more difficult to predict G3 without G2 and G1, but such prediction is much more useful (see paper source for more details).

# %% [markdown]
# ### Attribute Information:
#
# ### Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
# * 1 school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)*
# * 2 sex - student's sex (binary: 'F' - female or 'M' - male)
# * 3 age - student's age (numeric: from 15 to 22)
# * 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * 7 Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# * 8 Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# * 9 Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * 10 Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# * 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# * 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * 16 schoolsup - extra educational support (binary: yes or no)
# * 17 famsup - family educational support (binary: yes or no)
# * 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * 19 activities - extra-curricular activities (binary: yes or no)
# * 20 nursery - attended nursery school (binary: yes or no)
# * 21 higher - wants to take higher education (binary: yes or no)
# * 22 internet - Internet access at home (binary: yes or no)
# * 23 romantic - with a romantic relationship (binary: yes or no)
# * 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
# * 30 absences - number of school absences (numeric: from 0 to 93)
#
# #### these grades are related with the course subject, Math or Portuguese:
# * 31 G1 - first period grade (numeric: from 0 to 20)
# * 31 G2 - second period grade (numeric: from 0 to 20)
# * 32 G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## 2. Packages Needed

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.constraints import MaxNorm
from tensorflow import convert_to_tensor

from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# ### 3. Data Preprocessing
#
# Here, I will find for empty data, encode categorical data, plot some graph to understand the data.

# %%
df = pd.read_csv("student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         4   0  11  11
# 1       1     1       3         2   9  11  11
# 2       2     3       3         6  12  13  12
# 3       1     1       5         0  14  14  14
# 4       1     2       5         0  11  13  13
# ..    ...   ...     ...       ...  ..  ..  ..
# 644     1     2       5         4  10  11  10
# 645     1     1       1         4  15  15  16
# 646     1     1       5         6  11  12   9
# 647     3     4       2         6  10  10  10
# 648     3     4       5         4  10  11  11
#
# [649 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
# df.dtypes

# %%
# df.isnull().sum() 
# Check for missing data

# %%
features_list = list(df.columns)[:-1]
print("Features: {x}".format(x = features_list))
print("\nNumber of Features: {x}".format(x = len(features_list)))
# Out:
# Features: ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']
#
# Number of Features: 32

# %%
# df.info()
# # Check datatype of features

# %%
features = df.drop(["G3"], axis = 1)
features
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2
# 0       1     1       3         4   0  11
# 1       1     1       3         2   9  11
# 2       2     3       3         6  12  13
# 3       1     1       5         0  14  14
# 4       1     2       5         0  11  13
# ..    ...   ...     ...       ...  ..  ..
# 644     1     2       5         4  10  11
# 645     1     1       1         4  15  15
# 646     1     1       5         6  11  12
# 647     3     4       2         6  10  10
# 648     3     4       5         4  10  11
#
# [649 rows x 32 columns]

# %%
target = df.drop(features_list, axis = 1)
target
# Out:
#      G3
# 0    11
# 1    11
# 2    12
# 3    14
# 4    13
# ..   ..
# 644  10
# 645  16
# 646   9
# 647  10
# 648  11
#
# [649 rows x 1 columns]

# %%
mapping_school = {'GP' : 0, 'MS' : 1}
mapping_sex = {'F' : 0, 'M' : 1}
mapping_address = {'U' : 0, 'R' : 1}
mapping_famsize = {'GT3' : 0, 'LE3' : 1}
mapping_pstatus = {'A' : 0, 'T' : 1}
mapping_mjob = {'at_home' : 0, 'health' : 1, 'other' : 2, 'services' : 3, 'teacher' : 4}
mapping_fjob = {'at_home' : 0, 'health' : 1, 'other' : 2, 'services' : 3, 'teacher' : 4}
mapping_reason = {'course' : 0, 'other' : 1, 'home' : 2, 'reputation' : 3}
mapping_guardian = {'mother' : 0, 'father' : 1, 'other': 2}
mapping_schoolsup = {'no' : 0, 'yes' : 1}
mapping_famsup = {'no' : 0, 'yes' : 1}
mapping_romantic = {'no' : 0, 'yes' : 1}
mapping_paid = {'no' : 0, 'yes' : 1}
mapping_activities = {'no' : 0, 'yes' : 1}
mapping_nursery = {'no' : 0, 'yes' : 1}
mapping_higher = {'no' : 0, 'yes' : 1}
mapping_internet = {'no' : 0, 'yes' : 1}

# %%
df['school'] = features['school'].map(mapping_school)
df['sex'] = features['sex'].map(mapping_sex)
df['address'] = features['address'].map(mapping_address)
df['famsize'] = features['famsize'].map(mapping_famsize)
df['Pstatus'] = features['Pstatus'].map(mapping_pstatus)
df['Mjob'] = features['Mjob'].map(mapping_mjob)
df['Fjob'] = features['Fjob'].map(mapping_fjob)
df['reason'] = features['reason'].map(mapping_reason)
df['guardian'] = features['guardian'].map(mapping_guardian).astype('Int64')
df['famsup'] = features['famsup'].map(mapping_famsup)
df['schoolsup'] = features['schoolsup'].map(mapping_schoolsup)
df['romantic'] = features['romantic'].map(mapping_romantic)
df['paid'] = features['paid'].map(mapping_paid)
df['activities'] = features['activities'].map(mapping_activities)
df['nursery'] = features['nursery'].map(mapping_nursery)
df['higher'] = features['higher'].map(mapping_higher)
df['internet'] = features['internet'].map(mapping_internet)

# %%
sns.countplot(x='school', data=features);

# %%
features.hist(bins=20, figsize=(20,15));

# %% [markdown]
# #### Outliers
#
# As I go through the data, I found there are students who achieve 0 in their G3 depsite having more than half during their G1 & G2 examinations.
# The outliers might affect model's performance, hence I decided to drop those outliers.

# %%
sns.boxplot(x=target["G3"]);

# %% [markdown]
# #### Drop Outliers data if certain requirement satisfied.
#
# G3 with score of 2.5 and less considered as Outliers. To understand this data, I will list down these outliers.

# %%
df_outliers = df[df["G3"]<2.5]
df_outliers
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 163       0    1   18        0        1        1     1     1     2     2
# 172       0    1   16        0        0        1     3     3     2     3
# 440       1    1   16        0        0        1     1     1     0     3
# 519       1    1   16        1        0        1     2     1     2     3
# 563       1    1   17        0        0        1     2     2     2     2
# 567       1    1   18        1        0        1     3     2     3     2
# 583       1    0   18        1        0        1     2     2     2     2
# 586       1    0   17        0        0        1     4     2     4     3
# 597       1    0   18        1        0        1     2     2     0     2
# 603       1    0   18        1        1        0     4     2     4     2
# 605       1    0   19        0        0        1     1     1     0     3
# 610       1    0   19        1        0        0     1     1     0     0
# 626       1    0   18        1        0        1     4     4     2     4
# 637       1    1   18        1        0        1     2     1     2     2
# 639       1    1   19        1        0        1     1     1     2     3
# 640       1    1   18        1        0        1     4     2     2     2
#
#      reason  guardian  traveltime  studytime  failures  schoolsup  famsup  \
# 163       0         0           1          1         2          0       0
# 172       0         1           1          2         1          0       1
# 440       2         0           2          2         0          0       1
# 519       3         0           2          2         0          0       0
# 563       0         0           1          1         1          0       0
# 567       0         0           1          1         1          0       0
# 583       1         0           2          1         1          0       0
# 586       2         0           1          2         0          1       1
# 597       0         0           3          2         1          0       0
# 603       3         0           1          2         0          0       0
# 605       1         1           2          1         1          0       0
# 610       0         2           2          2         3          0       1
# 626       1         1           3          2         0          0       1
# 637       1         0           2          1         0          0       0
# 639       1         0           2          1         1          0       0
# 640       2         1           2          1         1          0       0
#
#      paid  activities  nursery  higher  internet  romantic  famrel  freetime  \
# 163     0           0        1       0         1         1       2         3
# 172     0           0        1       1         1         1       4         5
# 440     0           1        1       1         0         1       5         4
# 519     0           1        1       1         1         0       5         2
# 563     0           1        1       1         0         1       1         2
# 567     0           0        1       0         1         0       2         3
# 583     0           0        1       0         1         1       5         5
# 586     0           1        1       1         1         0       5         5
# 597     0           1        1       1         0         1       4         3
# 603     0           1        1       1         1         1       5         3
# 605     0           0        1       0         0         0       5         5
# 610     0           1        1       0         0         1       3         5
# 626     0           0        0       1         1         1       3         2
# 637     0           1        0       1         1         1       4         4
# 639     0           0        1       1         0         0       4         3
# 640     1           0        1       1         0         0       5         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# 163      5     2     5       4         0  11   9   0
# 172      5     4     4       5         0  10  10   1
# 440      5     4     5       3         0   7   0   0
# 519      1     1     1       2         0   8   7   0
# 563      1     2     3       5         0   7   0   0
# 567      1     2     2       5         0   4   0   0
# 583      5     1     1       3         0   8   6   0
# 586      5     1     3       5         0   8   8   0
# 597      3     1     1       4         0   9   0   0
# 603      1     1     1       5         0   5   0   0
# 605      5     2     3       2         0   5   0   0
# 610      4     1     4       1         0   8   0   0
# 626      2     4     2       5         0   7   5   0
# 637      3     1     3       5         0   7   7   0
# 639      2     1     3       5         0   5   8   0
# 640      3     4     3       3         0   7   7   0

# %% [markdown]
# #### Dropping rows if:
#
# G3 considered as outliers when G1 or G2 above average.

# %%
outlier_idx = df[df["G3"] < 2.5].index
len(outlier_idx) 
df = df.drop(outlier_idx)
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0         0    0   18        0        0        0     4     4     0     4
# 1         0    0   17        0        0        1     1     1     0     2
# 2         0    0   15        0        1        1     1     1     0     2
# 3         0    0   15        0        0        1     4     2     1     3
# 4         0    0   16        0        0        1     3     3     2     2
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...
# 644       1    0   19        1        0        1     2     3     3     2
# 645       1    0   18        0        1        1     3     1     4     3
# 646       1    0   18        0        0        1     1     1     2     2
# 647       1    1   17        0        1        1     3     1     3     3
# 648       1    1   18        1        1        1     3     2     3     2
#
#      reason  guardian  traveltime  studytime  failures  schoolsup  famsup  \
# 0         0         0           2          2         0          1       0
# 1         0         1           1          2         0          0       1
# 2         1         0           1          2         0          1       0
# 3         2         0           1          3         0          0       1
# 4         2         1           1          2         0          0       1
# ..      ...       ...         ...        ...       ...        ...     ...
# 644       0         0           1          3         1          0       0
# 645       0         0           1          2         0          0       1
# 646       0         0           2          2         0          0       0
# 647       0         0           2          1         0          0       0
# 648       0         0           3          1         0          0       0
#
#      paid  activities  nursery  higher  internet  romantic  famrel  freetime  \
# 0       0           0        1       1         0         0       4         3
# 1       0           0        0       1         1         0       5         3
# 2       0           0        1       1         1         0       4         3
# 3       0           1        1       1         1         1       3         2
# 4       0           0        1       1         0         0       4         3
# ..    ...         ...      ...     ...       ...       ...     ...       ...
# 644     0           1        0       1         1         0       5         4
# 645     0           0        1       1         1         0       4         3
# 646     0           1        1       1         0         0       1         1
# 647     0           0        0       1         1         0       2         4
# 648     0           0        0       1         1         0       4         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# 0        4     1     1       3         4   0  11  11
# 1        3     1     1       3         2   9  11  11
# 2        2     2     3       3         6  12  13  12
# 3        2     1     1       5         0  14  14  14
# 4        2     1     2       5         0  11  13  13
# ..     ...   ...   ...     ...       ...  ..  ..  ..
# 644      2     1     2       5         4  10  11  10
# 645      4     1     1       1         4  15  15  16
# 646      1     1     1       5         6  11  12   9
# 647      5     3     4       2         6  10  10  10
# 648      1     3     4       5         4  10  11  11
#
# [633 rows x 33 columns]

# %% [markdown]
# ### Reassign features and target dataframe after dropping outliers

# %%
target = df.drop(features_list, axis = 1)
features = df.drop(["G3"], axis = 1)

# %% [markdown]
# #### Data normalization
#
# Split into train and testing data and normalize the training data btu not the test data.

# %% [markdown]
# #### Split Training and Testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.3,random_state=11)

# %%
scaler = preprocessing.MinMaxScaler(feature_range = (0,1))
X_train_scaled = scaler.fit_transform(X_train)
y_train_scaled = scaler.fit_transform(y_train)
X_test_scaled = scaler.fit_transform(X_test)
y_test_scaled = scaler.fit_transform(y_test)

# %%
X_train_unscaled = scaler.inverse_transform(X_train_scaled).astype('float64') 
y_train_unscaled = scaler.inverse_transform(y_train_scaled).astype('float64') 
X_test_unscaled = scaler.inverse_transform(X_test_scaled).astype('float64') 
y_test_unscaled = scaler.inverse_transform(y_test_scaled).astype('float64')

# %% [markdown]
# If (un)scale it, it returns array instead of DataFrame right after splitting them.

# %% [markdown]
# ### Here we go!
#
# # 4. Building Deep Learning Model with Tensorflow/Keras

# %%
def create_model():
    
    model = Sequential([
        Dense(32, 
              input_dim=32, 
              activation='linear', 
              kernel_initializer='lecun_uniform',
              kernel_constraint=MaxNorm(5),
             ),
        Dense(8, activation='linear'),
        Dropout(0.2),
        Dense(32, activation='linear'),
        Dense(1, activation='linear')
    ])
    optimizer = Adam(lr = 0.01)
    
    model.compile(
    loss='mse', 
    optimizer=optimizer, 
    metrics=['mse', 'mae'])
        
    return model

model = create_model()

# %% [markdown]
# # 5. Applying Genetic Algorithm

# %% [markdown]
# ### Convert Pandas dataframe to Numpy Array

# %%
X_train_GA = X_train_scaled
y_train_GA = y_train_scaled

# %%
import tensorflow.keras
import pygad.kerasga
import numpy
import pygad

def fitness_func(solution, sol_idx):
    global data_inputs, data_outputs, keras_ga, model

    model_weights_matrix = pygad.kerasga.model_weights_as_matrix(model=model,
                                                                 weights_vector=solution)

    model.set_weights(weights=model_weights_matrix)

    predictions = model.predict(data_inputs)
    mae = tensorflow.keras.losses.MeanAbsoluteError()
    abs_error = mae(data_outputs, predictions).numpy() + 0.00000001
    solution_fitness = 1.0/abs_error

    return solution_fitness

def callback_generation(ga_instance):
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))


keras_ga = pygad.kerasga.KerasGA(model=model,
                                 num_solutions=10)

# Data inputs
data_inputs = X_train_GA

# Data outputs
data_outputs = y_train_GA

num_generations = 1500
num_parents_mating = 5 
initial_population = keras_ga.population_weights 
parent_selection_type = "rank" 
crossover_type = "single_point"
mutation_type = "adaptive" 
keep_parents = -1 
mutation_percent_genes = (20,10)
ga_instance = pygad.GA(num_generations=num_generations,
                       num_parents_mating=num_parents_mating,
                       initial_population=initial_population,
                       fitness_func=fitness_func,
                       parent_selection_type=parent_selection_type,
                       crossover_type=crossover_type,
                       mutation_type=mutation_type,
                       mutation_percent_genes=mutation_percent_genes,
                       keep_parents=keep_parents,
                       on_generation=callback_generation)

# %%
ga_instance.run()
# Out:
# Generation = 1
# Fitness    = 3.4564748056465584
# Generation = 2
# Fitness    = 3.4564748056465584
# Generation = 3
# Fitness    = 3.4564748056465584
# Generation = 4
# Fitness    = 3.4564748056465584
# Generation = 5
# Fitness    = 3.4564748056465584
# Generation = 6
# Fitness    = 3.4564748056465584
# Generation = 7
# Fitness    = 3.4564748056465584
# Generation = 8
# Fitness    = 3.4564748056465584
# Generation = 9
# Fitness    = 3.4564748056465584
# Generation = 10
# Fitness    = 3.4564748056465584
# Generation = 11
# Fitness    = 3.4564748056465584
# Generation = 12
# Fitness    = 3.4564748056465584
# Generation = 13
# Fitness    = 3.4564748056465584
# Generation = 14
# Fitness    = 3.4564748056465584
# Generation = 15
# Fitness    = 3.4564748056465584
# Generation = 16
# Fitness    = 3.4564748056465584
# Generation = 17
# Fitness    = 3.4564748056465584
# Generation = 18
# Fitness    = 3.4564748056465584
# Generation = 19
# Fitness    = 3.4564748056465584
# Generation = 20
# Fitness    = 3.4564748056465584
# Generation = 21
# Fitness    = 3.4564748056465584
# Generation = 22
# Fitness    = 3.4564748056465584
# Generation = 23
# Fitness    = 3.4564748056465584
# Generation = 24
# Fitness    = 3.4564748056465584
# Generation = 25
# Fitness    = 3.4564748056465584
# Generation = 26
# Fitness    = 3.4564748056465584
# Generation = 27
# Fitness    = 3.4564748056465584
# Generation = 28
# Fitness    = 3.4564748056465584
# Generation = 29
# Fitness    = 3.4564748056465584
# Generation = 30
# Fitness    = 3.4564748056465584
# Generation = 31
# Fitness    = 3.4564748056465584
# Generation = 32
# Fitness    = 3.4564748056465584
# Generation = 33
# Fitness    = 3.4564748056465584
# Generation = 34
# Fitness    = 3.4564748056465584
# Generation = 35
# Fitness    = 3.4564748056465584
# Generation = 36
# Fitness    = 3.4564748056465584
# Generation = 37
# Fitness    = 3.4564748056465584
# Generation = 38
# Fitness    = 3.4564748056465584
# Generation = 39
# Fitness    = 3.4564748056465584
# Generation = 40
# Fitness    = 3.4564748056465584
# Generation = 41
# Fitness    = 3.4564748056465584
# Generation = 42
# Fitness    = 3.4564748056465584
# Generation = 43
# Fitness    = 3.4564748056465584
# Generation = 44
# Fitness    = 3.4564748056465584
# Generation = 45
# Fitness    = 3.4564748056465584
# Generation = 46
# Fitness    = 3.4564748056465584
# Generation = 47
# Fitness    = 3.4564748056465584
# Generation = 48
# Fitness    = 3.4564748056465584
# Generation = 49
# Fitness    = 3.4564748056465584
# Generation = 50
# Fitness    = 3.4564748056465584
# Generation = 51
# Fitness    = 3.4564748056465584
# Generation = 52
# Fitness    = 3.4564748056465584
# Generation = 53
# Fitness    = 3.4564748056465584
# Generation = 54
# Fitness    = 3.4564748056465584
# Generation = 55
# Fitness    = 3.4564748056465584
# Generation = 56
# Fitness    = 3.4564748056465584
# Generation = 57
# Fitness    = 3.4564748056465584
# Generation = 58
# Fitness    = 3.4564748056465584
# Generation = 59
# Fitness    = 3.4564748056465584
# Generation = 60
# Fitness    = 3.4564748056465584
# Generation = 61
# Fitness    = 3.4564748056465584
# Generation = 62
# Fitness    = 3.4564748056465584
# Generation = 63
# Fitness    = 3.4564748056465584
# Generation = 64
# Fitness    = 3.4564748056465584
# Generation = 65
# Fitness    = 3.4564748056465584
# Generation = 66
# Fitness    = 3.4564748056465584
# Generation = 67
# Fitness    = 3.4564748056465584
# Generation = 68
# Fitness    = 3.4564748056465584
# Generation = 69
# Fitness    = 3.4564748056465584
# Generation = 70
# Fitness    = 3.4564748056465584
# Generation = 71
# Fitness    = 3.4564748056465584
# Generation = 72
# Fitness    = 3.4564748056465584
# Generation = 73
# Fitness    = 3.4564748056465584
# Generation = 74
# Fitness    = 3.4564748056465584
# Generation = 75
# Fitness    = 3.4564748056465584
# Generation = 76
# Fitness    = 3.4564748056465584
# Generation = 77
# Fitness    = 3.4564748056465584
# Generation = 78
# Fitness    = 3.4564748056465584
# Generation = 79
# Fitness    = 3.4564748056465584
# Generation = 80
# Fitness    = 3.4564748056465584
# Generation = 81
# Fitness    = 3.4564748056465584
# Generation = 82
# Fitness    = 3.4564748056465584
# Generation = 83
# Fitness    = 3.4564748056465584
# Generation = 84
# Fitness    = 3.4564748056465584
# Generation = 85
# Fitness    = 3.4564748056465584
# Generation = 86
# Fitness    = 3.4564748056465584
# Generation = 87
# Fitness    = 3.4564748056465584
# Generation = 88
# Fitness    = 3.4564748056465584
# Generation = 89
# Fitness    = 3.4564748056465584
# Generation = 90
# Fitness    = 3.4564748056465584
# Generation = 91
# Fitness    = 3.4564748056465584
# Generation = 92
# Fitness    = 3.4564748056465584
# Generation = 93
# Fitness    = 3.4564748056465584
# Generation = 94
# Fitness    = 3.4564748056465584
# Generation = 95
# Fitness    = 3.4564748056465584
# Generation = 96
# Fitness    = 3.4564748056465584
# Generation = 97
# Fitness    = 3.4564748056465584
# Generation = 98
# Fitness    = 3.4564748056465584
# Generation = 99
# Fitness    = 3.4564748056465584
# Generation = 100
# Fitness    = 3.4564748056465584
# Generation = 101
# Fitness    = 3.4564748056465584
# Generation = 102
# Fitness    = 3.4564748056465584
# Generation = 103
# Fitness    = 3.4564748056465584
# Generation = 104
# Fitness    = 3.4564748056465584
# Generation = 105
# Fitness    = 3.4564748056465584
# Generation = 106
# Fitness    = 3.4564748056465584
# Generation = 107
# Fitness    = 3.4564748056465584
# Generation = 108
# Fitness    = 3.4564748056465584
# Generation = 109
# Fitness    = 3.4564748056465584
# Generation = 110
# Fitness    = 3.4564748056465584
# Generation = 111
# Fitness    = 3.4564748056465584
# Generation = 112
# Fitness    = 3.4564748056465584
# Generation = 113
# Fitness    = 3.4564748056465584
# Generation = 114
# Fitness    = 3.4564748056465584
# Generation = 115
# Fitness    = 3.4564748056465584
# Generation = 116
# Fitness    = 3.4564748056465584
# Generation = 117
# Fitness    = 3.4564748056465584
# Generation = 118
# Fitness    = 3.4564748056465584
# Generation = 119
# Fitness    = 3.4564748056465584
# Generation = 120
# Fitness    = 3.4564748056465584
# Generation = 121
# Fitness    = 3.4564748056465584
# Generation = 122
# Fitness    = 3.4564748056465584
# Generation = 123
# Fitness    = 3.4564748056465584
# Generation = 124
# Fitness    = 3.4564748056465584
# Generation = 125
# Fitness    = 3.4564748056465584
# Generation = 126
# Fitness    = 3.4564748056465584
# Generation = 127
# Fitness    = 3.4564748056465584
# Generation = 128
# Fitness    = 3.4564748056465584
# Generation = 129
# Fitness    = 3.4564748056465584
# Generation = 130
# Fitness    = 3.4564748056465584
# Generation = 131
# Fitness    = 3.4564748056465584
# Generation = 132
# Fitness    = 3.4564748056465584
# Generation = 133
# Fitness    = 3.4564748056465584
# Generation = 134
# Fitness    = 3.4564748056465584
# Generation = 135
# Fitness    = 3.4564748056465584
# Generation = 136
# Fitness    = 3.4564748056465584
# Generation = 137
# Fitness    = 3.4564748056465584
# Generation = 138
# Fitness    = 3.4564748056465584
# Generation = 139
# Fitness    = 3.4564748056465584
# Generation = 140
# Fitness    = 3.4564748056465584
# Generation = 141
# Fitness    = 3.4564748056465584
# Generation = 142
# Fitness    = 3.4564748056465584
# Generation = 143
# Fitness    = 3.4564748056465584
# Generation = 144
# Fitness    = 3.4564748056465584
# Generation = 145
# Fitness    = 3.4564748056465584
# Generation = 146
# Fitness    = 3.4564748056465584
# Generation = 147
# Fitness    = 3.4564748056465584
# Generation = 148
# Fitness    = 3.4564748056465584
# Generation = 149
# Fitness    = 3.4564748056465584
# Generation = 150
# Fitness    = 3.4564748056465584
# Generation = 151
# Fitness    = 3.4564748056465584
# Generation = 152
# Fitness    = 3.4564748056465584
# Generation = 153
# Fitness    = 3.4564748056465584
# Generation = 154
# Fitness    = 3.4564748056465584
# Generation = 155
# Fitness    = 3.4564748056465584
# Generation = 156
# Fitness    = 3.4564748056465584
# Generation = 157
# Fitness    = 3.4564748056465584
# Generation = 158
# Fitness    = 3.4564748056465584
# Generation = 159
# Fitness    = 3.4564748056465584
# Generation = 160
# Fitness    = 3.4564748056465584
# Generation = 161
# Fitness    = 3.4564748056465584
# Generation = 162
# Fitness    = 3.4564748056465584
# Generation = 163
# Fitness    = 3.4564748056465584
# Generation = 164
# Fitness    = 3.4564748056465584
# Generation = 165
# Fitness    = 3.4564748056465584
# Generation = 166
# Fitness    = 3.4564748056465584
# Generation = 167
# Fitness    = 3.4564748056465584
# Generation = 168
# Fitness    = 3.4564748056465584
# Generation = 169
# Fitness    = 3.4564748056465584
# Generation = 170
# Fitness    = 3.4564748056465584
# Generation = 171
# Fitness    = 3.4564748056465584
# Generation = 172
# Fitness    = 3.4564748056465584
# Generation = 173
# Fitness    = 3.4564748056465584
# Generation = 174
# Fitness    = 3.4564748056465584
# Generation = 175
# Fitness    = 3.4564748056465584
# Generation = 176
# Fitness    = 3.4564748056465584
# Generation = 177
# Fitness    = 3.4564748056465584
# Generation = 178
# Fitness    = 3.4564748056465584
# Generation = 179
# Fitness    = 3.4564748056465584
# Generation = 180
# Fitness    = 3.4564748056465584
# Generation = 181
# Fitness    = 3.4564748056465584
# Generation = 182
# Fitness    = 3.4564748056465584
# Generation = 183
# Fitness    = 3.4564748056465584
# Generation = 184
# Fitness    = 3.4564748056465584
# Generation = 185
# Fitness    = 3.4564748056465584
# Generation = 186
# Fitness    = 3.4564748056465584
# Generation = 187
# Fitness    = 3.4564748056465584
# Generation = 188
# Fitness    = 3.4564748056465584
# Generation = 189
# Fitness    = 3.4564748056465584
# Generation = 190
# Fitness    = 3.4564748056465584
# Generation = 191
# Fitness    = 3.4564748056465584
# Generation = 192
# Fitness    = 3.4564748056465584
# Generation = 193
# Fitness    = 3.4564748056465584
# Generation = 194
# Fitness    = 3.4564748056465584
# Generation = 195
# Fitness    = 3.4564748056465584
# Generation = 196
# Fitness    = 3.4564748056465584
# Generation = 197
# Fitness    = 3.4564748056465584
# Generation = 198
# Fitness    = 3.4564748056465584
# Generation = 199
# Fitness    = 3.4564748056465584
# Generation = 200
# Fitness    = 3.4564748056465584
# Generation = 201
# Fitness    = 3.4564748056465584
# Generation = 202
# Fitness    = 3.4564748056465584
# Generation = 203
# Fitness    = 3.4564748056465584
# Generation = 204
# Fitness    = 3.4564748056465584
# Generation = 205
# Fitness    = 3.4564748056465584
# Generation = 206
# Fitness    = 3.4564748056465584
# Generation = 207
# Fitness    = 3.4564748056465584
# Generation = 208
# Fitness    = 3.4564748056465584
# Generation = 209
# Fitness    = 3.4564748056465584
# Generation = 210
# Fitness    = 3.4564748056465584
# Generation = 211
# Fitness    = 3.4564748056465584
# Generation = 212
# Fitness    = 3.4564748056465584
# Generation = 213
# Fitness    = 3.4564748056465584
# Generation = 214
# Fitness    = 3.4564748056465584
# Generation = 215
# Fitness    = 3.4564748056465584
# Generation = 216
# Fitness    = 3.4564748056465584
# Generation = 217
# Fitness    = 3.4564748056465584
# Generation = 218
# Fitness    = 3.4564748056465584
# Generation = 219
# Fitness    = 3.4564748056465584
# Generation = 220
# Fitness    = 3.4564748056465584
# Generation = 221
# Fitness    = 3.4564748056465584
# Generation = 222
# Fitness    = 3.4564748056465584
# Generation = 223
# Fitness    = 3.4564748056465584
# Generation = 224
# Fitness    = 3.4564748056465584
# Generation = 225
# Fitness    = 3.4564748056465584
# Generation = 226
# Fitness    = 3.4564748056465584
# Generation = 227
# Fitness    = 3.4564748056465584
# Generation = 228
# Fitness    = 3.4564748056465584
# Generation = 229
# Fitness    = 3.4564748056465584
# Generation = 230
# Fitness    = 3.4564748056465584
# Generation = 231
# Fitness    = 3.4564748056465584
# Generation = 232
# Fitness    = 3.4564748056465584
# Generation = 233
# Fitness    = 3.4564748056465584
# Generation = 234
# Fitness    = 3.4564748056465584
# Generation = 235
# Fitness    = 3.4564748056465584
# Generation = 236
# Fitness    = 3.4564748056465584
# Generation = 237
# Fitness    = 3.4564748056465584
# Generation = 238
# Fitness    = 3.4564748056465584
# Generation = 239
# Fitness    = 3.4564748056465584
# Generation = 240
# Fitness    = 3.4564748056465584
# Generation = 241
# Fitness    = 3.4564748056465584
# Generation = 242
# Fitness    = 3.4564748056465584
# Generation = 243
# Fitness    = 3.4564748056465584
# Generation = 244
# Fitness    = 3.4564748056465584
# Generation = 245
# Fitness    = 3.4564748056465584
# Generation = 246
# Fitness    = 3.4564748056465584
# Generation = 247
# Fitness    = 3.4564748056465584
# Generation = 248
# Fitness    = 3.4564748056465584
# Generation = 249
# Fitness    = 3.4564748056465584
# Generation = 250
# Fitness    = 3.4564748056465584
# Generation = 251
# Fitness    = 3.4564748056465584
# Generation = 252
# Fitness    = 3.4564748056465584
# Generation = 253
# Fitness    = 3.4564748056465584
# Generation = 254
# Fitness    = 3.4564748056465584
# Generation = 255
# Fitness    = 3.4564748056465584
# Generation = 256
# Fitness    = 3.4564748056465584
# Generation = 257
# Fitness    = 3.4564748056465584
# Generation = 258
# Fitness    = 3.4564748056465584
# Generation = 259
# Fitness    = 3.4564748056465584
# Generation = 260
# Fitness    = 3.4564748056465584
# Generation = 261
# Fitness    = 3.4564748056465584
# Generation = 262
# Fitness    = 3.4564748056465584
# Generation = 263
# Fitness    = 3.4564748056465584
# Generation = 264
# Fitness    = 3.4564748056465584
# Generation = 265
# Fitness    = 3.4564748056465584
# Generation = 266
# Fitness    = 3.4564748056465584
# Generation = 267
# Fitness    = 3.4564748056465584
# Generation = 268
# Fitness    = 3.4564748056465584
# Generation = 269
# Fitness    = 3.4564748056465584
# Generation = 270
# Fitness    = 3.4564748056465584
# Generation = 271
# Fitness    = 3.4564748056465584
# Generation = 272
# Fitness    = 3.4564748056465584
# Generation = 273
# Fitness    = 3.4564748056465584
# Generation = 274
# Fitness    = 3.4564748056465584
# Generation = 275
# Fitness    = 3.4564748056465584
# Generation = 276
# Fitness    = 3.4564748056465584
# Generation = 277
# Fitness    = 3.4564748056465584
# Generation = 278
# Fitness    = 3.4564748056465584
# Generation = 279
# Fitness    = 3.4564748056465584
# Generation = 280
# Fitness    = 3.4564748056465584
# Generation = 281
# Fitness    = 3.4564748056465584
# Generation = 282
# Fitness    = 3.4564748056465584
# Generation = 283
# Fitness    = 3.4564748056465584
# Generation = 284
# Fitness    = 3.4564748056465584
# Generation = 285
# Fitness    = 3.4564748056465584
# Generation = 286
# Fitness    = 3.4564748056465584
# Generation = 287
# Fitness    = 3.4564748056465584
# Generation = 288
# Fitness    = 3.4564748056465584
# Generation = 289
# Fitness    = 3.4564748056465584
# Generation = 290
# Fitness    = 3.4564748056465584
# Generation = 291
# Fitness    = 3.650738937656146
# Generation = 292
# Fitness    = 3.650738937656146
# Generation = 293
# Fitness    = 3.650738937656146
# Generation = 294
# Fitness    = 3.650738937656146
# Generation = 295
# Fitness    = 3.650738937656146
# Generation = 296
# Fitness    = 3.650738937656146
# Generation = 297
# Fitness    = 3.650738937656146
# Generation = 298
# Fitness    = 3.650738937656146
# Generation = 299
# Fitness    = 3.650738937656146
# Generation = 300
# Fitness    = 3.650738937656146
# Generation = 301
# Fitness    = 3.650738937656146
# Generation = 302
# Fitness    = 3.650738937656146
# Generation = 303
# Fitness    = 3.650738937656146
# Generation = 304
# Fitness    = 3.650738937656146
# Generation = 305
# Fitness    = 3.650738937656146
# Generation = 306
# Fitness    = 3.650738937656146
# Generation = 307
# Fitness    = 3.650738937656146
# Generation = 308
# Fitness    = 3.650738937656146
# Generation = 309
# Fitness    = 3.650738937656146
# Generation = 310
# Fitness    = 3.650738937656146
# Generation = 311
# Fitness    = 3.650738937656146
# Generation = 312
# Fitness    = 3.650738937656146
# Generation = 313
# Fitness    = 3.650738937656146
# Generation = 314
# Fitness    = 3.650738937656146
# Generation = 315
# Fitness    = 3.650738937656146
# Generation = 316
# Fitness    = 3.650738937656146
# Generation = 317
# Fitness    = 3.650738937656146
# Generation = 318
# Fitness    = 3.650738937656146
# Generation = 319
# Fitness    = 3.650738937656146
# Generation = 320
# Fitness    = 3.650738937656146
# Generation = 321
# Fitness    = 3.650738937656146
# Generation = 322
# Fitness    = 3.650738937656146
# Generation = 323
# Fitness    = 3.650738937656146
# Generation = 324
# Fitness    = 3.650738937656146
# Generation = 325
# Fitness    = 3.650738937656146
# Generation = 326
# Fitness    = 3.650738937656146
# Generation = 327
# Fitness    = 3.650738937656146
# Generation = 328
# Fitness    = 3.650738937656146
# Generation = 329
# Fitness    = 3.650738937656146
# Generation = 330
# Fitness    = 3.650738937656146
# Generation = 331
# Fitness    = 3.650738937656146
# Generation = 332
# Fitness    = 3.650738937656146
# Generation = 333
# Fitness    = 3.650738937656146
# Generation = 334
# Fitness    = 3.650738937656146
# Generation = 335
# Fitness    = 3.650738937656146
# Generation = 336
# Fitness    = 3.650738937656146
# Generation = 337
# Fitness    = 3.650738937656146
# Generation = 338
# Fitness    = 3.650738937656146
# Generation = 339
# Fitness    = 3.650738937656146
# Generation = 340
# Fitness    = 3.650738937656146
# Generation = 341
# Fitness    = 3.650738937656146
# Generation = 342
# Fitness    = 3.650738937656146
# Generation = 343
# Fitness    = 3.650738937656146
# Generation = 344
# Fitness    = 3.650738937656146
# Generation = 345
# Fitness    = 3.650738937656146
# Generation = 346
# Fitness    = 3.650738937656146
# Generation = 347
# Fitness    = 3.650738937656146
# Generation = 348
# Fitness    = 3.650738937656146
# Generation = 349
# Fitness    = 3.650738937656146
# Generation = 350
# Fitness    = 3.650738937656146
# Generation = 351
# Fitness    = 3.650738937656146
# Generation = 352
# Fitness    = 3.650738937656146
# Generation = 353
# Fitness    = 3.650738937656146
# Generation = 354
# Fitness    = 3.650738937656146
# Generation = 355
# Fitness    = 3.650738937656146
# Generation = 356
# Fitness    = 3.650738937656146
# Generation = 357
# Fitness    = 3.650738937656146
# Generation = 358
# Fitness    = 3.650738937656146
# Generation = 359
# Fitness    = 3.650738937656146
# Generation = 360
# Fitness    = 3.650738937656146
# Generation = 361
# Fitness    = 3.650738937656146
# Generation = 362
# Fitness    = 3.650738937656146
# Generation = 363
# Fitness    = 3.650738937656146
# Generation = 364
# Fitness    = 3.650738937656146
# Generation = 365
# Fitness    = 3.650738937656146
# Generation = 366
# Fitness    = 3.650738937656146
# Generation = 367
# Fitness    = 3.650738937656146
# Generation = 368
# Fitness    = 3.650738937656146
# Generation = 369
# Fitness    = 3.650738937656146
# Generation = 370
# Fitness    = 3.650738937656146
# Generation = 371
# Fitness    = 3.650738937656146
# Generation = 372
# Fitness    = 3.650738937656146
# Generation = 373
# Fitness    = 3.650738937656146
# Generation = 374
# Fitness    = 3.650738937656146
# Generation = 375
# Fitness    = 3.650738937656146
# Generation = 376
# Fitness    = 3.650738937656146
# Generation = 377
# Fitness    = 3.650738937656146
# Generation = 378
# Fitness    = 3.650738937656146
# Generation = 379
# Fitness    = 3.650738937656146
# Generation = 380
# Fitness    = 3.650738937656146
# Generation = 381
# Fitness    = 3.650738937656146
# Generation = 382
# Fitness    = 3.650738937656146
# Generation = 383
# Fitness    = 3.650738937656146
# Generation = 384
# Fitness    = 3.650738937656146
# Generation = 385
# Fitness    = 3.650738937656146
# Generation = 386
# Fitness    = 3.650738937656146
# Generation = 387
# Fitness    = 3.650738937656146
# Generation = 388
# Fitness    = 3.650738937656146
# Generation = 389
# Fitness    = 3.650738937656146
# Generation = 390
# Fitness    = 3.650738937656146
# Generation = 391
# Fitness    = 3.650738937656146
# Generation = 392
# Fitness    = 3.650738937656146
# Generation = 393
# Fitness    = 3.650738937656146
# Generation = 394
# Fitness    = 3.650738937656146
# Generation = 395
# Fitness    = 3.650738937656146
# Generation = 396
# Fitness    = 3.650738937656146
# Generation = 397
# Fitness    = 3.650738937656146
# Generation = 398
# Fitness    = 3.650738937656146
# Generation = 399
# Fitness    = 3.650738937656146
# Generation = 400
# Fitness    = 3.650738937656146
# Generation = 401
# Fitness    = 3.650738937656146
# Generation = 402
# Fitness    = 3.650738937656146
# Generation = 403
# Fitness    = 3.650738937656146
# Generation = 404
# Fitness    = 3.650738937656146
# Generation = 405
# Fitness    = 3.650738937656146
# Generation = 406
# Fitness    = 3.650738937656146
# Generation = 407
# Fitness    = 3.650738937656146
# Generation = 408
# Fitness    = 3.650738937656146
# Generation = 409
# Fitness    = 3.650738937656146
# Generation = 410
# Fitness    = 3.650738937656146
# Generation = 411
# Fitness    = 3.650738937656146
# Generation = 412
# Fitness    = 3.650738937656146
# Generation = 413
# Fitness    = 3.650738937656146
# Generation = 414
# Fitness    = 3.650738937656146
# Generation = 415
# Fitness    = 3.650738937656146
# Generation = 416
# Fitness    = 3.650738937656146
# Generation = 417
# Fitness    = 3.650738937656146
# Generation = 418
# Fitness    = 3.650738937656146
# Generation = 419
# Fitness    = 3.650738937656146
# Generation = 420
# Fitness    = 3.650738937656146
# Generation = 421
# Fitness    = 3.650738937656146
# Generation = 422
# Fitness    = 3.650738937656146
# Generation = 423
# Fitness    = 3.650738937656146
# Generation = 424
# Fitness    = 3.650738937656146
# Generation = 425
# Fitness    = 3.650738937656146
# Generation = 426
# Fitness    = 3.650738937656146
# Generation = 427
# Fitness    = 3.650738937656146
# Generation = 428
# Fitness    = 3.650738937656146
# Generation = 429
# Fitness    = 3.650738937656146
# Generation = 430
# Fitness    = 3.650738937656146
# Generation = 431
# Fitness    = 3.650738937656146
# Generation = 432
# Fitness    = 3.650738937656146
# Generation = 433
# Fitness    = 3.650738937656146
# Generation = 434
# Fitness    = 3.650738937656146
# Generation = 435
# Fitness    = 3.650738937656146
# Generation = 436
# Fitness    = 3.650738937656146
# Generation = 437
# Fitness    = 3.650738937656146
# Generation = 438
# Fitness    = 3.650738937656146
# Generation = 439
# Fitness    = 3.650738937656146
# Generation = 440
# Fitness    = 3.650738937656146
# Generation = 441
# Fitness    = 3.650738937656146
# Generation = 442
# Fitness    = 3.650738937656146
# Generation = 443
# Fitness    = 3.650738937656146
# Generation = 444
# Fitness    = 3.650738937656146
# Generation = 445
# Fitness    = 3.650738937656146
# Generation = 446
# Fitness    = 3.650738937656146
# Generation = 447
# Fitness    = 3.650738937656146
# Generation = 448
# Fitness    = 3.650738937656146
# Generation = 449
# Fitness    = 3.650738937656146
# Generation = 450
# Fitness    = 3.650738937656146
# Generation = 451
# Fitness    = 3.650738937656146
# Generation = 452
# Fitness    = 3.650738937656146
# Generation = 453
# Fitness    = 3.650738937656146
# Generation = 454
# Fitness    = 3.650738937656146
# Generation = 455
# Fitness    = 3.650738937656146
# Generation = 456
# Fitness    = 3.650738937656146
# Generation = 457
# Fitness    = 3.650738937656146
# Generation = 458
# Fitness    = 3.650738937656146
# Generation = 459
# Fitness    = 3.650738937656146
# Generation = 460
# Fitness    = 3.650738937656146
# Generation = 461
# Fitness    = 3.650738937656146
# Generation = 462
# Fitness    = 3.650738937656146
# Generation = 463
# Fitness    = 3.650738937656146
# Generation = 464
# Fitness    = 3.650738937656146
# Generation = 465
# Fitness    = 3.650738937656146
# Generation = 466
# Fitness    = 3.650738937656146
# Generation = 467
# Fitness    = 3.650738937656146
# Generation = 468
# Fitness    = 3.650738937656146
# Generation = 469
# Fitness    = 3.650738937656146
# Generation = 470
# Fitness    = 3.650738937656146
# Generation = 471
# Fitness    = 3.650738937656146
# Generation = 472
# Fitness    = 3.650738937656146
# Generation = 473
# Fitness    = 3.650738937656146
# Generation = 474
# Fitness    = 3.650738937656146
# Generation = 475
# Fitness    = 3.650738937656146
# Generation = 476
# Fitness    = 3.650738937656146
# Generation = 477
# Fitness    = 3.650738937656146
# Generation = 478
# Fitness    = 3.650738937656146
# Generation = 479
# Fitness    = 3.650738937656146
# Generation = 480
# Fitness    = 3.650738937656146
# Generation = 481
# Fitness    = 3.650738937656146
# Generation = 482
# Fitness    = 3.650738937656146
# Generation = 483
# Fitness    = 3.650738937656146
# Generation = 484
# Fitness    = 3.650738937656146
# Generation = 485
# Fitness    = 3.650738937656146
# Generation = 486
# Fitness    = 3.650738937656146
# Generation = 487
# Fitness    = 3.650738937656146
# Generation = 488
# Fitness    = 3.650738937656146
# Generation = 489
# Fitness    = 3.650738937656146
# Generation = 490
# Fitness    = 3.650738937656146
# Generation = 491
# Fitness    = 3.650738937656146
# Generation = 492
# Fitness    = 3.650738937656146
# Generation = 493
# Fitness    = 3.650738937656146
# Generation = 494
# Fitness    = 3.650738937656146
# Generation = 495
# Fitness    = 3.650738937656146
# Generation = 496
# Fitness    = 3.650738937656146
# Generation = 497
# Fitness    = 3.650738937656146
# Generation = 498
# Fitness    = 3.650738937656146
# Generation = 499
# Fitness    = 3.650738937656146
# Generation = 500
# Fitness    = 3.650738937656146
# Generation = 501
# Fitness    = 3.650738937656146
# Generation = 502
# Fitness    = 3.650738937656146
# Generation = 503
# Fitness    = 3.650738937656146
# Generation = 504
# Fitness    = 3.650738937656146
# Generation = 505
# Fitness    = 3.650738937656146
# Generation = 506
# Fitness    = 3.650738937656146
# Generation = 507
# Fitness    = 3.650738937656146
# Generation = 508
# Fitness    = 3.650738937656146
# Generation = 509
# Fitness    = 3.650738937656146
# Generation = 510
# Fitness    = 3.650738937656146
# Generation = 511
# Fitness    = 3.650738937656146
# Generation = 512
# Fitness    = 3.650738937656146
# Generation = 513
# Fitness    = 3.650738937656146
# Generation = 514
# Fitness    = 3.650738937656146
# Generation = 515
# Fitness    = 3.650738937656146
# Generation = 516
# Fitness    = 3.650738937656146
# Generation = 517
# Fitness    = 3.650738937656146
# Generation = 518
# Fitness    = 3.650738937656146
# Generation = 519
# Fitness    = 3.650738937656146
# Generation = 520
# Fitness    = 3.650738937656146
# Generation = 521
# Fitness    = 3.650738937656146
# Generation = 522
# Fitness    = 3.650738937656146
# Generation = 523
# Fitness    = 3.650738937656146
# Generation = 524
# Fitness    = 3.650738937656146
# Generation = 525
# Fitness    = 3.650738937656146
# Generation = 526
# Fitness    = 3.650738937656146
# Generation = 527
# Fitness    = 3.650738937656146
# Generation = 528
# Fitness    = 3.650738937656146
# Generation = 529
# Fitness    = 3.650738937656146
# Generation = 530
# Fitness    = 3.650738937656146
# Generation = 531
# Fitness    = 3.650738937656146
# Generation = 532
# Fitness    = 3.650738937656146
# Generation = 533
# Fitness    = 3.650738937656146
# Generation = 534
# Fitness    = 3.650738937656146
# Generation = 535
# Fitness    = 3.650738937656146
# Generation = 536
# Fitness    = 3.650738937656146
# Generation = 537
# Fitness    = 3.650738937656146
# Generation = 538
# Fitness    = 3.650738937656146
# Generation = 539
# Fitness    = 3.650738937656146
# Generation = 540
# Fitness    = 3.650738937656146
# Generation = 541
# Fitness    = 3.650738937656146
# Generation = 542
# Fitness    = 3.650738937656146
# Generation = 543
# Fitness    = 3.650738937656146
# Generation = 544
# Fitness    = 3.650738937656146
# Generation = 545
# Fitness    = 3.650738937656146
# Generation = 546
# Fitness    = 3.650738937656146
# Generation = 547
# Fitness    = 3.650738937656146
# Generation = 548
# Fitness    = 3.650738937656146
# Generation = 549
# Fitness    = 3.650738937656146
# Generation = 550
# Fitness    = 3.650738937656146
# Generation = 551
# Fitness    = 3.650738937656146
# Generation = 552
# Fitness    = 3.650738937656146
# Generation = 553
# Fitness    = 3.650738937656146
# Generation = 554
# Fitness    = 3.650738937656146
# Generation = 555
# Fitness    = 3.650738937656146
# Generation = 556
# Fitness    = 3.650738937656146
# Generation = 557
# Fitness    = 3.650738937656146
# Generation = 558
# Fitness    = 3.650738937656146
# Generation = 559
# Fitness    = 3.650738937656146
# Generation = 560
# Fitness    = 3.650738937656146
# Generation = 561
# Fitness    = 3.650738937656146
# Generation = 562
# Fitness    = 3.650738937656146
# Generation = 563
# Fitness    = 3.650738937656146
# Generation = 564
# Fitness    = 3.650738937656146
# Generation = 565
# Fitness    = 3.650738937656146
# Generation = 566
# Fitness    = 3.650738937656146
# Generation = 567
# Fitness    = 3.650738937656146
# Generation = 568
# Fitness    = 3.650738937656146
# Generation = 569
# Fitness    = 3.650738937656146
# Generation = 570
# Fitness    = 3.650738937656146
# Generation = 571
# Fitness    = 3.650738937656146
# Generation = 572
# Fitness    = 3.650738937656146
# Generation = 573
# Fitness    = 3.650738937656146
# Generation = 574
# Fitness    = 3.650738937656146
# Generation = 575
# Fitness    = 3.650738937656146
# Generation = 576
# Fitness    = 3.650738937656146
# Generation = 577
# Fitness    = 3.650738937656146
# Generation = 578
# Fitness    = 3.650738937656146
# Generation = 579
# Fitness    = 3.650738937656146
# Generation = 580
# Fitness    = 3.650738937656146
# Generation = 581
# Fitness    = 3.650738937656146
# Generation = 582
# Fitness    = 3.650738937656146
# Generation = 583
# Fitness    = 3.650738937656146
# Generation = 584
# Fitness    = 3.650738937656146
# Generation = 585
# Fitness    = 3.650738937656146
# Generation = 586
# Fitness    = 3.650738937656146
# Generation = 587
# Fitness    = 3.650738937656146
# Generation = 588
# Fitness    = 3.650738937656146
# Generation = 589
# Fitness    = 3.650738937656146
# Generation = 590
# Fitness    = 3.650738937656146
# Generation = 591
# Fitness    = 3.650738937656146
# Generation = 592
# Fitness    = 3.650738937656146
# Generation = 593
# Fitness    = 3.650738937656146
# Generation = 594
# Fitness    = 3.650738937656146
# Generation = 595
# Fitness    = 3.650738937656146
# Generation = 596
# Fitness    = 3.650738937656146
# Generation = 597
# Fitness    = 3.650738937656146
# Generation = 598
# Fitness    = 3.650738937656146
# Generation = 599
# Fitness    = 3.650738937656146
# Generation = 600
# Fitness    = 3.650738937656146
# Generation = 601
# Fitness    = 3.650738937656146
# Generation = 602
# Fitness    = 3.650738937656146
# Generation = 603
# Fitness    = 3.650738937656146
# Generation = 604
# Fitness    = 3.650738937656146
# Generation = 605
# Fitness    = 3.650738937656146
# Generation = 606
# Fitness    = 3.650738937656146
# Generation = 607
# Fitness    = 3.650738937656146
# Generation = 608
# Fitness    = 3.650738937656146
# Generation = 609
# Fitness    = 3.650738937656146
# Generation = 610
# Fitness    = 3.650738937656146
# Generation = 611
# Fitness    = 3.650738937656146
# Generation = 612
# Fitness    = 3.650738937656146
# Generation = 613
# Fitness    = 3.650738937656146
# Generation = 614
# Fitness    = 3.650738937656146
# Generation = 615
# Fitness    = 3.650738937656146
# Generation = 616
# Fitness    = 3.650738937656146
# Generation = 617
# Fitness    = 3.650738937656146
# Generation = 618
# Fitness    = 3.650738937656146
# Generation = 619
# Fitness    = 3.650738937656146
# Generation = 620
# Fitness    = 3.650738937656146
# Generation = 621
# Fitness    = 3.650738937656146
# Generation = 622
# Fitness    = 3.650738937656146
# Generation = 623
# Fitness    = 3.650738937656146
# Generation = 624
# Fitness    = 3.650738937656146
# Generation = 625
# Fitness    = 3.650738937656146
# Generation = 626
# Fitness    = 3.650738937656146
# Generation = 627
# Fitness    = 3.650738937656146
# Generation = 628
# Fitness    = 3.650738937656146
# Generation = 629
# Fitness    = 3.650738937656146
# Generation = 630
# Fitness    = 3.650738937656146
# Generation = 631
# Fitness    = 3.650738937656146
# Generation = 632
# Fitness    = 3.650738937656146
# Generation = 633
# Fitness    = 3.650738937656146
# Generation = 634
# Fitness    = 3.650738937656146
# Generation = 635
# Fitness    = 3.650738937656146
# Generation = 636
# Fitness    = 3.650738937656146
# Generation = 637
# Fitness    = 3.650738937656146
# Generation = 638
# Fitness    = 3.650738937656146
# Generation = 639
# Fitness    = 3.650738937656146
# Generation = 640
# Fitness    = 3.650738937656146
# Generation = 641
# Fitness    = 3.650738937656146
# Generation = 642
# Fitness    = 3.650738937656146
# Generation = 643
# Fitness    = 3.650738937656146
# Generation = 644
# Fitness    = 3.650738937656146
# Generation = 645
# Fitness    = 3.650738937656146
# Generation = 646
# Fitness    = 3.650738937656146
# Generation = 647
# Fitness    = 3.650738937656146
# Generation = 648
# Fitness    = 3.650738937656146
# Generation = 649
# Fitness    = 3.650738937656146
# Generation = 650
# Fitness    = 3.650738937656146
# Generation = 651
# Fitness    = 3.650738937656146
# Generation = 652
# Fitness    = 3.650738937656146
# Generation = 653
# Fitness    = 3.650738937656146
# Generation = 654
# Fitness    = 3.650738937656146
# Generation = 655
# Fitness    = 3.650738937656146
# Generation = 656
# Fitness    = 3.650738937656146
# Generation = 657
# Fitness    = 3.650738937656146
# Generation = 658
# Fitness    = 3.650738937656146
# Generation = 659
# Fitness    = 3.650738937656146
# Generation = 660
# Fitness    = 3.650738937656146
# Generation = 661
# Fitness    = 3.650738937656146
# Generation = 662
# Fitness    = 3.650738937656146
# Generation = 663
# Fitness    = 3.650738937656146
# Generation = 664
# Fitness    = 3.650738937656146
# Generation = 665
# Fitness    = 3.650738937656146
# Generation = 666
# Fitness    = 3.650738937656146
# Generation = 667
# Fitness    = 3.650738937656146
# Generation = 668
# Fitness    = 3.650738937656146
# Generation = 669
# Fitness    = 3.650738937656146
# Generation = 670
# Fitness    = 3.650738937656146
# Generation = 671
# Fitness    = 3.650738937656146
# Generation = 672
# Fitness    = 3.650738937656146
# Generation = 673
# Fitness    = 3.650738937656146
# Generation = 674
# Fitness    = 3.650738937656146
# Generation = 675
# Fitness    = 3.650738937656146
# Generation = 676
# Fitness    = 3.650738937656146
# Generation = 677
# Fitness    = 3.650738937656146
# Generation = 678
# Fitness    = 3.650738937656146
# Generation = 679
# Fitness    = 3.650738937656146
# Generation = 680
# Fitness    = 3.650738937656146
# Generation = 681
# Fitness    = 3.650738937656146
# Generation = 682
# Fitness    = 3.650738937656146
# Generation = 683
# Fitness    = 3.650738937656146
# Generation = 684
# Fitness    = 3.650738937656146
# Generation = 685
# Fitness    = 3.650738937656146
# Generation = 686
# Fitness    = 3.650738937656146
# Generation = 687
# Fitness    = 3.650738937656146
# Generation = 688
# Fitness    = 3.650738937656146
# Generation = 689
# Fitness    = 3.650738937656146
# Generation = 690
# Fitness    = 3.650738937656146
# Generation = 691
# Fitness    = 3.650738937656146
# Generation = 692
# Fitness    = 3.650738937656146
# Generation = 693
# Fitness    = 3.650738937656146
# Generation = 694
# Fitness    = 3.650738937656146
# Generation = 695
# Fitness    = 3.650738937656146
# Generation = 696
# Fitness    = 3.650738937656146
# Generation = 697
# Fitness    = 3.650738937656146
# Generation = 698
# Fitness    = 3.650738937656146
# Generation = 699
# Fitness    = 3.650738937656146
# Generation = 700
# Fitness    = 3.650738937656146
# Generation = 701
# Fitness    = 3.650738937656146
# Generation = 702
# Fitness    = 3.650738937656146
# Generation = 703
# Fitness    = 3.650738937656146
# Generation = 704
# Fitness    = 3.650738937656146
# Generation = 705
# Fitness    = 3.650738937656146
# Generation = 706
# Fitness    = 3.650738937656146
# Generation = 707
# Fitness    = 3.650738937656146
# Generation = 708
# Fitness    = 3.650738937656146
# Generation = 709
# Fitness    = 3.650738937656146
# Generation = 710
# Fitness    = 3.650738937656146
# Generation = 711
# Fitness    = 3.650738937656146
# Generation = 712
# Fitness    = 3.650738937656146
# Generation = 713
# Fitness    = 3.650738937656146
# Generation = 714
# Fitness    = 3.650738937656146
# Generation = 715
# Fitness    = 3.650738937656146
# Generation = 716
# Fitness    = 3.650738937656146
# Generation = 717
# Fitness    = 3.650738937656146
# Generation = 718
# Fitness    = 3.650738937656146
# Generation = 719
# Fitness    = 3.650738937656146
# Generation = 720
# Fitness    = 3.650738937656146
# Generation = 721
# Fitness    = 3.650738937656146
# Generation = 722
# Fitness    = 3.650738937656146
# Generation = 723
# Fitness    = 3.650738937656146
# Generation = 724
# Fitness    = 3.650738937656146
# Generation = 725
# Fitness    = 3.650738937656146
# Generation = 726
# Fitness    = 3.650738937656146
# Generation = 727
# Fitness    = 3.650738937656146
# Generation = 728
# Fitness    = 3.650738937656146
# Generation = 729
# Fitness    = 3.650738937656146
# Generation = 730
# Fitness    = 3.650738937656146
# Generation = 731
# Fitness    = 3.650738937656146
# Generation = 732
# Fitness    = 3.650738937656146
# Generation = 733
# Fitness    = 3.650738937656146
# Generation = 734
# Fitness    = 3.650738937656146
# Generation = 735
# Fitness    = 3.650738937656146
# Generation = 736
# Fitness    = 3.650738937656146
# Generation = 737
# Fitness    = 3.650738937656146
# Generation = 738
# Fitness    = 3.650738937656146
# Generation = 739
# Fitness    = 3.650738937656146
# Generation = 740
# Fitness    = 3.650738937656146
# Generation = 741
# Fitness    = 3.650738937656146
# Generation = 742
# Fitness    = 3.650738937656146
# Generation = 743
# Fitness    = 3.650738937656146
# Generation = 744
# Fitness    = 3.650738937656146
# Generation = 745
# Fitness    = 3.650738937656146
# Generation = 746
# Fitness    = 3.650738937656146
# Generation = 747
# Fitness    = 3.650738937656146
# Generation = 748
# Fitness    = 3.650738937656146
# Generation = 749
# Fitness    = 3.650738937656146
# Generation = 750
# Fitness    = 3.650738937656146
# Generation = 751
# Fitness    = 3.650738937656146
# Generation = 752
# Fitness    = 3.650738937656146
# Generation = 753
# Fitness    = 3.650738937656146
# Generation = 754
# Fitness    = 3.650738937656146
# Generation = 755
# Fitness    = 3.650738937656146
# Generation = 756
# Fitness    = 3.650738937656146
# Generation = 757
# Fitness    = 3.650738937656146
# Generation = 758
# Fitness    = 3.650738937656146
# Generation = 759
# Fitness    = 3.650738937656146
# Generation = 760
# Fitness    = 3.650738937656146
# Generation = 761
# Fitness    = 3.650738937656146
# Generation = 762
# Fitness    = 3.650738937656146
# Generation = 763
# Fitness    = 3.650738937656146
# Generation = 764
# Fitness    = 3.650738937656146
# Generation = 765
# Fitness    = 3.650738937656146
# Generation = 766
# Fitness    = 3.650738937656146
# Generation = 767
# Fitness    = 3.650738937656146
# Generation = 768
# Fitness    = 3.650738937656146
# Generation = 769
# Fitness    = 3.650738937656146
# Generation = 770
# Fitness    = 3.650738937656146
# Generation = 771
# Fitness    = 3.650738937656146
# Generation = 772
# Fitness    = 3.650738937656146
# Generation = 773
# Fitness    = 3.650738937656146
# Generation = 774
# Fitness    = 3.650738937656146
# Generation = 775
# Fitness    = 3.650738937656146
# Generation = 776
# Fitness    = 3.650738937656146
# Generation = 777
# Fitness    = 3.650738937656146
# Generation = 778
# Fitness    = 3.650738937656146
# Generation = 779
# Fitness    = 3.650738937656146
# Generation = 780
# Fitness    = 3.650738937656146
# Generation = 781
# Fitness    = 3.650738937656146
# Generation = 782
# Fitness    = 3.650738937656146
# Generation = 783
# Fitness    = 3.650738937656146
# Generation = 784
# Fitness    = 3.650738937656146
# Generation = 785
# Fitness    = 3.650738937656146
# Generation = 786
# Fitness    = 3.650738937656146
# Generation = 787
# Fitness    = 3.650738937656146
# Generation = 788
# Fitness    = 3.650738937656146
# Generation = 789
# Fitness    = 3.650738937656146
# Generation = 790
# Fitness    = 3.650738937656146
# Generation = 791
# Fitness    = 3.650738937656146
# Generation = 792
# Fitness    = 3.650738937656146
# Generation = 793
# Fitness    = 3.650738937656146
# Generation = 794
# Fitness    = 3.650738937656146
# Generation = 795
# Fitness    = 3.650738937656146
# Generation = 796
# Fitness    = 3.650738937656146
# Generation = 797
# Fitness    = 3.650738937656146
# Generation = 798
# Fitness    = 3.650738937656146
# Generation = 799
# Fitness    = 3.650738937656146
# Generation = 800
# Fitness    = 3.650738937656146
# Generation = 801
# Fitness    = 3.650738937656146
# Generation = 802
# Fitness    = 3.650738937656146
# Generation = 803
# Fitness    = 3.650738937656146
# Generation = 804
# Fitness    = 3.650738937656146
# Generation = 805
# Fitness    = 3.650738937656146
# Generation = 806
# Fitness    = 3.650738937656146
# Generation = 807
# Fitness    = 3.650738937656146
# Generation = 808
# Fitness    = 3.650738937656146
# Generation = 809
# Fitness    = 3.650738937656146
# Generation = 810
# Fitness    = 3.650738937656146
# Generation = 811
# Fitness    = 3.650738937656146
# Generation = 812
# Fitness    = 3.650738937656146
# Generation = 813
# Fitness    = 3.650738937656146
# Generation = 814
# Fitness    = 3.650738937656146
# Generation = 815
# Fitness    = 3.650738937656146
# Generation = 816
# Fitness    = 3.650738937656146
# Generation = 817
# Fitness    = 3.650738937656146
# Generation = 818
# Fitness    = 3.650738937656146
# Generation = 819
# Fitness    = 3.650738937656146
# Generation = 820
# Fitness    = 3.650738937656146
# Generation = 821
# Fitness    = 3.650738937656146
# Generation = 822
# Fitness    = 3.650738937656146
# Generation = 823
# Fitness    = 3.650738937656146
# Generation = 824
# Fitness    = 3.650738937656146
# Generation = 825
# Fitness    = 3.650738937656146
# Generation = 826
# Fitness    = 3.650738937656146
# Generation = 827
# Fitness    = 3.650738937656146
# Generation = 828
# Fitness    = 3.650738937656146
# Generation = 829
# Fitness    = 3.650738937656146
# Generation = 830
# Fitness    = 3.650738937656146
# Generation = 831
# Fitness    = 3.650738937656146
# Generation = 832
# Fitness    = 3.650738937656146
# Generation = 833
# Fitness    = 3.650738937656146
# Generation = 834
# Fitness    = 3.650738937656146
# Generation = 835
# Fitness    = 3.650738937656146
# Generation = 836
# Fitness    = 3.650738937656146
# Generation = 837
# Fitness    = 3.650738937656146
# Generation = 838
# Fitness    = 3.650738937656146
# Generation = 839
# Fitness    = 3.650738937656146
# Generation = 840
# Fitness    = 3.650738937656146
# Generation = 841
# Fitness    = 3.650738937656146
# Generation = 842
# Fitness    = 3.650738937656146
# Generation = 843
# Fitness    = 3.650738937656146
# Generation = 844
# Fitness    = 3.650738937656146
# Generation = 845
# Fitness    = 3.650738937656146
# Generation = 846
# Fitness    = 3.650738937656146
# Generation = 847
# Fitness    = 3.650738937656146
# Generation = 848
# Fitness    = 3.650738937656146
# Generation = 849
# Fitness    = 3.650738937656146
# Generation = 850
# Fitness    = 3.650738937656146
# Generation = 851
# Fitness    = 3.650738937656146
# Generation = 852
# Fitness    = 3.650738937656146
# Generation = 853
# Fitness    = 3.650738937656146
# Generation = 854
# Fitness    = 3.650738937656146
# Generation = 855
# Fitness    = 3.650738937656146
# Generation = 856
# Fitness    = 3.650738937656146
# Generation = 857
# Fitness    = 3.650738937656146
# Generation = 858
# Fitness    = 3.650738937656146
# Generation = 859
# Fitness    = 3.650738937656146
# Generation = 860
# Fitness    = 3.650738937656146
# Generation = 861
# Fitness    = 3.650738937656146
# Generation = 862
# Fitness    = 3.650738937656146
# Generation = 863
# Fitness    = 3.650738937656146
# Generation = 864
# Fitness    = 3.650738937656146
# Generation = 865
# Fitness    = 3.650738937656146
# Generation = 866
# Fitness    = 3.650738937656146
# Generation = 867
# Fitness    = 3.650738937656146
# Generation = 868
# Fitness    = 3.650738937656146
# Generation = 869
# Fitness    = 3.650738937656146
# Generation = 870
# Fitness    = 3.650738937656146
# Generation = 871
# Fitness    = 3.650738937656146
# Generation = 872
# Fitness    = 3.650738937656146
# Generation = 873
# Fitness    = 3.650738937656146
# Generation = 874
# Fitness    = 3.650738937656146
# Generation = 875
# Fitness    = 3.650738937656146
# Generation = 876
# Fitness    = 3.650738937656146
# Generation = 877
# Fitness    = 3.650738937656146
# Generation = 878
# Fitness    = 3.650738937656146
# Generation = 879
# Fitness    = 3.650738937656146
# Generation = 880
# Fitness    = 3.650738937656146
# Generation = 881
# Fitness    = 3.650738937656146
# Generation = 882
# Fitness    = 3.650738937656146
# Generation = 883
# Fitness    = 3.650738937656146
# Generation = 884
# Fitness    = 3.650738937656146
# Generation = 885
# Fitness    = 3.650738937656146
# Generation = 886
# Fitness    = 3.650738937656146
# Generation = 887
# Fitness    = 3.650738937656146
# Generation = 888
# Fitness    = 3.650738937656146
# Generation = 889
# Fitness    = 3.650738937656146
# Generation = 890
# Fitness    = 3.650738937656146
# Generation = 891
# Fitness    = 3.650738937656146
# Generation = 892
# Fitness    = 3.650738937656146
# Generation = 893
# Fitness    = 3.650738937656146
# Generation = 894
# Fitness    = 3.650738937656146
# Generation = 895
# Fitness    = 3.650738937656146
# Generation = 896
# Fitness    = 3.650738937656146
# Generation = 897
# Fitness    = 3.650738937656146
# Generation = 898
# Fitness    = 3.650738937656146
# Generation = 899
# Fitness    = 3.650738937656146
# Generation = 900
# Fitness    = 3.650738937656146
# Generation = 901
# Fitness    = 3.650738937656146
# Generation = 902
# Fitness    = 3.650738937656146
# Generation = 903
# Fitness    = 3.650738937656146
# Generation = 904
# Fitness    = 3.650738937656146
# Generation = 905
# Fitness    = 3.650738937656146
# Generation = 906
# Fitness    = 3.650738937656146
# Generation = 907
# Fitness    = 3.650738937656146
# Generation = 908
# Fitness    = 3.650738937656146
# Generation = 909
# Fitness    = 3.650738937656146
# Generation = 910
# Fitness    = 3.650738937656146
# Generation = 911
# Fitness    = 3.650738937656146
# Generation = 912
# Fitness    = 3.650738937656146
# Generation = 913
# Fitness    = 3.650738937656146
# Generation = 914
# Fitness    = 3.650738937656146
# Generation = 915
# Fitness    = 3.650738937656146
# Generation = 916
# Fitness    = 3.650738937656146
# Generation = 917
# Fitness    = 3.650738937656146
# Generation = 918
# Fitness    = 3.650738937656146
# Generation = 919
# Fitness    = 3.650738937656146
# Generation = 920
# Fitness    = 3.650738937656146
# Generation = 921
# Fitness    = 3.650738937656146
# Generation = 922
# Fitness    = 3.650738937656146
# Generation = 923
# Fitness    = 3.650738937656146
# Generation = 924
# Fitness    = 3.650738937656146
# Generation = 925
# Fitness    = 3.650738937656146
# Generation = 926
# Fitness    = 3.650738937656146
# Generation = 927
# Fitness    = 3.650738937656146
# Generation = 928
# Fitness    = 3.650738937656146
# Generation = 929
# Fitness    = 3.650738937656146
# Generation = 930
# Fitness    = 3.650738937656146
# Generation = 931
# Fitness    = 3.650738937656146
# Generation = 932
# Fitness    = 3.650738937656146
# Generation = 933
# Fitness    = 3.650738937656146
# Generation = 934
# Fitness    = 3.650738937656146
# Generation = 935
# Fitness    = 3.650738937656146
# Generation = 936
# Fitness    = 3.650738937656146
# Generation = 937
# Fitness    = 3.650738937656146
# Generation = 938
# Fitness    = 3.650738937656146
# Generation = 939
# Fitness    = 3.650738937656146
# Generation = 940
# Fitness    = 3.650738937656146
# Generation = 941
# Fitness    = 3.650738937656146
# Generation = 942
# Fitness    = 3.650738937656146
# Generation = 943
# Fitness    = 3.650738937656146
# Generation = 944
# Fitness    = 3.650738937656146
# Generation = 945
# Fitness    = 3.650738937656146
# Generation = 946
# Fitness    = 3.650738937656146
# Generation = 947
# Fitness    = 3.650738937656146
# Generation = 948
# Fitness    = 3.650738937656146
# Generation = 949
# Fitness    = 3.650738937656146
# Generation = 950
# Fitness    = 3.650738937656146
# Generation = 951
# Fitness    = 3.650738937656146
# Generation = 952
# Fitness    = 3.650738937656146
# Generation = 953
# Fitness    = 3.650738937656146
# Generation = 954
# Fitness    = 3.650738937656146
# Generation = 955
# Fitness    = 3.650738937656146
# Generation = 956
# Fitness    = 3.650738937656146
# Generation = 957
# Fitness    = 3.650738937656146
# Generation = 958
# Fitness    = 3.650738937656146
# Generation = 959
# Fitness    = 3.650738937656146
# Generation = 960
# Fitness    = 3.650738937656146
# Generation = 961
# Fitness    = 3.650738937656146
# Generation = 962
# Fitness    = 3.650738937656146
# Generation = 963
# Fitness    = 3.650738937656146
# Generation = 964
# Fitness    = 3.650738937656146
# Generation = 965
# Fitness    = 3.650738937656146
# Generation = 966
# Fitness    = 3.650738937656146
# Generation = 967
# Fitness    = 3.650738937656146
# Generation = 968
# Fitness    = 3.650738937656146
# Generation = 969
# Fitness    = 3.650738937656146
# Generation = 970
# Fitness    = 3.650738937656146
# Generation = 971
# Fitness    = 3.650738937656146
# Generation = 972
# Fitness    = 3.650738937656146
# Generation = 973
# Fitness    = 3.650738937656146
# Generation = 974
# Fitness    = 3.650738937656146
# Generation = 975
# Fitness    = 3.650738937656146
# Generation = 976
# Fitness    = 3.650738937656146
# Generation = 977
# Fitness    = 3.650738937656146
# Generation = 978
# Fitness    = 3.650738937656146
# Generation = 979
# Fitness    = 3.650738937656146
# Generation = 980
# Fitness    = 3.650738937656146
# Generation = 981
# Fitness    = 3.650738937656146
# Generation = 982
# Fitness    = 3.650738937656146
# Generation = 983
# Fitness    = 3.650738937656146
# Generation = 984
# Fitness    = 3.650738937656146
# Generation = 985
# Fitness    = 3.650738937656146
# Generation = 986
# Fitness    = 3.650738937656146
# Generation = 987
# Fitness    = 3.650738937656146
# Generation = 988
# Fitness    = 3.650738937656146
# Generation = 989
# Fitness    = 3.650738937656146
# Generation = 990
# Fitness    = 3.650738937656146
# Generation = 991
# Fitness    = 3.650738937656146
# Generation = 992
# Fitness    = 3.650738937656146
# Generation = 993
# Fitness    = 3.650738937656146
# Generation = 994
# Fitness    = 3.650738937656146
# Generation = 995
# Fitness    = 3.650738937656146
# Generation = 996
# Fitness    = 3.650738937656146
# ...
# Generation = 1175
# Fitness    = 3.650738937656146
# Generation = 1176
# Fitness    = 3.650738937656146
# Generation = 1177
# Fitness    = 3.650738937656146
# Generation = 1178
# Fitness    = 3.650738937656146
# Generation = 1179
# Fitness    = 3.650738937656146
# Generation = 1180
# Fitness    = 3.650738937656146
# Generation = 1181
# Fitness    = 3.650738937656146
# Generation = 1182
# Fitness    = 3.650738937656146
# Generation = 1183
# Fitness    = 3.650738937656146
# Generation = 1184
# Fitness    = 3.650738937656146
# Generation = 1185
# Fitness    = 3.650738937656146
# Generation = 1186
# Fitness    = 3.650738937656146
# Generation = 1187
# Fitness    = 3.650738937656146
# Generation = 1188
# Fitness    = 3.650738937656146
# Generation = 1189
# Fitness    = 3.650738937656146
# Generation = 1190
# Fitness    = 3.650738937656146
# Generation = 1191
# Fitness    = 3.650738937656146
# Generation = 1192
# Fitness    = 3.650738937656146
# Generation = 1193
# Fitness    = 3.650738937656146
# Generation = 1194
# Fitness    = 3.650738937656146
# Generation = 1195
# Fitness    = 3.650738937656146
# Generation = 1196
# Fitness    = 3.650738937656146
# Generation = 1197
# Fitness    = 3.650738937656146
# Generation = 1198
# Fitness    = 3.650738937656146
# Generation = 1199
# Fitness    = 3.650738937656146
# Generation = 1200
# Fitness    = 3.650738937656146
# Generation = 1201
# Fitness    = 3.650738937656146
# Generation = 1202
# Fitness    = 3.650738937656146
# Generation = 1203
# Fitness    = 3.650738937656146
# Generation = 1204
# Fitness    = 3.650738937656146
# Generation = 1205
# Fitness    = 3.650738937656146
# Generation = 1206
# Fitness    = 3.650738937656146
# Generation = 1207
# Fitness    = 3.650738937656146
# Generation = 1208
# Fitness    = 3.650738937656146
# Generation = 1209
# Fitness    = 3.650738937656146
# Generation = 1210
# Fitness    = 3.650738937656146
# Generation = 1211
# Fitness    = 3.650738937656146
# Generation = 1212
# Fitness    = 3.650738937656146
# Generation = 1213
# Fitness    = 3.650738937656146
# Generation = 1214
# Fitness    = 3.650738937656146
# Generation = 1215
# Fitness    = 3.650738937656146
# Generation = 1216
# Fitness    = 3.650738937656146
# Generation = 1217
# Fitness    = 3.650738937656146
# Generation = 1218
# Fitness    = 3.650738937656146
# Generation = 1219
# Fitness    = 3.650738937656146
# Generation = 1220
# Fitness    = 3.650738937656146
# Generation = 1221
# Fitness    = 3.650738937656146
# Generation = 1222
# Fitness    = 3.650738937656146
# Generation = 1223
# Fitness    = 3.650738937656146
# Generation = 1224
# Fitness    = 3.650738937656146
# Generation = 1225
# Fitness    = 3.650738937656146
# Generation = 1226
# Fitness    = 3.650738937656146
# Generation = 1227
# Fitness    = 3.650738937656146
# Generation = 1228
# Fitness    = 3.650738937656146
# Generation = 1229
# Fitness    = 3.650738937656146
# Generation = 1230
# Fitness    = 3.650738937656146
# Generation = 1231
# Fitness    = 3.650738937656146
# Generation = 1232
# Fitness    = 3.650738937656146
# Generation = 1233
# Fitness    = 3.650738937656146
# Generation = 1234
# Fitness    = 3.650738937656146
# Generation = 1235
# Fitness    = 3.650738937656146
# Generation = 1236
# Fitness    = 3.650738937656146
# Generation = 1237
# Fitness    = 3.650738937656146
# Generation = 1238
# Fitness    = 3.650738937656146
# Generation = 1239
# Fitness    = 3.650738937656146
# Generation = 1240
# Fitness    = 3.650738937656146
# Generation = 1241
# Fitness    = 3.650738937656146
# Generation = 1242
# Fitness    = 3.650738937656146
# Generation = 1243
# Fitness    = 3.650738937656146
# Generation = 1244
# Fitness    = 3.650738937656146
# Generation = 1245
# Fitness    = 3.650738937656146
# Generation = 1246
# Fitness    = 3.650738937656146
# Generation = 1247
# Fitness    = 3.650738937656146
# Generation = 1248
# Fitness    = 3.650738937656146
# Generation = 1249
# Fitness    = 3.650738937656146
# Generation = 1250
# Fitness    = 3.650738937656146
# Generation = 1251
# Fitness    = 3.650738937656146
# Generation = 1252
# Fitness    = 3.650738937656146
# Generation = 1253
# Fitness    = 3.650738937656146
# Generation = 1254
# Fitness    = 3.650738937656146
# Generation = 1255
# Fitness    = 3.650738937656146
# Generation = 1256
# Fitness    = 3.650738937656146
# Generation = 1257
# Fitness    = 3.650738937656146
# Generation = 1258
# Fitness    = 3.650738937656146
# Generation = 1259
# Fitness    = 3.650738937656146
# Generation = 1260
# Fitness    = 3.650738937656146
# Generation = 1261
# Fitness    = 3.650738937656146
# Generation = 1262
# Fitness    = 3.650738937656146
# Generation = 1263
# Fitness    = 3.650738937656146
# Generation = 1264
# Fitness    = 3.650738937656146
# Generation = 1265
# Fitness    = 3.650738937656146
# Generation = 1266
# Fitness    = 3.650738937656146
# Generation = 1267
# Fitness    = 3.650738937656146
# Generation = 1268
# Fitness    = 3.650738937656146
# Generation = 1269
# Fitness    = 3.650738937656146
# Generation = 1270
# Fitness    = 3.650738937656146
# Generation = 1271
# Fitness    = 3.650738937656146
# Generation = 1272
# Fitness    = 3.650738937656146
# Generation = 1273
# Fitness    = 3.650738937656146
# Generation = 1274
# Fitness    = 3.650738937656146
# Generation = 1275
# Fitness    = 3.650738937656146
# Generation = 1276
# Fitness    = 3.650738937656146
# Generation = 1277
# Fitness    = 3.650738937656146
# Generation = 1278
# Fitness    = 3.650738937656146
# Generation = 1279
# Fitness    = 3.650738937656146
# Generation = 1280
# Fitness    = 3.650738937656146
# Generation = 1281
# Fitness    = 3.650738937656146
# Generation = 1282
# Fitness    = 3.650738937656146
# Generation = 1283
# Fitness    = 3.650738937656146
# Generation = 1284
# Fitness    = 3.650738937656146
# Generation = 1285
# Fitness    = 3.650738937656146
# Generation = 1286
# Fitness    = 3.650738937656146
# Generation = 1287
# Fitness    = 3.650738937656146
# Generation = 1288
# Fitness    = 3.650738937656146
# Generation = 1289
# Fitness    = 3.650738937656146
# Generation = 1290
# Fitness    = 3.650738937656146
# Generation = 1291
# Fitness    = 3.650738937656146
# Generation = 1292
# Fitness    = 3.650738937656146
# Generation = 1293
# Fitness    = 3.650738937656146
# Generation = 1294
# Fitness    = 3.650738937656146
# Generation = 1295
# Fitness    = 3.650738937656146
# Generation = 1296
# Fitness    = 3.650738937656146
# Generation = 1297
# Fitness    = 3.650738937656146
# Generation = 1298
# Fitness    = 3.650738937656146
# Generation = 1299
# Fitness    = 3.650738937656146
# Generation = 1300
# Fitness    = 3.650738937656146
# Generation = 1301
# Fitness    = 3.650738937656146
# Generation = 1302
# Fitness    = 3.650738937656146
# Generation = 1303
# Fitness    = 3.650738937656146
# Generation = 1304
# Fitness    = 3.650738937656146
# Generation = 1305
# Fitness    = 3.650738937656146
# Generation = 1306
# Fitness    = 3.650738937656146
# Generation = 1307
# Fitness    = 3.650738937656146
# Generation = 1308
# Fitness    = 3.650738937656146
# Generation = 1309
# Fitness    = 3.650738937656146
# Generation = 1310
# Fitness    = 3.650738937656146
# Generation = 1311
# Fitness    = 3.650738937656146
# Generation = 1312
# Fitness    = 3.650738937656146
# Generation = 1313
# Fitness    = 3.650738937656146
# Generation = 1314
# Fitness    = 3.650738937656146
# Generation = 1315
# Fitness    = 3.650738937656146
# Generation = 1316
# Fitness    = 3.650738937656146
# Generation = 1317
# Fitness    = 3.650738937656146
# Generation = 1318
# Fitness    = 3.650738937656146
# Generation = 1319
# Fitness    = 3.650738937656146
# Generation = 1320
# Fitness    = 3.650738937656146
# Generation = 1321
# Fitness    = 3.650738937656146
# Generation = 1322
# Fitness    = 3.650738937656146
# Generation = 1323
# Fitness    = 3.650738937656146
# Generation = 1324
# Fitness    = 3.650738937656146
# Generation = 1325
# Fitness    = 3.650738937656146
# Generation = 1326
# Fitness    = 3.650738937656146
# Generation = 1327
# Fitness    = 3.650738937656146
# Generation = 1328
# Fitness    = 3.650738937656146
# Generation = 1329
# Fitness    = 3.650738937656146
# Generation = 1330
# Fitness    = 3.650738937656146
# Generation = 1331
# Fitness    = 3.650738937656146
# Generation = 1332
# Fitness    = 3.650738937656146
# Generation = 1333
# Fitness    = 3.650738937656146
# Generation = 1334
# Fitness    = 3.650738937656146
# Generation = 1335
# Fitness    = 3.650738937656146
# Generation = 1336
# Fitness    = 3.650738937656146
# Generation = 1337
# Fitness    = 3.650738937656146
# Generation = 1338
# Fitness    = 3.650738937656146
# Generation = 1339
# Fitness    = 3.650738937656146
# Generation = 1340
# Fitness    = 3.650738937656146
# Generation = 1341
# Fitness    = 3.650738937656146
# Generation = 1342
# Fitness    = 3.650738937656146
# Generation = 1343
# Fitness    = 3.650738937656146
# Generation = 1344
# Fitness    = 3.650738937656146
# Generation = 1345
# Fitness    = 3.650738937656146
# Generation = 1346
# Fitness    = 3.650738937656146
# Generation = 1347
# Fitness    = 3.650738937656146
# Generation = 1348
# Fitness    = 3.650738937656146
# Generation = 1349
# Fitness    = 3.650738937656146
# Generation = 1350
# Fitness    = 3.650738937656146
# Generation = 1351
# Fitness    = 3.650738937656146
# Generation = 1352
# Fitness    = 3.650738937656146
# Generation = 1353
# Fitness    = 3.650738937656146
# Generation = 1354
# Fitness    = 3.650738937656146
# Generation = 1355
# Fitness    = 3.650738937656146
# Generation = 1356
# Fitness    = 3.650738937656146
# Generation = 1357
# Fitness    = 3.650738937656146
# Generation = 1358
# Fitness    = 3.650738937656146
# Generation = 1359
# Fitness    = 3.650738937656146
# Generation = 1360
# Fitness    = 3.650738937656146
# Generation = 1361
# Fitness    = 3.650738937656146
# Generation = 1362
# Fitness    = 3.650738937656146
# Generation = 1363
# Fitness    = 3.650738937656146
# Generation = 1364
# Fitness    = 3.650738937656146
# Generation = 1365
# Fitness    = 3.650738937656146
# Generation = 1366
# Fitness    = 3.650738937656146
# Generation = 1367
# Fitness    = 3.650738937656146
# Generation = 1368
# Fitness    = 3.650738937656146
# Generation = 1369
# Fitness    = 3.650738937656146
# Generation = 1370
# Fitness    = 3.650738937656146
# Generation = 1371
# Fitness    = 3.650738937656146
# Generation = 1372
# Fitness    = 3.650738937656146
# Generation = 1373
# Fitness    = 3.650738937656146
# Generation = 1374
# Fitness    = 3.650738937656146
# Generation = 1375
# Fitness    = 3.650738937656146
# Generation = 1376
# Fitness    = 3.650738937656146
# Generation = 1377
# Fitness    = 3.650738937656146
# Generation = 1378
# Fitness    = 3.650738937656146
# Generation = 1379
# Fitness    = 3.650738937656146
# Generation = 1380
# Fitness    = 3.650738937656146
# Generation = 1381
# Fitness    = 3.650738937656146
# Generation = 1382
# Fitness    = 3.650738937656146
# Generation = 1383
# Fitness    = 3.650738937656146
# Generation = 1384
# Fitness    = 3.650738937656146
# Generation = 1385
# Fitness    = 3.650738937656146
# Generation = 1386
# Fitness    = 3.650738937656146
# Generation = 1387
# Fitness    = 3.650738937656146
# Generation = 1388
# Fitness    = 3.650738937656146
# Generation = 1389
# Fitness    = 3.650738937656146
# Generation = 1390
# Fitness    = 3.650738937656146
# Generation = 1391
# Fitness    = 3.650738937656146
# Generation = 1392
# Fitness    = 3.650738937656146
# Generation = 1393
# Fitness    = 3.650738937656146
# Generation = 1394
# Fitness    = 3.650738937656146
# Generation = 1395
# Fitness    = 3.650738937656146
# Generation = 1396
# Fitness    = 3.650738937656146
# Generation = 1397
# Fitness    = 3.650738937656146
# Generation = 1398
# Fitness    = 3.650738937656146
# Generation = 1399
# Fitness    = 3.650738937656146
# Generation = 1400
# Fitness    = 3.650738937656146
# Generation = 1401
# Fitness    = 3.650738937656146
# Generation = 1402
# Fitness    = 3.650738937656146
# Generation = 1403
# Fitness    = 3.650738937656146
# Generation = 1404
# Fitness    = 3.650738937656146
# Generation = 1405
# Fitness    = 3.650738937656146
# Generation = 1406
# Fitness    = 3.650738937656146
# Generation = 1407
# Fitness    = 3.650738937656146
# Generation = 1408
# Fitness    = 3.650738937656146
# Generation = 1409
# Fitness    = 3.650738937656146
# Generation = 1410
# Fitness    = 3.650738937656146
# Generation = 1411
# Fitness    = 3.650738937656146
# Generation = 1412
# Fitness    = 3.650738937656146
# Generation = 1413
# Fitness    = 3.650738937656146
# Generation = 1414
# Fitness    = 3.650738937656146
# Generation = 1415
# Fitness    = 3.650738937656146
# Generation = 1416
# Fitness    = 3.650738937656146
# Generation = 1417
# Fitness    = 3.650738937656146
# Generation = 1418
# Fitness    = 3.650738937656146
# Generation = 1419
# Fitness    = 3.650738937656146
# Generation = 1420
# Fitness    = 3.650738937656146
# Generation = 1421
# Fitness    = 3.650738937656146
# Generation = 1422
# Fitness    = 3.650738937656146
# Generation = 1423
# Fitness    = 3.650738937656146
# Generation = 1424
# Fitness    = 3.650738937656146
# Generation = 1425
# Fitness    = 3.650738937656146
# Generation = 1426
# Fitness    = 3.650738937656146
# Generation = 1427
# Fitness    = 3.650738937656146
# Generation = 1428
# Fitness    = 3.650738937656146
# Generation = 1429
# Fitness    = 3.650738937656146
# Generation = 1430
# Fitness    = 3.650738937656146
# Generation = 1431
# Fitness    = 3.650738937656146
# Generation = 1432
# Fitness    = 3.650738937656146
# Generation = 1433
# Fitness    = 3.650738937656146
# Generation = 1434
# Fitness    = 3.650738937656146
# Generation = 1435
# Fitness    = 3.650738937656146
# Generation = 1436
# Fitness    = 3.650738937656146
# Generation = 1437
# Fitness    = 3.650738937656146
# Generation = 1438
# Fitness    = 3.650738937656146
# Generation = 1439
# Fitness    = 3.650738937656146
# Generation = 1440
# Fitness    = 3.650738937656146
# Generation = 1441
# Fitness    = 3.650738937656146
# Generation = 1442
# Fitness    = 3.650738937656146
# Generation = 1443
# Fitness    = 3.650738937656146
# Generation = 1444
# Fitness    = 3.650738937656146
# Generation = 1445
# Fitness    = 3.650738937656146
# Generation = 1446
# Fitness    = 3.650738937656146
# Generation = 1447
# Fitness    = 3.650738937656146
# Generation = 1448
# Fitness    = 3.650738937656146
# Generation = 1449
# Fitness    = 3.650738937656146
# Generation = 1450
# Fitness    = 3.650738937656146
# Generation = 1451
# Fitness    = 3.650738937656146
# Generation = 1452
# Fitness    = 3.650738937656146
# Generation = 1453
# Fitness    = 3.650738937656146
# Generation = 1454
# Fitness    = 3.650738937656146
# Generation = 1455
# Fitness    = 3.650738937656146
# Generation = 1456
# Fitness    = 3.650738937656146
# Generation = 1457
# Fitness    = 3.650738937656146
# Generation = 1458
# Fitness    = 3.650738937656146
# Generation = 1459
# Fitness    = 3.650738937656146
# Generation = 1460
# Fitness    = 3.650738937656146
# Generation = 1461
# Fitness    = 3.650738937656146
# Generation = 1462
# Fitness    = 3.650738937656146
# Generation = 1463
# Fitness    = 3.650738937656146
# Generation = 1464
# Fitness    = 3.650738937656146
# Generation = 1465
# Fitness    = 3.650738937656146
# Generation = 1466
# Fitness    = 3.650738937656146
# Generation = 1467
# Fitness    = 3.650738937656146
# Generation = 1468
# Fitness    = 3.650738937656146
# Generation = 1469
# Fitness    = 3.650738937656146
# Generation = 1470
# Fitness    = 3.650738937656146
# Generation = 1471
# Fitness    = 3.650738937656146
# Generation = 1472
# Fitness    = 3.650738937656146
# Generation = 1473
# Fitness    = 3.650738937656146
# Generation = 1474
# Fitness    = 3.650738937656146
# Generation = 1475
# Fitness    = 3.650738937656146
# Generation = 1476
# Fitness    = 3.650738937656146
# Generation = 1477
# Fitness    = 3.650738937656146
# Generation = 1478
# Fitness    = 3.650738937656146
# Generation = 1479
# Fitness    = 3.650738937656146
# Generation = 1480
# Fitness    = 3.650738937656146
# Generation = 1481
# Fitness    = 3.650738937656146
# Generation = 1482
# Fitness    = 3.650738937656146
# Generation = 1483
# Fitness    = 3.650738937656146
# Generation = 1484
# Fitness    = 3.650738937656146
# Generation = 1485
# Fitness    = 3.650738937656146
# Generation = 1486
# Fitness    = 3.650738937656146
# Generation = 1487
# Fitness    = 3.650738937656146
# Generation = 1488
# Fitness    = 3.650738937656146
# Generation = 1489
# Fitness    = 3.650738937656146
# Generation = 1490
# Fitness    = 3.650738937656146
# Generation = 1491
# Fitness    = 3.650738937656146
# Generation = 1492
# Fitness    = 3.650738937656146
# Generation = 1493
# Fitness    = 3.650738937656146
# Generation = 1494
# Fitness    = 3.650738937656146
# Generation = 1495
# Fitness    = 3.650738937656146
# Generation = 1496
# Fitness    = 3.650738937656146
# Generation = 1497
# Fitness    = 3.650738937656146
# Generation = 1498
# Fitness    = 3.650738937656146
# Generation = 1499
# Fitness    = 3.650738937656146
# Generation = 1500
# Fitness    = 3.650738937656146

# %%
ga_instance.plot_result(title="PyGAD & Keras - Iteration vs. Fitness", linewidth=4)

# %%
solution, solution_fitness, solution_idx = ga_instance.best_solution()
print("Fitness value of the best solution = {solution_fitness}".format(solution_fitness=solution_fitness))
print("Index of the best solution : {solution_idx}".format(solution_idx=solution_idx))
# Out:
# Fitness value of the best solution = 3.650738937656146
# Index of the best solution : 0

# %% [markdown]
# ### Fetch the parameters of the best solution.

# %%
np.set_printoptions(suppress=True)

# %%
best_solution_weights = pygad.kerasga.model_weights_as_matrix(model=model,
                                                              weights_vector=solution)
model.set_weights(best_solution_weights)
predictions = model.predict(X_test_scaled)
predictions = scaler.inverse_transform(predictions)
predictions = np.round(predictions, 2)
# print("Predictions : \n", predictions)

# %% [markdown]
# # 6. Inference

# %%
X_test_np = X_test.values.astype(int)
y_test_np = y_test.values.astype(int)
X_test_np = convert_to_tensor(X_test_np)
y_test_np = convert_to_tensor(y_test_np)

# %%
student_index = 14
g_truth = float(y_test_np[student_index])
p = float(predictions[student_index])
print("Real Values :", g_truth)
print("Predicted G3's score is {:.2f}".format(p))
diff = np.abs(p-g_truth)
print("Difference : {:.3f}".format(diff))
# Out:
# Real Values : 16.0
# Predicted G3's score is 8.27
# Difference : 7.730

# %% [markdown]
# #### On Test Set/Unseen Data, manually:

# %%
diff_list = []

for i in range(0,len(y_test)):
    
    g_truth = float(y_test_np[i])
    p = float(predictions[i])
    diff = np.abs(p-g_truth)
    diff_list.append(diff)
    print(i)  
    print("Real Values :", g_truth)
    print("Predicted G3's score is {:.2f}".format(p))
    print("Difference : {:.3f}".format(diff))
# Out:
# 0
# Real Values : 14.0
# Predicted G3's score is 12.00
# Difference : 2.000
# 1
# Real Values : 12.0
# Predicted G3's score is 13.48
# Difference : 1.480
# 2
# Real Values : 10.0
# Predicted G3's score is 13.75
# Difference : 3.750
# 3
# Real Values : 19.0
# Predicted G3's score is 9.86
# Difference : 9.140
# 4
# Real Values : 13.0
# Predicted G3's score is 12.75
# Difference : 0.250
# 5
# Real Values : 15.0
# Predicted G3's score is 15.88
# Difference : 0.880
# 6
# Real Values : 10.0
# Predicted G3's score is 15.34
# Difference : 5.340
# 7
# Real Values : 11.0
# Predicted G3's score is 9.65
# Difference : 1.350
# 8
# Real Values : 11.0
# Predicted G3's score is 9.20
# Difference : 1.800
# 9
# Real Values : 11.0
# Predicted G3's score is 12.43
# Difference : 1.430
# 10
# Real Values : 15.0
# Predicted G3's score is 10.21
# Difference : 4.790
# 11
# Real Values : 16.0
# Predicted G3's score is 12.65
# Difference : 3.350
# 12
# Real Values : 10.0
# Predicted G3's score is 14.80
# Difference : 4.800
# 13
# Real Values : 11.0
# Predicted G3's score is 12.53
# Difference : 1.530
# 14
# Real Values : 16.0
# Predicted G3's score is 8.27
# Difference : 7.730
# 15
# Real Values : 6.0
# Predicted G3's score is 13.14
# Difference : 7.140
# 16
# Real Values : 10.0
# Predicted G3's score is 11.95
# Difference : 1.950
# 17
# Real Values : 13.0
# Predicted G3's score is 10.62
# Difference : 2.380
# 18
# Real Values : 14.0
# Predicted G3's score is 10.01
# Difference : 3.990
# 19
# Real Values : 12.0
# Predicted G3's score is 10.36
# Difference : 1.640
# 20
# Real Values : 9.0
# Predicted G3's score is 9.94
# Difference : 0.940
# 21
# Real Values : 11.0
# Predicted G3's score is 16.92
# Difference : 5.920
# 22
# Real Values : 10.0
# Predicted G3's score is 14.36
# Difference : 4.360
# 23
# Real Values : 17.0
# Predicted G3's score is 12.56
# Difference : 4.440
# 24
# Real Values : 9.0
# Predicted G3's score is 9.55
# Difference : 0.550
# 25
# Real Values : 14.0
# Predicted G3's score is 8.53
# Difference : 5.470
# 26
# Real Values : 11.0
# Predicted G3's score is 17.17
# Difference : 6.170
# 27
# Real Values : 13.0
# Predicted G3's score is 15.98
# Difference : 2.980
# 28
# Real Values : 13.0
# Predicted G3's score is 12.13
# Difference : 0.870
# 29
# Real Values : 10.0
# Predicted G3's score is 14.12
# Difference : 4.120
# 30
# Real Values : 8.0
# Predicted G3's score is 15.23
# Difference : 7.230
# 31
# Real Values : 16.0
# Predicted G3's score is 22.78
# Difference : 6.780
# 32
# Real Values : 8.0
# Predicted G3's score is 13.50
# Difference : 5.500
# 33
# Real Values : 15.0
# Predicted G3's score is 18.40
# Difference : 3.400
# 34
# Real Values : 10.0
# Predicted G3's score is 15.29
# Difference : 5.290
# 35
# Real Values : 14.0
# Predicted G3's score is 15.64
# Difference : 1.640
# 36
# Real Values : 14.0
# Predicted G3's score is 18.85
# Difference : 4.850
# 37
# Real Values : 11.0
# Predicted G3's score is 3.42
# Difference : 7.580
# 38
# Real Values : 10.0
# Predicted G3's score is 7.58
# Difference : 2.420
# 39
# Real Values : 13.0
# Predicted G3's score is 9.38
# Difference : 3.620
# 40
# Real Values : 13.0
# Predicted G3's score is 19.70
# Difference : 6.700
# 41
# Real Values : 17.0
# Predicted G3's score is 13.38
# Difference : 3.620
# 42
# Real Values : 12.0
# Predicted G3's score is 11.88
# Difference : 0.120
# 43
# Real Values : 14.0
# Predicted G3's score is 17.83
# Difference : 3.830
# 44
# Real Values : 10.0
# Predicted G3's score is 16.50
# Difference : 6.500
# 45
# Real Values : 12.0
# Predicted G3's score is 8.70
# Difference : 3.300
# 46
# Real Values : 14.0
# Predicted G3's score is 14.88
# Difference : 0.880
# 47
# Real Values : 13.0
# Predicted G3's score is 7.38
# Difference : 5.620
# 48
# Real Values : 10.0
# Predicted G3's score is 17.06
# Difference : 7.060
# 49
# Real Values : 13.0
# Predicted G3's score is 16.91
# Difference : 3.910
# 50
# Real Values : 17.0
# Predicted G3's score is 12.73
# Difference : 4.270
# 51
# Real Values : 10.0
# Predicted G3's score is 14.42
# Difference : 4.420
# 52
# Real Values : 11.0
# Predicted G3's score is 15.72
# Difference : 4.720
# 53
# Real Values : 11.0
# Predicted G3's score is 6.26
# Difference : 4.740
# 54
# Real Values : 8.0
# Predicted G3's score is 10.47
# Difference : 2.470
# 55
# Real Values : 10.0
# Predicted G3's score is 14.11
# Difference : 4.110
# 56
# Real Values : 17.0
# Predicted G3's score is 15.34
# Difference : 1.660
# 57
# Real Values : 12.0
# Predicted G3's score is 12.27
# Difference : 0.270
# 58
# Real Values : 12.0
# Predicted G3's score is 18.67
# Difference : 6.670
# 59
# Real Values : 11.0
# Predicted G3's score is 9.66
# Difference : 1.340
# 60
# Real Values : 15.0
# Predicted G3's score is 15.03
# Difference : 0.030
# 61
# Real Values : 10.0
# Predicted G3's score is 16.84
# Difference : 6.840
# 62
# Real Values : 10.0
# Predicted G3's score is 10.06
# Difference : 0.060
# 63
# Real Values : 11.0
# Predicted G3's score is 16.22
# Difference : 5.220
# 64
# Real Values : 12.0
# Predicted G3's score is 10.29
# Difference : 1.710
# 65
# Real Values : 14.0
# Predicted G3's score is 11.88
# Difference : 2.120
# 66
# Real Values : 12.0
# Predicted G3's score is 17.15
# Difference : 5.150
# 67
# Real Values : 10.0
# Predicted G3's score is 11.96
# Difference : 1.960
# 68
# Real Values : 13.0
# Predicted G3's score is 16.68
# Difference : 3.680
# 69
# Real Values : 10.0
# Predicted G3's score is 12.58
# Difference : 2.580
# 70
# Real Values : 12.0
# Predicted G3's score is 21.57
# Difference : 9.570
# 71
# Real Values : 14.0
# Predicted G3's score is 13.06
# Difference : 0.940
# 72
# Real Values : 11.0
# Predicted G3's score is 12.95
# Difference : 1.950
# 73
# Real Values : 11.0
# Predicted G3's score is 21.24
# Difference : 10.240
# 74
# Real Values : 16.0
# Predicted G3's score is 17.85
# Difference : 1.850
# 75
# Real Values : 18.0
# Predicted G3's score is 11.53
# Difference : 6.470
# 76
# Real Values : 11.0
# Predicted G3's score is 17.26
# Difference : 6.260
# 77
# Real Values : 16.0
# Predicted G3's score is 15.53
# Difference : 0.470
# 78
# Real Values : 16.0
# Predicted G3's score is 14.57
# Difference : 1.430
# 79
# Real Values : 13.0
# Predicted G3's score is 15.30
# Difference : 2.300
# 80
# Real Values : 13.0
# Predicted G3's score is 12.03
# Difference : 0.970
# 81
# Real Values : 18.0
# Predicted G3's score is 10.84
# Difference : 7.160
# 82
# Real Values : 12.0
# Predicted G3's score is 16.46
# Difference : 4.460
# 83
# Real Values : 16.0
# Predicted G3's score is 13.15
# Difference : 2.850
# 84
# Real Values : 14.0
# Predicted G3's score is 9.64
# Difference : 4.360
# 85
# Real Values : 9.0
# Predicted G3's score is 13.28
# Difference : 4.280
# 86
# Real Values : 18.0
# Predicted G3's score is 16.27
# Difference : 1.730
# 87
# Real Values : 13.0
# Predicted G3's score is 11.89
# Difference : 1.110
# 88
# Real Values : 10.0
# Predicted G3's score is 15.78
# Difference : 5.780
# 89
# Real Values : 13.0
# Predicted G3's score is 12.13
# Difference : 0.870
# 90
# Real Values : 10.0
# Predicted G3's score is 12.06
# Difference : 2.060
# 91
# Real Values : 8.0
# Predicted G3's score is 7.35
# Difference : 0.650
# 92
# Real Values : 16.0
# Predicted G3's score is 12.55
# Difference : 3.450
# 93
# Real Values : 12.0
# Predicted G3's score is 15.99
# Difference : 3.990
# 94
# Real Values : 12.0
# Predicted G3's score is 9.99
# Difference : 2.010
# 95
# Real Values : 11.0
# Predicted G3's score is 18.52
# Difference : 7.520
# 96
# Real Values : 16.0
# Predicted G3's score is 10.06
# Difference : 5.940
# 97
# Real Values : 9.0
# Predicted G3's score is 8.71
# Difference : 0.290
# 98
# Real Values : 17.0
# Predicted G3's score is 11.68
# Difference : 5.320
# 99
# Real Values : 14.0
# Predicted G3's score is 11.31
# Difference : 2.690
# 100
# Real Values : 8.0
# Predicted G3's score is 12.80
# Difference : 4.800
# 101
# Real Values : 11.0
# Predicted G3's score is 10.33
# Difference : 0.670
# 102
# Real Values : 11.0
# Predicted G3's score is 15.71
# Difference : 4.710
# 103
# Real Values : 15.0
# Predicted G3's score is 13.73
# Difference : 1.270
# 104
# Real Values : 13.0
# Predicted G3's score is 5.12
# Difference : 7.880
# 105
# Real Values : 9.0
# Predicted G3's score is 9.62
# Difference : 0.620
# 106
# Real Values : 13.0
# Predicted G3's score is 11.39
# Difference : 1.610
# 107
# Real Values : 9.0
# Predicted G3's score is 17.08
# Difference : 8.080
# 108
# Real Values : 13.0
# Predicted G3's score is 8.62
# Difference : 4.380
# 109
# Real Values : 11.0
# Predicted G3's score is 18.72
# Difference : 7.720
# 110
# Real Values : 15.0
# Predicted G3's score is 10.79
# Difference : 4.210
# 111
# Real Values : 10.0
# Predicted G3's score is 16.32
# Difference : 6.320
# 112
# Real Values : 12.0
# Predicted G3's score is 11.39
# Difference : 0.610
# 113
# Real Values : 13.0
# Predicted G3's score is 11.34
# Difference : 1.660
# 114
# Real Values : 16.0
# Predicted G3's score is 12.96
# Difference : 3.040
# 115
# Real Values : 9.0
# Predicted G3's score is 9.63
# Difference : 0.630
# 116
# Real Values : 9.0
# Predicted G3's score is 20.11
# Difference : 11.110
# 117
# Real Values : 12.0
# Predicted G3's score is 13.00
# Difference : 1.000
# 118
# Real Values : 15.0
# Predicted G3's score is 16.87
# Difference : 1.870
# 119
# Real Values : 10.0
# Predicted G3's score is 13.67
# Difference : 3.670
# 120
# Real Values : 10.0
# Predicted G3's score is 14.22
# Difference : 4.220
# 121
# Real Values : 13.0
# Predicted G3's score is 16.76
# Difference : 3.760
# 122
# Real Values : 17.0
# Predicted G3's score is 10.55
# Difference : 6.450
# 123
# Real Values : 15.0
# Predicted G3's score is 12.12
# Difference : 2.880
# 124
# Real Values : 9.0
# Predicted G3's score is 14.68
# Difference : 5.680
# 125
# Real Values : 11.0
# Predicted G3's score is 9.02
# Difference : 1.980
# 126
# Real Values : 13.0
# Predicted G3's score is 18.57
# Difference : 5.570
# 127
# Real Values : 10.0
# Predicted G3's score is 14.58
# Difference : 4.580
# 128
# Real Values : 13.0
# Predicted G3's score is 3.37
# Difference : 9.630
# 129
# Real Values : 11.0
# Predicted G3's score is 11.33
# Difference : 0.330
# 130
# Real Values : 14.0
# Predicted G3's score is 16.27
# Difference : 2.270
# 131
# Real Values : 13.0
# Predicted G3's score is 19.24
# Difference : 6.240
# 132
# Real Values : 11.0
# Predicted G3's score is 13.34
# Difference : 2.340
# 133
# Real Values : 15.0
# Predicted G3's score is 18.93
# Difference : 3.930
# 134
# Real Values : 11.0
# Predicted G3's score is 17.91
# Difference : 6.910
# 135
# Real Values : 16.0
# Predicted G3's score is 13.55
# Difference : 2.450
# 136
# Real Values : 12.0
# Predicted G3's score is 18.03
# Difference : 6.030
# 137
# Real Values : 11.0
# Predicted G3's score is 18.13
# Difference : 7.130
# 138
# Real Values : 14.0
# Predicted G3's score is 13.48
# Difference : 0.520
# 139
# Real Values : 10.0
# Predicted G3's score is 18.01
# Difference : 8.010
# 140
# Real Values : 15.0
# Predicted G3's score is 16.05
# Difference : 1.050
# 141
# Real Values : 10.0
# Predicted G3's score is 12.71
# Difference : 2.710
# 142
# Real Values : 13.0
# Predicted G3's score is 10.46
# Difference : 2.540
# 143
# Real Values : 11.0
# Predicted G3's score is 7.89
# Difference : 3.110
# 144
# Real Values : 17.0
# Predicted G3's score is 14.37
# Difference : 2.630
# 145
# Real Values : 11.0
# Predicted G3's score is 8.48
# Difference : 2.520
# 146
# Real Values : 14.0
# Predicted G3's score is 14.32
# Difference : 0.320
# 147
# Real Values : 11.0
# Predicted G3's score is 12.21
# Difference : 1.210
# 148
# Real Values : 12.0
# Predicted G3's score is 9.44
# Difference : 2.560
# 149
# Real Values : 15.0
# Predicted G3's score is 12.92
# Difference : 2.080
# 150
# Real Values : 13.0
# Predicted G3's score is 11.92
# Difference : 1.080
# 151
# Real Values : 14.0
# Predicted G3's score is 18.31
# Difference : 4.310
# 152
# Real Values : 14.0
# Predicted G3's score is 15.20
# Difference : 1.200
# 153
# Real Values : 7.0
# Predicted G3's score is 2.49
# Difference : 4.510
# 154
# Real Values : 18.0
# Predicted G3's score is 15.72
# Difference : 2.280
# 155
# Real Values : 6.0
# Predicted G3's score is 16.99
# Difference : 10.990
# 156
# Real Values : 14.0
# Predicted G3's score is 12.01
# Difference : 1.990
# 157
# Real Values : 16.0
# Predicted G3's score is 6.71
# Difference : 9.290
# 158
# Real Values : 13.0
# Predicted G3's score is 10.46
# Difference : 2.540
# 159
# Real Values : 14.0
# Predicted G3's score is 12.16
# Difference : 1.840
# 160
# Real Values : 13.0
# Predicted G3's score is 11.32
# Difference : 1.680
# 161
# Real Values : 18.0
# Predicted G3's score is 13.85
# Difference : 4.150
# 162
# Real Values : 16.0
# Predicted G3's score is 7.52
# Difference : 8.480
# 163
# Real Values : 15.0
# Predicted G3's score is 9.84
# Difference : 5.160
# 164
# Real Values : 11.0
# Predicted G3's score is 13.24
# Difference : 2.240
# 165
# Real Values : 9.0
# Predicted G3's score is 7.57
# Difference : 1.430
# 166
# Real Values : 11.0
# Predicted G3's score is 10.86
# Difference : 0.140
# 167
# Real Values : 15.0
# Predicted G3's score is 6.77
# Difference : 8.230
# 168
# Real Values : 13.0
# Predicted G3's score is 8.87
# Difference : 4.130
# 169
# Real Values : 16.0
# Predicted G3's score is 12.40
# Difference : 3.600
# 170
# Real Values : 8.0
# Predicted G3's score is 10.54
# Difference : 2.540
# 171
# Real Values : 12.0
# Predicted G3's score is 7.92
# Difference : 4.080
# 172
# Real Values : 13.0
# Predicted G3's score is 16.40
# Difference : 3.400
# 173
# Real Values : 11.0
# Predicted G3's score is 12.14
# Difference : 1.140
# 174
# Real Values : 12.0
# Predicted G3's score is 14.48
# Difference : 2.480
# 175
# Real Values : 9.0
# Predicted G3's score is 15.02
# Difference : 6.020
# 176
# Real Values : 15.0
# Predicted G3's score is 14.45
# Difference : 0.550
# 177
# Real Values : 12.0
# Predicted G3's score is 12.71
# Difference : 0.710
# 178
# Real Values : 15.0
# Predicted G3's score is 6.13
# Difference : 8.870
# 179
# Real Values : 14.0
# Predicted G3's score is 7.02
# Difference : 6.980
# 180
# Real Values : 12.0
# Predicted G3's score is 11.19
# Difference : 0.810
# 181
# Real Values : 10.0
# Predicted G3's score is 10.02
# Difference : 0.020
# 182
# Real Values : 10.0
# Predicted G3's score is 14.38
# Difference : 4.380
# 183
# Real Values : 13.0
# Predicted G3's score is 15.50
# Difference : 2.500
# 184
# Real Values : 12.0
# Predicted G3's score is 10.34
# Difference : 1.660
# 185
# Real Values : 11.0
# Predicted G3's score is 15.27
# Difference : 4.270
# 186
# Real Values : 11.0
# Predicted G3's score is 10.31
# Difference : 0.690
# 187
# Real Values : 9.0
# Predicted G3's score is 11.78
# Difference : 2.780
# 188
# Real Values : 11.0
# Predicted G3's score is 18.18
# Difference : 7.180
# 189
# Real Values : 14.0
# Predicted G3's score is 9.77
# Difference : 4.230

# %% [markdown]
# ### Mean Absolute Error after applying genetic algorithm

# %%
mean_abs_e_on_test_set = sum(diff_list) / len(y_test)
# mean_abs_e_on_test_set = mean_absolute_error(y_test_np, predictions)
print("Mean Absolute Error : {:.5f}".format(mean_abs_e_on_test_set))
# Out:
# Mean Absolute Error : 3.67074
