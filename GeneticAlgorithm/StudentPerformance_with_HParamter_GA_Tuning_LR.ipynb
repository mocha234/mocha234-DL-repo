# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # StudentPerformance_with_HParamter_GA_Tuning
#
# Building a predictions modle with Deep Learning Approach with Tensorflow/Keras.

# %% [markdown]
# ### Other Notebooks(in this learnign "series"):
#
# 1. [Genetic Algorithm with Python](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/GA_with_Python.ipynb) --> Understanding Genetic Algorithm with Python(without libraries)
# 2. [Predicting Student Performance(Empirically)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_with_NN.ipynb) --> Empirically tune hyper-parameters
# 3. [Predicting Student Performance(SKLearn's GridSearchCV)](ww) --> Tune hyper-parameters with Sci-Kit Learn's GridSearchCV
# 4. [Predicting Student Performance(Genetic Algorithm with PyGAD)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_PyGAD.ipynb) --> Tune hyper-parameters with GA using PyGAD
# 5. [Predicting Student Performance(Genetic Algorithm with Trained Model + PyGAD)](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_Tensorflow_PyGAD.ipynb) --> Tune GA hyper-parameters using PyGAD of a trained Model
# 6. [Some Findings, Comparison, Summary](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/GA_summary.ipynb) --> Summary of this learning "series"
#
#
# ***This Notebook*** 7. [Using GA to find the Best Hyperparameters](https://github.com/mocha234/mocha234-DL-repo/blob/main/GeneticAlgorithm/StudentPerformance_with_HParamter_GA_Tuning.ipynb) --> Using GA to find the Best Hyperparameters, encoding desire hyperparameter into gene in string of chromosome.

# %% [markdown]
# ### Index
#
# 1. Dataset
# 2. Packages Needed
# 3. Data Preprocessing
# 4. Building Deep Learning Model with Tensorflow/Keras
# 5. Finding the best Hyperparameters with GA
# 5. Inference

# %% [markdown]
# # 1. Dataset
#
# Source: https://archive.ics.uci.edu/ml/datasets/Student+Performance
#
# References:
# - https://www.kaggle.com/terrifictitan12/student-performance-81-accuracy
# - https://janakiev.com/blog/keras-iris/
# - https://datascienceplus.com/keras-regression-based-neural-networks/

# %% [markdown]
# #### Description
#
# This data approach student achievement in secondary education of two Portuguese schools. The data attributes include student grades, demographic, social and school related features) and it was collected by using school reports and questionnaires.
#
# Two datasets are provided regarding the performance in two distinct subjects: Mathematics (mat) and Portuguese language (por).
#
# #### Note: In this notebook, I used the Dataset with Portuguese Language
#
# In [Cortez and Silva, 2008], the two datasets were modeled under binary/five-level classification and regression tasks.
#
# Important note: the target attribute G3 has a strong correlation with attributes G2 and G1.
#
# This occurs because G3 is the final year grade (issued at the 3rd period), while G1 and G2 correspond to the 1st and 2nd-period grades. It is more difficult to predict G3 without G2 and G1, but such prediction is much more useful (see paper source for more details).

# %% [markdown]
# ### Attribute Information:
#
# ### Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
# * 1 school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)*
# * 2 sex - student's sex (binary: 'F' - female or 'M' - male)
# * 3 age - student's age (numeric: from 15 to 22)
# * 4 address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * 5 famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * 6 Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * 7 Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# * 8 Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 â€“ 5th to 9th grade, 3 â€“ secondary education or 4 â€“ higher education)
# * 9 Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * 10 Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * 11 reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * 12 guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# * 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# * 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * 16 schoolsup - extra educational support (binary: yes or no)
# * 17 famsup - family educational support (binary: yes or no)
# * 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * 19 activities - extra-curricular activities (binary: yes or no)
# * 20 nursery - attended nursery school (binary: yes or no)
# * 21 higher - wants to take higher education (binary: yes or no)
# * 22 internet - Internet access at home (binary: yes or no)
# * 23 romantic - with a romantic relationship (binary: yes or no)
# * 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
# * 30 absences - number of school absences (numeric: from 0 to 93)
#
# #### these grades are related with the course subject, Math or Portuguese:
# * 31 G1 - first period grade (numeric: from 0 to 20)
# * 31 G2 - second period grade (numeric: from 0 to 20)
# * 32 G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# # 2. Packages Needed

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow import convert_to_tensor
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

pd.set_option('display.max_columns', None)
np.set_printoptions(precision=15)
plt.rcParams["figure.figsize"] = (17, 6) # (w, h)
# %matplotlib inline

# %% [markdown]
# # 3. Data Preprocessing

# %%
df = pd.read_csv("student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2  G3
# 0       1     1       3         4   0  11  11
# 1       1     1       3         2   9  11  11
# 2       2     3       3         6  12  13  12
# 3       1     1       5         0  14  14  14
# 4       1     2       5         0  11  13  13
# ..    ...   ...     ...       ...  ..  ..  ..
# 644     1     2       5         4  10  11  10
# 645     1     1       1         4  15  15  16
# 646     1     1       5         6  11  12   9
# 647     3     4       2         6  10  10  10
# 648     3     4       5         4  10  11  11
#
# [649 rows x 33 columns]

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
# df.dtypes

# %%
# df.isnull().sum() 
# Check for missing data

# %%
features_list = list(df.columns)[:-1]
print("Features: {x}".format(x = features_list))
print("\nNumber of Features: {x}".format(x = len(features_list)))
# Out:
# Features: ['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']
#
# Number of Features: 32

# %%
# df.info()
# # Check datatype of features

# %%
features = df.drop(["G3"], axis = 1)
features
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2
# 0       1     1       3         4   0  11
# 1       1     1       3         2   9  11
# 2       2     3       3         6  12  13
# 3       1     1       5         0  14  14
# 4       1     2       5         0  11  13
# ..    ...   ...     ...       ...  ..  ..
# 644     1     2       5         4  10  11
# 645     1     1       1         4  15  15
# 646     1     1       5         6  11  12
# 647     3     4       2         6  10  10
# 648     3     4       5         4  10  11
#
# [649 rows x 32 columns]

# %%
target = df.drop(features_list, axis = 1)
target
# Out:
#      G3
# 0    11
# 1    11
# 2    12
# 3    14
# 4    13
# ..   ..
# 644  10
# 645  16
# 646   9
# 647  10
# 648  11
#
# [649 rows x 1 columns]

# %%
mapping_school = {'GP' : 0, 'MS' : 1}
mapping_sex = {'F' : 0, 'M' : 1}
mapping_address = {'U' : 0, 'R' : 1}
mapping_famsize = {'GT3' : 0, 'LE3' : 1}
mapping_pstatus = {'A' : 0, 'T' : 1}
mapping_mjob = {'at_home' : 0, 'health' : 1, 'other' : 2, 'services' : 3, 'teacher' : 4}
mapping_fjob = {'at_home' : 0, 'health' : 1, 'other' : 2, 'services' : 3, 'teacher' : 4}
mapping_reason = {'course' : 0, 'other' : 1, 'home' : 2, 'reputation' : 3}
mapping_guardian = {'mother' : 0, 'father' : 1, 'other': 2}
mapping_schoolsup = {'no' : 0, 'yes' : 1}
mapping_famsup = {'no' : 0, 'yes' : 1}
mapping_romantic = {'no' : 0, 'yes' : 1}
mapping_paid = {'no' : 0, 'yes' : 1}
mapping_activities = {'no' : 0, 'yes' : 1}
mapping_nursery = {'no' : 0, 'yes' : 1}
mapping_higher = {'no' : 0, 'yes' : 1}
mapping_internet = {'no' : 0, 'yes' : 1}

# %%
df['school'] = features['school'].map(mapping_school)
df['sex'] = features['sex'].map(mapping_sex)
df['address'] = features['address'].map(mapping_address)
df['famsize'] = features['famsize'].map(mapping_famsize)
df['Pstatus'] = features['Pstatus'].map(mapping_pstatus)
df['Mjob'] = features['Mjob'].map(mapping_mjob)
df['Fjob'] = features['Fjob'].map(mapping_fjob)
df['reason'] = features['reason'].map(mapping_reason)
df['guardian'] = features['guardian'].map(mapping_guardian).astype('Int64')
df['famsup'] = features['famsup'].map(mapping_famsup)
df['schoolsup'] = features['schoolsup'].map(mapping_schoolsup)
df['romantic'] = features['romantic'].map(mapping_romantic)
df['paid'] = features['paid'].map(mapping_paid)
df['activities'] = features['activities'].map(mapping_activities)
df['nursery'] = features['nursery'].map(mapping_nursery)
df['higher'] = features['higher'].map(mapping_higher)
df['internet'] = features['internet'].map(mapping_internet)

# %%
features
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother           2          2         0       yes     no   no
# 1    course   father           1          2         0        no    yes   no
# 2     other   mother           1          2         0       yes     no   no
# 3      home   mother           1          3         0        no    yes   no
# 4      home   father           1          2         0        no    yes   no
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 644  course   mother           1          3         1        no     no   no
# 645  course   mother           1          2         0        no    yes   no
# 646  course   mother           2          2         0        no     no   no
# 647  course   mother           2          1         0        no     no   no
# 648  course   mother           3          1         0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes       no       no       4         3      4
# 1           no      no    yes      yes       no       5         3      3
# 2           no     yes    yes      yes       no       4         3      2
# 3          yes     yes    yes      yes      yes       3         2      2
# 4           no     yes    yes       no       no       4         3      2
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 644        yes      no    yes      yes       no       5         4      2
# 645         no     yes    yes      yes       no       4         3      4
# 646        yes     yes    yes       no       no       1         1      1
# 647         no      no    yes      yes       no       2         4      5
# 648         no      no    yes      yes       no       4         4      1
#
#      Dalc  Walc  health  absences  G1  G2
# 0       1     1       3         4   0  11
# 1       1     1       3         2   9  11
# 2       2     3       3         6  12  13
# 3       1     1       5         0  14  14
# 4       1     2       5         0  11  13
# ..    ...   ...     ...       ...  ..  ..
# 644     1     2       5         4  10  11
# 645     1     1       1         4  15  15
# 646     1     1       5         6  11  12
# 647     3     4       2         6  10  10
# 648     3     4       5         4  10  11
#
# [649 rows x 32 columns]

# %%
# features.dtypes

# %%
sns.countplot(x='school', data=features);

# %%
features.hist(bins=20, figsize=(20,15));

# %% [markdown]
# #### Outliers
#
# As I go through the data, I found there are students who achieve 0 in their G3 depsite having more than half during their G1 & G2 examinations.
# The outliers might affect model's performance, hence I decided to drop those outliers.

# %%
sns.boxplot(x=target["G3"]);

# %% [markdown]
# #### Drop Outliers data if certain requirement satisfied.
#
# G3 with score of 2.5 and less considered as Outliers. To understand this data, I will list down these outliers.

# %%
df_outliers = df[df["G3"]<2.5]
df_outliers
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 163       0    1   18        0        1        1     1     1     2     2
# 172       0    1   16        0        0        1     3     3     2     3
# 440       1    1   16        0        0        1     1     1     0     3
# 519       1    1   16        1        0        1     2     1     2     3
# 563       1    1   17        0        0        1     2     2     2     2
# 567       1    1   18        1        0        1     3     2     3     2
# 583       1    0   18        1        0        1     2     2     2     2
# 586       1    0   17        0        0        1     4     2     4     3
# 597       1    0   18        1        0        1     2     2     0     2
# 603       1    0   18        1        1        0     4     2     4     2
# 605       1    0   19        0        0        1     1     1     0     3
# 610       1    0   19        1        0        0     1     1     0     0
# 626       1    0   18        1        0        1     4     4     2     4
# 637       1    1   18        1        0        1     2     1     2     2
# 639       1    1   19        1        0        1     1     1     2     3
# 640       1    1   18        1        0        1     4     2     2     2
#
#      reason  guardian  traveltime  studytime  failures  schoolsup  famsup  \
# 163       0         0           1          1         2          0       0
# 172       0         1           1          2         1          0       1
# 440       2         0           2          2         0          0       1
# 519       3         0           2          2         0          0       0
# 563       0         0           1          1         1          0       0
# 567       0         0           1          1         1          0       0
# 583       1         0           2          1         1          0       0
# 586       2         0           1          2         0          1       1
# 597       0         0           3          2         1          0       0
# 603       3         0           1          2         0          0       0
# 605       1         1           2          1         1          0       0
# 610       0         2           2          2         3          0       1
# 626       1         1           3          2         0          0       1
# 637       1         0           2          1         0          0       0
# 639       1         0           2          1         1          0       0
# 640       2         1           2          1         1          0       0
#
#      paid  activities  nursery  higher  internet  romantic  famrel  freetime  \
# 163     0           0        1       0         1         1       2         3
# 172     0           0        1       1         1         1       4         5
# 440     0           1        1       1         0         1       5         4
# 519     0           1        1       1         1         0       5         2
# 563     0           1        1       1         0         1       1         2
# 567     0           0        1       0         1         0       2         3
# 583     0           0        1       0         1         1       5         5
# 586     0           1        1       1         1         0       5         5
# 597     0           1        1       1         0         1       4         3
# 603     0           1        1       1         1         1       5         3
# 605     0           0        1       0         0         0       5         5
# 610     0           1        1       0         0         1       3         5
# 626     0           0        0       1         1         1       3         2
# 637     0           1        0       1         1         1       4         4
# 639     0           0        1       1         0         0       4         3
# 640     1           0        1       1         0         0       5         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# 163      5     2     5       4         0  11   9   0
# 172      5     4     4       5         0  10  10   1
# 440      5     4     5       3         0   7   0   0
# 519      1     1     1       2         0   8   7   0
# 563      1     2     3       5         0   7   0   0
# 567      1     2     2       5         0   4   0   0
# 583      5     1     1       3         0   8   6   0
# 586      5     1     3       5         0   8   8   0
# 597      3     1     1       4         0   9   0   0
# 603      1     1     1       5         0   5   0   0
# 605      5     2     3       2         0   5   0   0
# 610      4     1     4       1         0   8   0   0
# 626      2     4     2       5         0   7   5   0
# 637      3     1     3       5         0   7   7   0
# 639      2     1     3       5         0   5   8   0
# 640      3     4     3       3         0   7   7   0

# %% [markdown]
# #### Dropping rows if:
#
# G3 considered as outliers when G1 or G2 above average.

# %%
outlier_idx = df[df["G3"] < 2.5].index
len(outlier_idx) 
df = df.drop(outlier_idx)
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  \
# 0         0    0   18        0        0        0     4     4     0     4
# 1         0    0   17        0        0        1     1     1     0     2
# 2         0    0   15        0        1        1     1     1     0     2
# 3         0    0   15        0        0        1     4     2     1     3
# 4         0    0   16        0        0        1     3     3     2     2
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...
# 644       1    0   19        1        0        1     2     3     3     2
# 645       1    0   18        0        1        1     3     1     4     3
# 646       1    0   18        0        0        1     1     1     2     2
# 647       1    1   17        0        1        1     3     1     3     3
# 648       1    1   18        1        1        1     3     2     3     2
#
#      reason  guardian  traveltime  studytime  failures  schoolsup  famsup  \
# 0         0         0           2          2         0          1       0
# 1         0         1           1          2         0          0       1
# 2         1         0           1          2         0          1       0
# 3         2         0           1          3         0          0       1
# 4         2         1           1          2         0          0       1
# ..      ...       ...         ...        ...       ...        ...     ...
# 644       0         0           1          3         1          0       0
# 645       0         0           1          2         0          0       1
# 646       0         0           2          2         0          0       0
# 647       0         0           2          1         0          0       0
# 648       0         0           3          1         0          0       0
#
#      paid  activities  nursery  higher  internet  romantic  famrel  freetime  \
# 0       0           0        1       1         0         0       4         3
# 1       0           0        0       1         1         0       5         3
# 2       0           0        1       1         1         0       4         3
# 3       0           1        1       1         1         1       3         2
# 4       0           0        1       1         0         0       4         3
# ..    ...         ...      ...     ...       ...       ...     ...       ...
# 644     0           1        0       1         1         0       5         4
# 645     0           0        1       1         1         0       4         3
# 646     0           1        1       1         0         0       1         1
# 647     0           0        0       1         1         0       2         4
# 648     0           0        0       1         1         0       4         4
#
#      goout  Dalc  Walc  health  absences  G1  G2  G3
# 0        4     1     1       3         4   0  11  11
# 1        3     1     1       3         2   9  11  11
# 2        2     2     3       3         6  12  13  12
# 3        2     1     1       5         0  14  14  14
# 4        2     1     2       5         0  11  13  13
# ..     ...   ...   ...     ...       ...  ..  ..  ..
# 644      2     1     2       5         4  10  11  10
# 645      4     1     1       1         4  15  15  16
# 646      1     1     1       5         6  11  12   9
# 647      5     3     4       2         6  10  10  10
# 648      1     3     4       5         4  10  11  11
#
# [633 rows x 33 columns]

# %% [markdown]
# ### Reassign features and target dataframe after dropping outliers

# %%
target = df.drop(features_list, axis = 1)
features = df.drop(["G3"], axis = 1)

# %% [markdown]
# ### Data Normalization

# %% [markdown]
# #### Split Training and Testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.3,random_state=11)

# %%
scaler = preprocessing.MinMaxScaler(feature_range = (0,1))
X_train_scaled = scaler.fit_transform(X_train)
y_train_scaled = scaler.fit_transform(y_train)
X_test_scaled = scaler.fit_transform(X_test)
y_test_scaled = scaler.fit_transform(y_test)

# %%
X_train_unscaled = scaler.inverse_transform(X_train_scaled).astype('float64') 
y_train_unscaled = scaler.inverse_transform(y_train_scaled).astype('float64') 
X_test_unscaled = scaler.inverse_transform(X_test_scaled).astype('float64') 
y_test_unscaled = scaler.inverse_transform(y_test_scaled).astype('float64')

# %%
X_test_np = X_test.values.astype(int)
y_test_np = y_test.values.astype(int)
X_test_np = convert_to_tensor(X_test_np)
y_test_np = convert_to_tensor(y_test_np)

# %% [markdown]
# # 4. Building Deep Learning Model with Tensorflow/Keras

# %%
init_LR = 0.1
theLearningRate = init_LR

# %%
def create_model(theLearningRate = theLearningRate):

    model = Sequential([
    Dense(32, input_dim=32, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1, activation='relu')
    ])
    optimizer = Adam(lr = theLearningRate)
    model.compile(
        loss='mse', 
        optimizer=optimizer, 
        metrics=['mse','mae']
    )
    return model

# %% [markdown]
# # GA Starts here

# %% [markdown]
# # 5. Finding the best Hyperparameters with GA

# %% [markdown]
# ### Hyperparameters Encoding

# %%
# hyperparams_optimizerFunc = {
#     1 : "SGD",
#     2 : "RMSprop",
#     3 : "Adagrad",
#     4 : "Adam"
# }
# For now use ADAM

hyperparams_batchSize = {
    0 : 50,
    1 : 100,
    2 : 200,
    3 : 500,
}


hyperparams_learningRate = {
    0 : 0.1,
    1 : 0.5,
    2 : 0.01,
    3 : 0.05,
}

hyperparams_noEpochs = {
    0 : 100,
    1 : 200,
    2 : 400,
    3 : 500,
}

# %%
# hyperparams_optimizerFunc = {
#     1 : "SGD",
#     2 : "RMSprop",
#     3 : "Adagrad",
#     4 : "Adam"
# }
# For now use ADAM

hyperparams_batchSize = {
    0 : 6,
    1 : 12,
    2 : 24,
    3 : 36,
    4 : 48
}


hyperparams_learningRate = {
    0 : 0.1,
    1 : 0.5,
    2 : 0.01,
    3 : 0.05,
}

hyperparams_noEpochs = {
    0 : 100,
    1 : 200,
    2 : 400,
    3 : 500,
    4 : 600,
    5 : 700,
}

# %%
# Initially Learning Rate
hyperparams_learningRate = np.random.uniform(0.1, 0.0005)

# %% [markdown]
# ### Configure GA

# %%
chromosomes_per_population = 4 
genes_per_chromosome = 3 
pop_size = (chromosomes_per_population, genes_per_chromosome)
n_gen = 50
new_population = np.random.randint(0,4,pop_size) # 0-4 --> 0,1,2,3

# %% [markdown]
# ### Define Initial Population

# %%
new_population
# Out:
# array([[1, 2, 0],
#        [3, 2, 2],
#        [3, 1, 1],
#        [3, 0, 3]])

# %% [markdown]
# ## Enconding
#
# Index : 2, 1, 0
#
# Genes : Batch Size, Learning Rate, No of Epochs

# %% [markdown]
# # Defining Functions

# %% [markdown]
# ### Breeding

# %%
range(chromosomes_per_population)
# Out:
# range(0, 4)

# %%
def breeding(chromosomes_per_population):
    print("\n<---Breeding--->")
    fitness_val_in_pop = []
    print("Chromosome per population :", chromosomes_per_population)
    

    for i in range(chromosomes_per_population) :
        print("Chromosome :", i)
        
        the_NoEpochs = hyperparams_noEpochs[new_population[i][0]]
        the_LR = hyperparams_learningRate[new_population[i][1]]
        the_BatchSize = hyperparams_batchSize[new_population[i][2]]
        

        print("Learning Rate: ",the_LR)
        print("Batch Size:",the_BatchSize)
        print("Number of Epochs :",the_NoEpochs)
        print("\n")

        model = create_model(
            theLearningRate = the_LR
        )
        model.optimizer.get_config()
        print(model.optimizer.get_config())

        history = model.fit(
            X_test_scaled, 
            y_test_scaled, 
            epochs=the_NoEpochs, 
            batch_size= the_BatchSize,  
            verbose=0, validation_split=0.2) 
        print("\n")
        loss, mean_sq_e, mean_abs_e = model.evaluate(X_test_np, y_test_np)
        f_val = 1/mean_sq_e + 0.00001
        fitness_val_in_pop.append(f_val)
        print("Fitness Value: ",f_val)
#         print(fitness_val_in_pop)
        max_fVal = np.max(fitness_val_in_pop)
        print("Max Fitness Value of the Population :",max_fVal)
        print(fitness_val_in_pop)
        print("\n")
        
    return (max_fVal, fitness_val_in_pop)

# %% [markdown]
# ### Selection
#
# Selecting the best parents to mate and breed.

# %%
def sorting_by_fVal(fitness_val_in_pop):
    print("\n<---Sorting--->")
    fitness_val_in_pop_sorted_index = np.argsort(-fitness_val_in_pop)
    top1and2 = new_population[fitness_val_in_pop_sorted_index[0:2]]
    top3and4 = new_population[fitness_val_in_pop_sorted_index[2:4]]

    
    sorted_population = np.concatenate((top1and2, top3and4))
    fittest_chromose_in_pop = new_population[fitness_val_in_pop_sorted_index[0]]
    print(sorted_population)
    return (fittest_chromose_in_pop, sorted_population)

# %% [markdown]
# ### Crossover
#
# For now, only got 3 genes, crossover/swap index 0 between the parents.
# Instead of swapping just one, swap the other two.

# %%
def crossover(sorted_population):
    print("\n<---Crossover--->")
    tmp = np.array(sorted_population[:])
    tmp2 = np.zeros(np.shape(sorted_population))

    for i in range(len(sorted_population)):
        if (i % 2) == 0:  
            tmp[i][1:3] = sorted_population[i+1][1:3]
        else:  
            tmp[i][1:3] = sorted_population[i-1][1:3]
            
    new_population = tmp
    return new_population

# %% [markdown]
# ### Fittest chromosome

# %% [markdown]
# ### Combining the functions

# %%
def ga_run(new_population):
    fVal_gen = []
    max_fVal = 0.00
    idx_max_fVal = 0
    
    for i in range(n_gen):
        print("Generation: ",i)
        print("Population of Chromosomes:")
        print(new_population)
        
        pop_max_fVal, fitness_val_in_pop = breeding(chromosomes_per_population)
        fVal_gen.append(pop_max_fVal)
        
        fittest_chromosome, sorted_population = sorting_by_fVal(np.array(fitness_val_in_pop))
        
        new_population = crossover(sorted_population)
        print("After Crossover")
        print(new_population)
        
        if max_fVal < pop_max_fVal:
            max_fVal = pop_max_fVal
            idx_max_fVal = i
            fittest_chromosome = fittest_chromosome
            print("Chromosome Updated")
            print("Current fittest Chromosome :")
            print(fittest_chromosome)
            
        else:
            print("Previous Generation Chromosome is better:")
            print("Current fittest Chromosome :")
            print(fittest_chromosome)
            
        print("\n")
            
    return (fVal_gen, max_fVal, idx_max_fVal, fittest_chromosome)

# %% [markdown]
# # Executing Genetic Algorithm

# %%
fVal_gen, max_fVal, idx_max_fVal, fittest_chromosome = ga_run(new_population)
# Out:
# Generation:  0
# Population of Chromosomes:
# [[1 2 0]
#  [3 2 2]
#  [3 1 1]
#  [3 0 3]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.006221586329733097
# [0.006221586329733097]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 878us/step - loss: 30.6491 - mse: 30.6491 - mae: 5.4244
# Fitness Value:  0.03263733336980111
# Max Fitness Value of the Population : 0.03263733336980111
# [0.006221586329733097, 0.03263733336980111]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.03263733336980111
# [0.006221586329733097, 0.03263733336980111, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.03263733336980111
# [0.006221586329733097, 0.03263733336980111, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[3 2 2]
#  [1 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
# Chromosome Updated
# Current fittest Chromosome :
# [3 2 2]
#
#
# Generation:  1
# Population of Chromosomes:
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 7.7078 - mse: 7.7078 - mae: 2.5836
# Fitness Value:  0.12974804959135786
# Max Fitness Value of the Population : 0.12974804959135786
# [0.12974804959135786]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 27.6567 - mse: 27.6567 - mae: 5.1163
# Fitness Value:  0.03616761356219473
# Max Fitness Value of the Population : 0.12974804959135786
# [0.12974804959135786, 0.03616761356219473]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 954us/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.12974804959135786
# [0.12974804959135786, 0.03616761356219473, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.12974804959135786
# [0.12974804959135786, 0.03616761356219473, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[1 2 0]
#  [3 2 2]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
# Chromosome Updated
# Current fittest Chromosome :
# [1 2 0]
#
#
# Generation:  2
# Population of Chromosomes:
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 10.7231 - mse: 10.7231 - mae: 3.0546
# Fitness Value:  0.09326669969917221
# Max Fitness Value of the Population : 0.09326669969917221
# [0.09326669969917221]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 13.5830 - mse: 13.5830 - mae: 3.5061
# Fitness Value:  0.07363127216201262
# Max Fitness Value of the Population : 0.09326669969917221
# [0.09326669969917221, 0.07363127216201262]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 822us/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.09326669969917221
# [0.09326669969917221, 0.07363127216201262, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.09326669969917221
# [0.09326669969917221, 0.07363127216201262, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[1 2 0]
#  [3 2 2]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [1 2 0]
#
#
# Generation:  3
# Population of Chromosomes:
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 848us/step - loss: 23.1734 - mse: 23.1734 - mae: 4.6535
# Fitness Value:  0.04316301249572926
# Max Fitness Value of the Population : 0.04316301249572926
# [0.04316301249572926]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 10.7742 - mse: 10.7742 - mae: 3.1242
# Fitness Value:  0.09282426260186478
# Max Fitness Value of the Population : 0.09282426260186478
# [0.04316301249572926, 0.09282426260186478]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.09282426260186478
# [0.04316301249572926, 0.09282426260186478, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 964us/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.09282426260186478
# [0.04316301249572926, 0.09282426260186478, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[3 2 2]
#  [1 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [3 2 2]
#
#
# Generation:  4
# Population of Chromosomes:
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
# 6/6 [==============================] - 0s 1ms/step - loss: 6.5616 - mse: 6.5616 - mae: 2.2873
# Fitness Value:  0.15241071870952036
# Max Fitness Value of the Population : 0.15241071870952036
# [0.15241071870952036]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 977us/step - loss: 8.0302 - mse: 8.0302 - mae: 2.6460
# Fitness Value:  0.12454009181899565
# Max Fitness Value of the Population : 0.15241071870952036
# [0.15241071870952036, 0.12454009181899565]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.15241071870952036
# [0.15241071870952036, 0.12454009181899565, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 32.4047 - mse: 32.4047 - mae: 5.4897
# Fitness Value:  0.030869727057919436
# Max Fitness Value of the Population : 0.15241071870952036
# [0.15241071870952036, 0.12454009181899565, 0.006221586329733097, 0.030869727057919436]
#
#
#
# <---Sorting--->
# [[1 2 0]
#  [3 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Crossover--->
# After Crossover
# [[1 2 2]
#  [3 2 0]
#  [3 1 1]
#  [3 0 3]]
# Chromosome Updated
# Current fittest Chromosome :
# [1 2 0]
#
#
# Generation:  5
# Population of Chromosomes:
# [[1 2 2]
#  [3 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 13.1007 - mse: 13.1007 - mae: 3.4569
# Fitness Value:  0.07634171351002522
# Max Fitness Value of the Population : 0.07634171351002522
# [0.07634171351002522]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 10.9930 - mse: 10.9930 - mae: 3.1320
# Fitness Value:  0.0909769945173911
# Max Fitness Value of the Population : 0.0909769945173911
# [0.07634171351002522, 0.0909769945173911]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.0909769945173911
# [0.07634171351002522, 0.0909769945173911, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.0909769945173911
# [0.07634171351002522, 0.0909769945173911, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[3 2 2]
#  [1 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [3 2 2]
#
#
# Generation:  6
# Population of Chromosomes:
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 5.5370 - mse: 5.5370 - mae: 2.1445
# Fitness Value:  0.18061404876834297
# Max Fitness Value of the Population : 0.18061404876834297
# [0.18061404876834297]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 12.8672 - mse: 12.8672 - mae: 3.4179
# Fitness Value:  0.07772721684763423
# Max Fitness Value of the Population : 0.18061404876834297
# [0.18061404876834297, 0.07772721684763423]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.18061404876834297
# [0.18061404876834297, 0.07772721684763423, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.18061404876834297
# [0.18061404876834297, 0.07772721684763423, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[1 2 0]
#  [3 2 2]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
# Chromosome Updated
# Current fittest Chromosome :
# [1 2 0]
#
#
# Generation:  7
# Population of Chromosomes:
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 6.1745 - mse: 6.1745 - mae: 2.2572
# Fitness Value:  0.161966383989984
# Max Fitness Value of the Population : 0.161966383989984
# [0.161966383989984]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 3.5594 - mse: 3.5594 - mae: 1.5629
# Fitness Value:  0.28095277669367447
# Max Fitness Value of the Population : 0.28095277669367447
# [0.161966383989984, 0.28095277669367447]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 855us/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.28095277669367447
# [0.161966383989984, 0.28095277669367447, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.28095277669367447
# [0.161966383989984, 0.28095277669367447, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[3 2 2]
#  [1 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
# Chromosome Updated
# Current fittest Chromosome :
# [3 2 2]
#
#
# Generation:  8
# Population of Chromosomes:
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
# 6/6 [==============================] - 0s 1ms/step - loss: 21.5287 - mse: 21.5287 - mae: 4.5233
# Fitness Value:  0.046459610985571144
# Max Fitness Value of the Population : 0.046459610985571144
# [0.046459610985571144]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 970us/step - loss: 19.7153 - mse: 19.7153 - mae: 4.3003
# Fitness Value:  0.050732058524901445
# Max Fitness Value of the Population : 0.050732058524901445
# [0.046459610985571144, 0.050732058524901445]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 839us/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.050732058524901445
# [0.046459610985571144, 0.050732058524901445, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 911us/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.050732058524901445
# [0.046459610985571144, 0.050732058524901445, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[3 2 2]
#  [1 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [3 2 2]
#
#
# Generation:  9
# Population of Chromosomes:
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 11.7474 - mse: 11.7474 - mae: 3.2838
# Fitness Value:  0.08513536226395457
# Max Fitness Value of the Population : 0.08513536226395457
# [0.08513536226395457]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 27.7528 - mse: 27.7528 - mae: 5.1010
# Fitness Value:  0.036042365681008055
# Max Fitness Value of the Population : 0.08513536226395457
# [0.08513536226395457, 0.036042365681008055]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.08513536226395457
# [0.08513536226395457, 0.036042365681008055, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 6.1505 - mse: 6.1505 - mae: 2.3035
# Fitness Value:  0.16259862647454948
# Max Fitness Value of the Population : 0.16259862647454948
# [0.08513536226395457, 0.036042365681008055, 0.006221586329733097, 0.16259862647454948]
#
#
#
# <---Sorting--->
# [[3 0 3]
#  [1 2 0]
#  [3 2 2]
#  [3 1 1]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 0 3]
#  [3 1 1]
#  [3 2 2]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [3 0 3]
#
#
# Generation:  10
# Population of Chromosomes:
# [[3 2 0]
#  [1 0 3]
#  [3 1 1]
#  [3 2 2]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.006221586329733097
# [0.006221586329733097]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 915us/step - loss: 11.5340 - mse: 11.5340 - mae: 3.2581
# Fitness Value:  0.08671003721588778
# Max Fitness Value of the Population : 0.08671003721588778
# [0.006221586329733097, 0.08671003721588778]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.08671003721588778
# [0.006221586329733097, 0.08671003721588778, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.08671003721588778
# [0.006221586329733097, 0.08671003721588778, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[3 2 2]
#  [1 2 0]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [3 2 2]
#
#
# Generation:  11
# Population of Chromosomes:
# [[3 2 0]
#  [1 2 2]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.006221586329733097
# [0.006221586329733097]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.006221586329733097
# [0.006221586329733097, 0.006221586329733097]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.006221586329733097
# [0.006221586329733097, 0.006221586329733097, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.006221586329733097
# [0.006221586329733097, 0.006221586329733097, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[1 2 0]
#  [3 2 2]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [1 2 0]
#
#
# Generation:  12
# Population of Chromosomes:
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
# 6/6 [==============================] - 0s 910us/step - loss: 7.8901 - mse: 7.8901 - mae: 2.6502
# Fitness Value:  0.12675089143818852
# Max Fitness Value of the Population : 0.12675089143818852
# [0.12675089143818852]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 9.8281 - mse: 9.8281 - mae: 2.9708
# Fitness Value:  0.10175881750437993
# Max Fitness Value of the Population : 0.12675089143818852
# [0.12675089143818852, 0.10175881750437993]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.12675089143818852
# [0.12675089143818852, 0.10175881750437993, 0.006221586329733097]
#
#
# Chromosome : 3
# Learning Rate:  0.1
# Batch Size: 36
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.1, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 1ms/step - loss: 160.9895 - mse: 160.9895 - mae: 12.4211
# Fitness Value:  0.006221586329733097
# Max Fitness Value of the Population : 0.12675089143818852
# [0.12675089143818852, 0.10175881750437993, 0.006221586329733097, 0.006221586329733097]
#
#
#
# <---Sorting--->
# [[1 2 0]
#  [3 2 2]
#  [3 1 1]
#  [3 0 3]]
#
# <---Crossover--->
# After Crossover
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
# Previous Generation Chromosome is better:
# Current fittest Chromosome :
# [1 2 0]
#
#
# Generation:  13
# Population of Chromosomes:
# [[1 2 2]
#  [3 2 0]
#  [3 0 3]
#  [3 1 1]]
#
# <---Breeding--->
# Chromosome per population : 4
# Chromosome : 0
# Learning Rate:  0.01
# Batch Size: 6
# Number of Epochs : 200
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 870us/step - loss: 8.3518 - mse: 8.3518 - mae: 2.7004
# Fitness Value:  0.11974529740560352
# Max Fitness Value of the Population : 0.11974529740560352
# [0.11974529740560352]
#
#
# Chromosome : 1
# Learning Rate:  0.01
# Batch Size: 24
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.01, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
#
#
# 6/6 [==============================] - 0s 872us/step - loss: 7.6033 - mse: 7.6033 - mae: 2.5936
# Fitness Value:  0.13153111996446867
# Max Fitness Value of the Population : 0.13153111996446867
# [0.11974529740560352, 0.13153111996446867]
#
#
# Chromosome : 2
# Learning Rate:  0.5
# Batch Size: 12
# Number of Epochs : 500
#
#
# {'name': 'Adam', 'learning_rate': 0.5, 'decay': 0.0, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}

# %%
x_axis= list(range(len(fVal_gen)))
x_ticks = x_axis
x_labels = x_axis
fig, ax = plt.subplots(1,1)
ax.plot(x_axis, fVal_gen)

ax.xaxis.set_ticks(x_ticks)
ax.xaxis.set_ticklabels(x_labels)
plt.xlabel("Generation")
plt.ylabel("Fitness Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a24de4b41274> in <module>
# ----> 1 x_axis= list(range(len(fVal_gen)))
#       2 x_ticks = x_axis
#       3 x_labels = x_axis
#       4 fig, ax = plt.subplots(1,1)
#       5 ax.plot(x_axis, fVal_gen)
#
# NameError: name 'fVal_gen' is not defined

# %%
print("Fittest Generation: ", idx_max_fVal)
print("Fittest Chromosome's Fitness Value: ", max_fVal)
print("Fittest Chromosome: ", fittest_chromosome)

print("\nBest Hyperparameters found using Genetic Algorithm:")
print("Learning Rate :\t",hyperparams_learningRate[fittest_chromosome[1]])
print("Batch Size :\t",hyperparams_batchSize[fittest_chromosome[2]])
print("No of Epochs :\t",hyperparams_noEpochs[fittest_chromosome[0]])

# %% [markdown]
# ## Building model based on the "Best Chromosome"

# %% [markdown]
# By using above Hyperparameters(best Hyperparameter foudn using GA), we build a model again and train it.

# %%
best_hyperparams = fittest_chromosome[:]
best_LR = hyperparams_learningRate[best_hyperparams[1]]
best_BatchSize = hyperparams_batchSize[best_hyperparams[2]]
best_noOfEpochs = hyperparams_batchSize[best_hyperparams[0]]

print("Learning Rate :\t",best_LR)
print("Batch Size :\t", best_BatchSize)
print("No of Epochs :\t",best_noOfEpochs)
print("\n")

# %%
model = create_model(
#       theLearningRate = best_LR
        theLearningRate = 0.01
        )

print(model.optimizer.get_config())
print("\n")

model.summary()

# %%
history = model.fit(
    X_test_scaled, 
    y_test_scaled, 
    epochs=400, 
    batch_size= 50,  
    
    #epochs=best_noOfEpochs, 
    #batch_size= best_BatchSize,  
    
    verbose=0, 
    validation_split=0.2)

# %%
# print(history.history.keys())
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
loss, mean_sq_e, mean_abs_e = model.evaluate(X_test_scaled, y_test_scaled)
print("Mean Squared Error : {:.5f}".format(mean_sq_e))
print("Mean Absolute Error : {:.5f}".format(mean_abs_e))

# %% [markdown]
# # 6. Inference

# %%
predictions = model.predict(X_test_scaled)
predictions = scaler.inverse_transform(predictions)
predictions = np.round(predictions, 2)
# print("Predictions : \n", predictions)

# %% [markdown]
# Inference on 14th Student

# %%
student_index = 14
g_truth = float(y_test_np[student_index])
p = float(predictions[student_index])
print("Real Values :", g_truth)
print("Predicted G3's score is {:.2f}".format(p))
diff = np.abs(p-g_truth)
print("Difference : {:.3f}".format(diff))

# %% [markdown]
# #### On Test Set/Unseen Data, manually:

# %%
diff_list = []

for i in range(0,len(y_test)):
    
    g_truth = float(y_test_np[i])
    p = float(predictions[i])
    diff = np.abs(p-g_truth)
    diff_list.append(diff)
    print(i)  
    print("Real Values :", g_truth)
    print("Predicted G3's score is {:.2f}".format(p))
    print("Difference : {:.3f}".format(diff))

# %% [markdown]
# ### Mean Absolute Error after applying genetic algorithm

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mean_abs_e_on_test_set = sum(diff_list) / len(y_test)
mean_abs_e_on_test_set1 = mean_absolute_error(y_test_np, predictions)
print("Mean Absolute Error : {:.5f}".format(mean_abs_e_on_test_set))

# %% [markdown]
# Thanks for reading!
